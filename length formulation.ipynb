# %% [markdown]
# # I. DATA PREPARATION

# %%
# we will import all the necessary libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import json
import re
from shapely.geometry import Point, LineString #this library is for manipulating geometric objects, and it is what geopandas uses to store geometries
from scipy.spatial import distance

# %%
#tlf provides passenger flow data for each network separately
#we need to create a list of all the different files we need
df_dlr = pd.read_csv('https://www.dropbox.com/scl/fi/xkf9ttbop2wyypp8bttgw/NBT19MTT2b_od__DLR_tb_wf.csv?rlkey=me22ozynt7i13ah9hvh9f157m&dl=1')
df_ezl = pd.read_csv('https://www.dropbox.com/scl/fi/vizzmmz5u1mhhxignbwei/NBT19MTT2b_od__EZL_tb_wf.csv?rlkey=nz69dj4n7x02389gl7gc95knw&dl=1')
df_lo = pd.read_csv('https://www.dropbox.com/scl/fi/rhofj793lzlh6ptheo0ui/NBT19MTT2b_od__LO_tb_wf.csv?rlkey=btj1o5i02dx9paqhpkhk1chlo&dl=1')
df_lu = pd.read_csv('https://www.dropbox.com/scl/fi/572yutkebg3pa4pjn42d9/NBT19MTT2b_od__LU_tb_wf.csv?rlkey=0rfklc4u7nxcwbtsjsko0i3xd&dl=1')

files = [df_dlr, df_ezl, df_lo, df_lu]
london_OD = pd.concat(files, ignore_index=True)

# %%
london_OD
# Out:
#        mode_mnlc_o  mode_mnlc_d          2         3        4        5  \
# 0              504          523    8.03300    16.430   24.563   28.555
# 1              504          533   30.71900    40.105   61.571   57.881
# 2              504          538    5.94100    17.238   37.493   43.158
# 3              504          559    5.79500    26.397   27.285   24.065
# 4              504          573   77.78600   113.750  143.938  387.562
# ...            ...          ...        ...       ...      ...      ...
# 62575          884          784   97.99600   538.180  298.849  173.856
# 62576          884          787  115.91900   281.952  149.409  138.607
# 62577          884          788  139.04400   682.340  768.051  504.189
# 62578          884          789  156.23601   481.302  702.600  595.686
# 62579          884          852  283.30700  1191.298  809.155  366.224
#
#              6        7 mode    1    8
# 0       13.023    2.263  DLR  NaN  NaN
# 1       15.573    0.317  DLR  NaN  NaN
# 2       33.890   10.429  DLR  NaN  NaN
# 3       15.213    8.508  DLR  NaN  NaN
# 4      165.776   65.283  DLR  NaN  NaN
# ...        ...      ...  ...  ...  ...
# 62575   51.263   14.653   LU  0.0  0.0
# 62576   64.885   25.433   LU  0.0  0.0
# 62577  345.944  113.663   LU  0.0  0.0
# 62578  317.113   63.273   LU  0.0  0.0
# 62579  177.616   34.625   LU  0.0  0.0
#
# [62580 rows x 11 columns]

# %%
definition_df = pd.read_excel('https://www.dropbox.com/scl/fi/8rvd82qd4ald2yyt2bz6m/NBT19_Definitions.xlsx?rlkey=5jcia5kufnlmictzcs9nc2qia&dl=1', 'Stations')

# %%
definition_df
# Out:
#        MNLC  MASC                  StationName  TFL?
# 0     500.0  ACTu                   Acton Town  True
# 1     501.0  BARu                     Barbican  True
# 2     502.0  ALDu                      Aldgate  True
# 3     503.0  ALEu                 Aldgate East  True
# 4     504.0  STId  Stratford International DLR  True
# ..      ...   ...                          ...   ...
# 732  9445.0  BCJt     Beckenham Junction Trams  True
# 733  9460.0  CSTt                Church Street  True
# 734  9471.0  ELMt                   Elmers End  True
# 735  9473.0  GSTt                George Street  True
# 736  9484.0  NADt                New Addington  True
#
# [737 rows x 4 columns]

# %%
#we will drop any missing values from our dataframe
definition_df.dropna(inplace=True)

#transform mnlc codes from floats to int
definition_df.MNLC = definition_df.MNLC.astype(int)

# %%
#add the station names
london_OD['station_origin'] = london_OD['mode_mnlc_o'].apply(lambda x: definition_df[definition_df.MNLC==x]['StationName'].values[0])
london_OD['station_destination'] = london_OD['mode_mnlc_d'].apply(lambda x: definition_df[definition_df.MNLC==x]['StationName'].values[0])

# %%
london_OD.head()
# Out:
#    mode_mnlc_o  mode_mnlc_d       2        3        4        5        6  \
# 0          504          523   8.033   16.430   24.563   28.555   13.023
# 1          504          533  30.719   40.105   61.571   57.881   15.573
# 2          504          538   5.941   17.238   37.493   43.158   33.890
# 3          504          559   5.795   26.397   27.285   24.065   15.213
# 4          504          573  77.786  113.750  143.938  387.562  165.776
#
#         7 mode   1   8               station_origin  station_destination
# 0   2.263  DLR NaN NaN  Stratford International DLR        King George V
# 1   0.317  DLR NaN NaN  Stratford International DLR  London City Airport
# 2  10.429  DLR NaN NaN  Stratford International DLR         Pontoon Dock
# 3   8.508  DLR NaN NaN  Stratford International DLR      West Silvertown
# 4  65.283  DLR NaN NaN  Stratford International DLR     Woolwich Arsenal

# %%
# we will only keep passenger flows for the timeband we are interested in
london_OD_AMpeak = london_OD[['station_origin', 'station_destination', '3']].copy()

# %%
#rename column
london_OD_AMpeak.rename({'3':'flows'}, axis=1, inplace=True)

#since the flows are averages the are stored as flows.
#for our analysis we will turn the into ints
london_OD_AMpeak.flows = london_OD_AMpeak.flows.astype(int)

# %%
london_OD_AMpeak
# Out:
#                     station_origin  station_destination  flows
# 0      Stratford International DLR        King George V     16
# 1      Stratford International DLR  London City Airport     40
# 2      Stratford International DLR         Pontoon Dock     17
# 3      Stratford International DLR      West Silvertown     26
# 4      Stratford International DLR     Woolwich Arsenal    113
# ...                            ...                  ...    ...
# 62575                 Canning Town            Southwark    538
# 62576                 Canning Town           Bermondsey    281
# 62577                 Canning Town         Canada Water    682
# 62578                 Canning Town      North Greenwich    481
# 62579                 Canning Town      Canary Wharf LU   1191
#
# [62580 rows x 3 columns]

# %%
station_origin = list(london_OD_AMpeak.station_origin.values)
station_destination = list(london_OD_AMpeak.station_destination.values)
all_stations = list(set(station_origin + station_destination))
all_stations = sorted(all_stations, key=str.lower)

# %%
london_OD_AMpeak['station_origin']= london_OD_AMpeak.station_origin.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )
london_OD_AMpeak['station_destination']=london_OD_AMpeak.station_destination.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )

# %%
london_OD_AMpeak
# Out:
#                 station_origin  station_destination  flows
# 0      Stratford International        King George V     16
# 1      Stratford International  London City Airport     40
# 2      Stratford International         Pontoon Dock     17
# 3      Stratford International      West Silvertown     26
# 4      Stratford International     Woolwich Arsenal    113
# ...                        ...                  ...    ...
# 62575             Canning Town            Southwark    538
# 62576             Canning Town           Bermondsey    281
# 62577             Canning Town         Canada Water    682
# 62578             Canning Town      North Greenwich    481
# 62579             Canning Town         Canary Wharf   1191
#
# [62580 rows x 3 columns]

# %%
#group by origin and destination station and sum the flows
london_OD_AMpeak = london_OD_AMpeak.groupby(['station_origin', 'station_destination'], as_index=False).sum()

# %%
london_OD_AMpeak
# Out:
#          station_origin station_destination  flows
# 0            Abbey Road   Bank and Monument      0
# 1            Abbey Road             Beckton      1
# 2            Abbey Road           Blackwall      3
# 3            Abbey Road        Canary Wharf      1
# 4            Abbey Road        Canning Town     37
# ...                 ...                 ...    ...
# 61523  Woolwich Arsenal       Tower Gateway    127
# 61524  Woolwich Arsenal            West Ham    608
# 61525  Woolwich Arsenal     West India Quay      6
# 61526  Woolwich Arsenal     West Silvertown     81
# 61527  Woolwich Arsenal           Westferry     76
#
# [61528 rows x 3 columns]

# %%
#let's sanity check and see the highest and lowest flows in and out flows
outflows = london_OD_AMpeak.groupby('station_origin', as_index=False).sum()
#let's sanity check and see the highest and lowest flows in and out flows
inflows = london_OD_AMpeak.groupby('station_destination', as_index=False).sum()

# %% [markdown]
# ### Load London Underground shapefile data

# %%
#read in the data using geopandas
stations = gpd.read_file('https://www.dropbox.com/scl/fi/j1ugr3bsub9jhp8b0btkq/tfl_stations.json?rlkey=r38t2xn9n5erc1y3jzub6tqol&dl=1')
lines = gpd.read_file('https://www.dropbox.com/scl/fi/ov98qi02qju6kcq5vxnbb/tfl_lines.json?rlkey=h9wip7f1drqn4prgf0fhkcvna&dl=1')

# %%
#project data to British National Grid
#we do this so we can work in meters
stations = stations.to_crs(epsg = 27700)
lines = lines.to_crs(epsg = 27700)

# %% [markdown]
# ### Clean station names
#
# We have multiple points representing one station (for example Paddington has seperate points for different entrances). We will simplify this by using RegEx make the names consistent.
#
# Once we have cleaned the names we can set the coordinate of these stations to the mean values of the coordinates of all the stations with the same name.

# %%
#get all station names
station_names = {row.id: row['name'] for i, row in stations.iterrows()}

#clean station names
for k, v in station_names.items():
    if k == 'none':
        continue
    cleaned_name = re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', v)
    
    #note that bank and monument are enconded as one station in our TFL data, so we will do the same
    if cleaned_name in ['Bank', 'Monument']:
        cleaned_name = 'Bank and Monument'
    station_names[k] = cleaned_name
    
stations['name'] = stations['id'].apply(lambda x: station_names[x])

#stations[['name','id']].groupby('name').count().sort_values(by='id',ascending=False)

# %% [markdown]
# **Change position of station to mean of all station with the same name**

# %%
#get position of stations as mean of x, y of stations

#create empty dict to store list of coordinates
pos = {}

#iterate through the stations
for i, station in stations.iterrows():
    xy = station.geometry.coords[0]
    
    #if station already in dict add coordinate to coordinate list
    if station['name'] in pos.keys():
        pos[station['name']].extend([xy])
    #if station is not in the dict add station to dict and set first coordinate in list
    else:
        pos[station['name']] = [xy]

#iterate through our dict and replace coordinate list with mean value
for k, v in pos.items():
    #we set axis to 0 to make sure to take mean of x and y coordinates
    pos[k] = np.mean(v, axis=0)

# %%
#set new geometry
stations['geometry'] = stations['name'].apply(lambda x: Point(pos[x]))

# %% [markdown]
# ### Lines file

# %%
#get all line types as a list and subset geoms by lines
line_names  = lines.lines.apply(lambda x: [x['name'] for x in json.loads(x)] )
line_names = list(set([item for sublist in line_names for item in sublist]))

# %%
#We can see that east london line is incomplete
#digging into this however we notice that it's because east london is actually part of the overground
#merge East London line and London Overground since they are one line
lines.lines = lines.lines.str.replace('East London', 'London Overground')
stations.lines = stations.lines.str.replace('East London', 'London Overground')

# %%
#Our TFL data doesn't include tramlink, emirates air lines, and crossrail is still in construction (except not really)
#exclude the lines that we are not going to use
excluded_lines = ['Thameslink 6tph line', 'East London', 'Crossrail 2', 'Emirates Air Line', 'Crossrail', 'Tramlink']

# %% [markdown]
# ## Create seperate graphs for each line and then join
#
# Since we don't have properly constructed line geometries because:
# * there are discontinuities in the line geometries
# * a line between two stations can actually be composed of more than one geometry
#
# We will construct geometric graphs (meaning graphs just from the line geometries where nodes are coordinates that define the line geometry). It's easy to fix the discontinuities in this manner because the can be thought of as nodes with degree = 1 that have another node with degree = 1 within a threshold distance.
#
# Once we have these discontinuties fixed we can use these geometric graphs to construct proper geometries between stations by taking the shortest paths within these networks starting from the node closest to the origin station and ending in the node closest to the destination station. The shortest path will then be a list of coordinates that define the line geometry between the two stations.

# %%
#create an empty dict to hold our geometric graphs
geometric_graphs = {}

#iterate through each line individually
for line_name in line_names:
    #skip lines that we won't be using
    if line_name in excluded_lines :
        continue
    print(line_name)
    
    #subset our line and station files for the ones the belong to a specific line
    temp_lines = lines[lines.lines.str.contains(line_name)]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #create empty graph
    G= nx.Graph()
    
    #iterate through our line geometries
    for i, line in temp_lines.iterrows():
        #get list of coordinates that define our line
        _l = list(line.geometry.coords)

        #add coordinates as edges
        G.add_edges_from(list(zip(_l,_l[1:])))
    
    #remove any self loops
    G.remove_edges_from(nx.selfloop_edges(G))
    
    #the position of the node is the name of the node
    #let's extract this to plot our graph
    pos = {n: n for n in G.nodes()}
    
    # get degree one nodes
    D = nx.degree(G)
    k1 = [node for node,degree in D if degree==1]
    #let's plot our graph and all degree one nodes
    nx.draw(G, pos=pos, node_size=0.5, node_color='grey')
    nx.draw_networkx_nodes(G, pos=pos, nodelist=k1, node_color='red', node_size=8)
    plt.show()
    
    #get distance between all points of 1-degree, this will be a matrix
    dist = distance.cdist(k1, k1)
    
    #add edges between points that are close
    for j in range(dist.shape[0]-1):
        temp = dist[j][j+1:]
        #get index of closest node
        i_min = np.argmin(temp)
        if dist[j][i_min+j+1]<50:
            G.add_edge(k1[j],k1[i_min+j+1])
    
    #recalculate degree
    D = nx.degree(G)
    k1 = [node for node,degree in D if degree==1]
    #plot new graph
    nx.draw(G, pos=pos, node_size=0.5, node_color='grey')
    nx.draw_networkx_nodes(G, pos=pos, nodelist=k1, node_color='red', node_size=8)
    plt.show()
    print(nx.number_connected_components(G))
    #store graph in dictionary
    geometric_graphs[line_name] = G
# Out:
# London Overground
# 3
# DLR
# 1
# Jubilee
# 1
# Metropolitan
# 1
# Circle
# 1
# Hammersmith & City
# 1
# District
# 1
# Piccadilly
# 1
# Central
# 1
# Bakerloo
# 1
# Waterloo & City
# 1
# TfL Rail
# 1
# Victoria
# 1
# Northern
# 1

# %% [markdown]
# Now that we have these geometric graphs we can create our final graph by using the data in the lines attribute in our lines geodataframe that contains origin and destination station. We can then use our geometric graph and find the shortest route to create our line geometries and find the length of the lines.
#
# We will store this information in a dataframe that we can use to create our final graph

# %%
#create a dataframe with all geometries from all valid lines
#this list will contain a dictionary for each edge in our graph that contains
# node pairs, line name, and a geometry (this is just for quick visualization purposes and will be replaced by true geometry)
edge_list = []
def _has_ids(k):
    #helper function to check if line contains id of start and end station
    if ('start_sid' in k.keys()) and ('end_sid' in k.keys()):
        return True
    else:
        return False

#iterate through each line seperately 
for line_name in line_names:
    if line_name in excluded_lines :
        continue
        
    #subset lines and stations
    temp_lines = lines[lines.lines.str.contains(line_name)]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #for each line in our subset dataframe get each origin and destination pair
    for i, line in temp_lines.iterrows():
        for k in json.loads(line.lines):
            if k['name'] == line_name:
                if _has_ids(k):
                    #get start and end station ids
                    start_id = k['start_sid']
                    end_id = k['end_sid']

                    #get info of start and end station
                    start_station = temp_stations[(temp_stations.id == start_id) | (temp_stations.altmodeid == start_id)].values
                    end_station = temp_stations[(temp_stations.id == end_id) | (temp_stations.altmodeid == end_id)].values
                    
                    #if no matching station exist, let's just take the starting and ending coordinate of the line for now
                    if len(start_station) >= 1 and len(end_station) >=1:
                        s_geom = start_station[0][-1].coords[0]
                        e_geom = end_station[0][-1].coords[0]
                        edge_list.append({
                            'line_name': line_name,
                            'start_id': start_id,
                            'end_id': end_id,
                            'geometry': LineString([s_geom, e_geom])
                        })

# %%
#turn our dictionary list into a geopandas df to quickly plot and sanity check our work
edge_gdf = gpd.GeoDataFrame(edge_list)
edge_gdf.crs = lines.crs

# %%
edge_gdf
# Out:
#              line_name     start_id       end_id  \
# 0    London Overground   910GCAMHTH  910GBTHNLGR
# 1    London Overground   910GCAMHTH  910GLONFLDS
# 2    London Overground  910GLONFLDS  910GHAKNYNM
# 3    London Overground  910GHAKNYNM  910GRCTRYRD
# 4    London Overground  910GRCTRYRD  910GSTKNWNG
# ..                 ...          ...          ...
# 631           Northern  940GZZLUTCR  940GZZLULSQ
# 632           Northern  940GZZLULSQ  940GZZLUCHX
# 633           Northern  940GZZLUWLO  940GZZLUKNG
# 634           Northern  940GZZLU991  940GZZLU990
# 635           Northern  940GZZLU990  940GZZLUKNG
#
#                                               geometry
# 0    LINESTRING (534826.877 183290.997, 534856.070 ...
# 1    LINESTRING (534826.877 183290.997, 534782.941 ...
# 2    LINESTRING (534782.941 184260.470, 534531.043 ...
# 3    LINESTRING (534531.043 185134.568, 533997.280 ...
# 4    LINESTRING (533997.280 186185.005, 533682.473 ...
# ..                                                 ...
# 631  LINESTRING (529781.482 181328.939, 529970.022 ...
# 632  LINESTRING (529970.022 180803.970, 530059.341 ...
# 633  LINESTRING (530974.091 179921.099, 531626.075 ...
# 634  LINESTRING (529053.258 177243.076, 530049.490 ...
# 635  LINESTRING (530049.490 177348.742, 531626.075 ...
#
# [636 rows x 4 columns]

# %%
### Add geometry information back into the graph
for line_name in line_names:
    if line_name in excluded_lines :
        continue
    temp_lines = edge_gdf[edge_gdf.line_name == line_name]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #let's plot our lines so we can check them
    fig, ax = plt.subplots(figsize = (7,7))
    fig.suptitle(f'line: {line_name}')
    ax.set_aspect("equal")
    ax.axis('off')
    ax.margins(0.1)
    
    base = temp_lines.plot(ax=ax, color='grey')
    temp_stations.plot(ax=base, markersize=20, color='red')
    plt.show()
    
    #add real geometry back
    for i, edge in temp_lines.iterrows():
        #get start and end of line coordinates
        start = edge.geometry.coords[0]
        end = edge.geometry.coords[-1]
        
        #let's get all the coordinates in our geometric graph
        nodes = list(geometric_graphs[line_name].nodes)
        
        #find nearest node in graph to origin and destination
        s_dist = distance.cdist([start], nodes)[0]
        s_i = np.argmin(s_dist)
        source= nodes[s_i]
        
        t_dist = distance.cdist([end], nodes)[0]
        t_i = np.argmin(t_dist)
        target= nodes[t_i]
        
        #get shortest path
        sp = nx.shortest_path(geometric_graphs[line_name], source, target)
        
        #make into geometry
        #notice how I'm also adding the start and end coordinates to the line definition
        #this fixes the problem of stations and lines not matching up
        geometry = LineString([start] + sp + [end])
        edge_gdf.loc[i, 'geometry'] = geometry

# %%
#let's store the length of the real geometry
edge_gdf['length'] = edge_gdf.geometry.length

# %%
edge_gdf.head(2)
# Out:
#            line_name    start_id       end_id  \
# 0  London Overground  910GCAMHTH  910GBTHNLGR
# 1  London Overground  910GCAMHTH  910GLONFLDS
#
#                                             geometry      length
# 0  LINESTRING (534826.877 183290.997, 534827.512 ...  831.871588
# 1  LINESTRING (534826.877 183290.997, 534827.512 ...  979.416986

# %%
edge_gdf.sample(1).plot()
# Out:
# <Axes: >

# %%
#let's replace the ids with the actual name
#get all station names
station_names_2 = {row.altmodeid: row['name'] for i, row in stations.iterrows() if row.altmodeid != None}
station_names.update(station_names_2)

# %%
edge_gdf['start_id'] = edge_gdf['start_id'].apply(lambda x: station_names[x])
edge_gdf['end_id'] = edge_gdf['end_id'].apply(lambda x: station_names[x])

# %%
edge_gdf
# Out:
#              line_name                 start_id            end_id  \
# 0    London Overground          Cambridge Heath     Bethnal Green
# 1    London Overground          Cambridge Heath     London Fields
# 2    London Overground            London Fields     Hackney Downs
# 3    London Overground            Hackney Downs      Rectory Road
# 4    London Overground             Rectory Road   Stoke Newington
# ..                 ...                      ...               ...
# 631           Northern     Tottenham Court Road  Leicester Square
# 632           Northern         Leicester Square     Charing Cross
# 633           Northern                 Waterloo        Kennington
# 634           Northern  Battersea Power Station         Nine Elms
# 635           Northern                Nine Elms        Kennington
#
#                                               geometry       length
# 0    LINESTRING (534826.877 183290.997, 534827.512 ...   831.871588
# 1    LINESTRING (534826.877 183290.997, 534827.512 ...   979.416986
# 2    LINESTRING (534782.941 184260.470, 534782.678 ...   926.012712
# 3    LINESTRING (534531.043 185134.568, 534531.871 ...  1201.022377
# 4    LINESTRING (533997.280 186185.005, 533998.001 ...   783.255714
# ..                                                 ...          ...
# 631  LINESTRING (529781.482 181328.939, 529830.781 ...   585.940371
# 632  LINESTRING (529970.022 180803.970, 529970.059 ...   462.074817
# 633  LINESTRING (530974.091 179921.099, 530974.644 ...  1760.198517
# 634  LINESTRING (529053.258 177243.076, 529053.258 ...  1073.465362
# 635  LINESTRING (530049.490 177348.742, 530049.489 ...  2030.621843
#
# [636 rows x 5 columns]

# %% [markdown]
# ## IMPORTANT!!!

# %%
#now we can use this to create our network!
G = nx.from_pandas_edgelist(edge_gdf, source = 'start_id', target='end_id', edge_attr=['length', 'line_name'])

#let's plot
#notice that even though we created the real geometries, the graph still plots just straight line
#this is because networkx doesn't have a concept of a edge geometry
#however this is ok, since we only need the distance as weights, and that is already an attribute in our graph
pos = {row['name']: row.geometry.coords[0] for i, row in stations.iterrows() if row['name'] in G.nodes()}
Gcc = nx.connected_components(G)
for n in Gcc:
    G_sub = G.subgraph(n)
    lines = [data['line_name'] for u,v, data in G_sub.edges(data=True)]
    print(set(lines))
    nx.draw(G_sub, pos, node_size=4)
    plt.show()

#save position to graph
nx.set_node_attributes(G, pos, 'coords')
# Out:
# {'TfL Rail', 'Piccadilly', 'Northern', 'Metropolitan', 'Circle', 'Victoria', 'London Overground', 'Central', 'Hammersmith & City', 'Bakerloo', 'DLR', 'District', 'Waterloo & City', 'Jubilee'}

# %% [markdown]
# ### Sanity check our network

# %%
#check that all distances are greater or equal to euclidean distance
for u,v, data in G.edges(data=True):
    assert(data['length'] >= distance.euclidean(pos[u], pos[v]))

# %%
#if want to know what is the maximum distance between stations
max(dict(G.edges).items(), key=lambda x: x[1]['length'])
# Out:
# (('Wembley Park', 'Finchley Road'),
#  {'length': 7266.373927496486, 'line_name': 'Metropolitan'})

# %%
#if want to know to which stations Baker Street is directly connected to
Baker_Street = [(u,v) for  u,v in G.edges() if u == 'Baker Street' or v == 'Baker Street']
Baker_Street
# Out:
# [('Bond Street', 'Baker Street'),
#  ('Baker Street', "St. John's Wood"),
#  ('Baker Street', 'Great Portland Street'),
#  ('Baker Street', 'Finchley Road'),
#  ('Baker Street', 'Edgware Road'),
#  ('Baker Street', 'Marylebone'),
#  ('Baker Street', "Regent's Park")]

# %%
#We can also check the degree of the nodes in our network and check that they make sense
deg_london = nx.degree(G)

# %%
df = pd.DataFrame(index = dict(deg_london).keys())
df['degree'] = dict(deg_london).values()

# %%
df.sort_values('degree', ascending = False).head(20)
# Out:
#                           degree
# Stratford                      9
# Bank and Monument              8
# Baker Street                   7
# King's Cross St. Pancras       7
# Liverpool Street               6
# West Ham                       6
# Canning Town                   6
# Oxford Circus                  6
# Green Park                     6
# Earl's Court                   6
# Waterloo                       6
# Turnham Green                  5
# Willesden Junction             5
# Shadwell                       5
# Euston                         5
# Westminster                    4
# Camden Town                    4
# Bond Street                    4
# Hammersmith                    4
# Finchley Road                  4

# %% [markdown]
# ### Merge Network with OD data
#
# ok, we are almost done!
#
# We have processed our raw data, now we need to combine the two (TLF OD and our Network). For this we need two types of merge:
#
# 1. add flows as weights to the network (to be able to calculate disruptions to the network)
# 2. create OD with distance for our spatial interaction models (for our spatial interaction models)

# %%
#check that our OD data and network data match
OD_names = set(london_OD_AMpeak.station_origin.unique())
network_names = set([n for n in G.nodes()])

# %%
OD_names
# Out:
# {'Abbey Road',
#  'Acton Central',
#  'Acton Main Line',
#  'Acton Town',
#  'Aldgate',
#  'Aldgate East',
#  'All Saints',
#  'Alperton',
#  'Amersham',
#  'Anerley',
#  'Angel',
#  'Archway',
#  'Arnos Grove',
#  'Arsenal',
#  'Baker Street',
#  'Balham',
#  'Bank and Monument',
#  'Barbican',
#  'Barking',
#  'Barkingside',
#  'Barons Court',
#  'Battersea Park',
#  'Bayswater',
#  'Beckton',
#  'Beckton Park',
#  'Becontree',
#  'Belsize Park',
#  'Bermondsey',
#  'Bethnal Green',
#  'Blackfriars',
#  'Blackhorse Road',
#  'Blackwall',
#  'Bond Street',
#  'Borough',
#  'Boston Manor',
#  'Bounds Green',
#  'Bow Church',
#  'Bow Road',
#  'Brent Cross',
#  'Brentwood',
#  'Brixton',
#  'Brockley',
#  'Bromley-by-Bow',
#  'Brondesbury',
#  'Brondesbury Park',
#  'Bruce Grove',
#  'Buckhurst Hill',
#  'Burnt Oak',
#  'Bush Hill Park',
#  'Bushey',
#  'Caledonian Road',
#  'Caledonian Road & Barnsbury',
#  'Cambridge Heath',
#  'Camden Road',
#  'Camden Town',
#  'Canada Water',
#  'Canary Wharf',
#  'Canning Town',
#  'Cannon Street',
#  'Canonbury',
#  'Canons Park',
#  'Carpenders Park',
#  'Chadwell Heath',
#  'Chalfont & Latimer',
#  'Chalk Farm',
#  'Chancery Lane',
#  'Charing Cross',
#  'Chesham',
#  'Cheshunt',
#  'Chigwell',
#  'Chingford',
#  'Chiswick Park',
#  'Chorleywood',
#  'Clapham Common',
#  'Clapham High Street',
#  'Clapham Junction',
#  'Clapham North',
#  'Clapham South',
#  'Clapton',
#  'Cockfosters',
#  'Colindale',
#  'Colliers Wood',
#  'Covent Garden',
#  'Crossharbour',
#  'Crouch Hill',
#  'Croxley',
#  'Crystal Palace',
#  'Custom House',
#  'Cutty Sark',
#  'Cyprus',
#  'Dagenham East',
#  'Dagenham Heathway',
#  'Dalston Junction',
#  'Dalston Kingsland',
#  'Debden',
#  'Denmark Hill',
#  'Deptford Bridge',
#  'Devons Road',
#  'Dollis Hill',
#  'Ealing Broadway',
#  'Ealing Common',
#  "Earl's Court",
#  'East Acton',
#  'East Finchley',
#  'East Ham',
#  'East India',
#  'East Putney',
#  'Eastcote',
#  'Edgware',
#  'Edgware Road',
#  'Edmonton Green',
#  'Elephant & Castle',
#  'Elm Park',
#  'Elverson Road',
#  'Embankment',
#  'Emerson Park',
#  'Enfield Town',
#  'Epping',
#  'Euston',
#  'Euston Square',
#  'Fairlop',
#  'Farringdon',
#  'Finchley Central',
#  'Finchley Road',
#  'Finchley Road & Frognal',
#  'Finsbury Park',
#  'Forest Gate',
#  'Forest Hill',
#  'Fulham Broadway',
#  'Gallions Reach',
#  'Gants Hill',
#  'Gidea Park',
#  'Gloucester Road',
#  'Golders Green',
#  'Goldhawk Road',
#  'Goodge Street',
#  'Goodmayes',
#  'Gospel Oak',
#  'Grange Hill',
#  'Great Portland Street',
#  'Green Park',
#  'Greenford',
#  'Greenwich',
#  'Gunnersbury',
#  'Hackney Central',
#  'Hackney Downs',
#  'Hackney Wick',
#  'Haggerston',
#  'Hainault',
#  'Hammersmith',
#  'Hampstead',
#  'Hampstead Heath',
#  'Hanger Lane',
#  'Hanwell',
#  'Harlesden',
#  'Harold Wood',
#  'Harringay Green Lanes',
#  'Harrow & Wealdstone',
#  'Harrow-on-the-Hill',
#  'Hatch End',
#  'Hatton Cross',
#  'Hayes & Harlington',
#  'Headstone Lane',
#  'Heathrow Terminal 4',
#  'Heathrow Terminal 4 EL',
#  'Heathrow Terminal 5',
#  'Heathrow Terminals 123',
#  'Heathrow Terminals 2 & 3 EL',
#  'Hendon Central',
#  'Heron Quays',
#  'High Barnet',
#  'High Street Kensington',
#  'Highams Park',
#  'Highbury & Islington',
#  'Highgate',
#  'Hillingdon',
#  'Holborn',
#  'Holland Park',
#  'Holloway Road',
#  'Homerton',
#  'Honor Oak Park',
#  'Hornchurch',
#  'Hounslow Central',
#  'Hounslow East',
#  'Hounslow West',
#  'Hoxton',
#  'Hyde Park Corner',
#  'Ickenham',
#  'Ilford',
#  'Imperial Wharf',
#  'Island Gardens',
#  'Kennington',
#  'Kensal Green',
#  'Kensal Rise',
#  'Kensington',
#  'Kentish Town',
#  'Kentish Town West',
#  'Kenton',
#  'Kew Gardens',
#  'Kilburn',
#  'Kilburn High Road',
#  'Kilburn Park',
#  'King George V',
#  "King's Cross St. Pancras",
#  'Kingsbury',
#  'Knightsbridge',
#  'Ladbroke Grove',
#  'Lambeth North',
#  'Lancaster Gate',
#  'Langdon Park',
#  'Latimer Road',
#  'Leicester Square',
#  'Lewisham',
#  'Leyton',
#  'Leyton Midland Road',
#  'Leytonstone',
#  'Leytonstone High Road',
#  'Limehouse',
#  'Liverpool Street',
#  'London Bridge',
#  'London City Airport',
#  'London Fields',
#  'Loughton',
#  'Maida Vale',
#  'Manor House',
#  'Manor Park',
#  'Mansion House',
#  'Marble Arch',
#  'Maryland',
#  'Marylebone',
#  'Mile End',
#  'Mill Hill East',
#  'Moor Park',
#  'Moorgate',
#  'Morden',
#  'Mornington Crescent',
#  'Mudchute',
#  'Neasden',
#  'New Cross',
#  'New Cross Gate',
#  'Newbury Park',
#  'North Acton',
#  'North Ealing',
#  'North Greenwich',
#  'North Harrow',
#  'North Wembley',
#  'Northfields',
#  'Northolt',
#  'Northwick Park',
#  'Northwood',
#  'Northwood Hills',
#  'Norwood Junction',
#  'Notting Hill Gate',
#  'Oakwood',
#  'Old Street',
#  'Osterley',
#  'Oval',
#  'Oxford Circus',
#  'Paddington',
#  'Park Royal',
#  'Parsons Green',
#  'Peckham Rye',
#  'Penge West',
#  'Perivale',
#  'Piccadilly Circus',
#  'Pimlico',
#  'Pinner',
#  'Plaistow',
#  'Pontoon Dock',
#  'Poplar',
#  'Preston Road',
#  'Prince Regent',
#  'Pudding Mill Lane',
#  'Putney Bridge',
#  "Queen's Park",
#  'Queens Road Peckham',
#  'Queensbury',
#  'Queensway',
#  'Ravenscourt Park',
#  'Rayners Lane',
#  'Rectory Road',
#  'Redbridge',
#  "Regent's Park",
#  'Richmond',
#  'Rickmansworth',
#  'Roding Valley',
#  'Romford',
#  'Rotherhithe',
#  'Royal Albert',
#  'Royal Oak',
#  'Royal Victoria',
#  'Ruislip',
#  'Ruislip Gardens',
#  'Ruislip Manor',
#  'Russell Square',
#  'Seven Kings',
#  'Seven Sisters',
#  'Shadwell',
#  'Shenfield',
#  "Shepherd's Bush",
#  "Shepherd's Bush Market",
#  'Shoreditch High Street',
#  'Silver Street',
#  'Sloane Square',
#  'Snaresbrook',
#  'South Acton',
#  'South Ealing',
#  'South Hampstead',
#  'South Harrow',
#  'South Kensington',
#  'South Kenton',
#  'South Quay',
#  'South Ruislip',
#  'South Tottenham',
#  'South Wimbledon',
#  'South Woodford',
#  'Southall',
#  'Southbury',
#  'Southfields',
#  'Southgate',
#  'Southwark',
#  'St James Street',
#  "St. James's Park",
#  "St. John's Wood",
#  "St. Paul's",
#  'Stamford Brook',
#  'Stamford Hill',
#  'Stanmore',
#  'Star Lane',
#  'Stepney Green',
#  'Stockwell',
#  'Stoke Newington',
#  'Stonebridge Park',
#  'Stratford',
#  'Stratford High Street',
#  'Stratford International',
#  'Sudbury Hill',
#  'Sudbury Town',
#  'Surrey Quays',
#  'Swiss Cottage',
#  'Sydenham',
#  'Temple',
#  'Theobalds Grove',
#  'Theydon Bois',
#  'Tooting Bec',
#  'Tooting Broadway',
#  'Tottenham Court Road',
#  'Tottenham Hale',
#  'Totteridge & Whetstone',
#  'Tower Gateway',
#  'Tower Hill',
#  'Tufnell Park',
#  'Turkey Street',
#  'Turnham Green',
#  'Turnpike Lane',
#  'Upminster',
#  'Upminster Bridge',
#  'Upney',
#  'Upper Holloway',
#  'Upton Park',
#  'Uxbridge',
#  'Vauxhall',
#  'Victoria',
#  'Walthamstow Central',
#  "Walthamstow Queen's Road",
#  'Wandsworth Road',
#  'Wanstead',
#  'Wanstead Park',
#  'Wapping',
#  'Warren Street',
#  'Warwick Avenue',
#  'Waterloo',
#  'Watford',
#  'Watford High Street',
#  'Watford Junction',
#  'Wembley Central',
#  'Wembley Park',
#  'West Acton',
#  'West Brompton',
#  'West Croydon',
#  'West Ealing',
#  'West Finchley',
#  'West Ham',
#  'West Hampstead',
#  'West Harrow',
#  'West India Quay',
#  'West Kensington',
#  'West Ruislip',
#  'West Silvertown',
#  'Westbourne Park',
#  'Westferry',
#  'Westminster',
#  'White City',
#  'White Hart Lane',
#  'Whitechapel',
#  'Willesden Green',
#  'Willesden Junction',
#  'Wimbledon',
#  'Wimbledon Park',
#  'Wood Green',
#  'Wood Lane',
#  'Wood Street',
#  'Woodford',
#  'Woodgrange Park',
#  'Woodside Park',
#  'Woolwich Arsenal'}

# %% [markdown]
# Ok, we have a few stations that don't match up. They are small enough that we can solve this quickly by creating a mapping between names of the stations that we can keep.
#
# * Battersea power station and Nine Elms data doesn't exist in our TFL data because the station wasn't opened when the data was collected. This was an extension of Northern line that opened recently.
# * Action Main Line, Hanwell, Hayes & Harlington, Southall, and West Ealing are part of crossrail which we are not considering

# %%
name_map = {
    'Heathrow Terminal 4 EL': 'Heathrow Terminal 4',
    'Heathrow Terminals 123': 'Heathrow Terminals 2 & 3',
    'Heathrow Terminals 2 & 3 EL': 'Heathrow Terminals 2 & 3',
    "Walthamstow Queen's Road": 'Walthamstow Queens Road'
}

# %%
london_OD_AMpeak.station_origin = london_OD_AMpeak.station_origin.apply(
    lambda x: name_map[x] if x in name_map.keys() else x
)
london_OD_AMpeak.station_destination = london_OD_AMpeak.station_destination.apply(
    lambda x: name_map[x] if x in name_map.keys() else x
)

# %%
#let's filter out the stations that we don't have in our network
OD_names = set(london_OD_AMpeak.station_origin.unique())
_filter = list(network_names.symmetric_difference(OD_names))
_filter
# Out:
# ['Acton Main Line',
#  'West Ealing',
#  'Southall',
#  'Hayes & Harlington',
#  'Battersea Power Station',
#  'Nine Elms',
#  'Hanwell']

# %%
london_OD_AMpeak = london_OD_AMpeak[~london_OD_AMpeak.station_origin.isin(_filter)]
london_OD_AMpeak = london_OD_AMpeak[~london_OD_AMpeak.station_destination.isin(_filter)]

# %% [markdown]
# **Add flow data to our network**
#
# Our TFL data contains flows for OD pairs, but we don't know the flows passing through each edge in our network. We will have to calculate this assuming fall people travelling from Origin to Destination station are taking the shortest path within the network.

# %%
#create a dictionary to store flows for all edges
flows = {(u,v): 0 for u,v in G.edges()}

# %%
#calculate shortest paths for all flows and add data to dict
for i, row in london_OD_AMpeak.iterrows():
    source = row.station_origin
    target = row.station_destination
    
    #get shortest path
    path = nx.dijkstra_path(G, source, target)
    
    #our path is a list of nodes, we need to turn this to a list of edges
    path_edges = list(zip(path,path[1:])) 
    
    #add flows to our dict
    for u,v in path_edges:
        try:
            flows[(u,v)] += row.flows
        except:
            flows[(v,u)] += row.flows

# %%
flows
# Out:
# {('Cambridge Heath', 'Bethnal Green'): 13816,
#  ('Cambridge Heath', 'London Fields'): 14266,
#  ('Bethnal Green', 'Liverpool Street'): 31564,
#  ('Bethnal Green', 'Mile End'): 12930,
#  ('London Fields', 'Hackney Downs'): 14238,
#  ('Hackney Downs', 'Rectory Road'): 3890,
#  ('Hackney Downs', 'Clapton'): 10816,
#  ('Rectory Road', 'Stoke Newington'): 3888,
#  ('Stoke Newington', 'Stamford Hill'): 3913,
#  ('Stamford Hill', 'Seven Sisters'): 3814,
#  ('Seven Sisters', 'Bruce Grove'): 12361,
#  ('Seven Sisters', 'Finsbury Park'): 54607,
#  ('Seven Sisters', 'Tottenham Hale'): 33279,
#  ('Bruce Grove', 'White Hart Lane'): 11728,
#  ('White Hart Lane', 'Silver Street'): 10497,
#  ('Silver Street', 'Edmonton Green'): 8985,
#  ('Edmonton Green', 'Southbury'): 2937,
#  ('Edmonton Green', 'Bush Hill Park'): 4062,
#  ('Southbury', 'Turkey Street'): 2083,
#  ('Turkey Street', 'Theobalds Grove'): 934,
#  ('Theobalds Grove', 'Cheshunt'): 287,
#  ('Liverpool Street', 'Aldgate'): 8087,
#  ('Liverpool Street', 'Moorgate'): 46909,
#  ('Liverpool Street', 'Aldgate East'): 8178,
#  ('Liverpool Street', 'Bank and Monument'): 149143,
#  ('Liverpool Street', 'Stratford'): 145962,
#  ('Enfield Town', 'Bush Hill Park'): 2552,
#  ('Romford', 'Emerson Park'): 1184,
#  ('Romford', 'Chadwell Heath'): 14919,
#  ('Romford', 'Gidea Park'): 8884,
#  ('Emerson Park', 'Upminster'): 1211,
#  ('Upminster', 'Upminster Bridge'): 1330,
#  ('Clapton', 'St James Street'): 10403,
#  ('St James Street', 'Walthamstow Central'): 9581,
#  ('Walthamstow Central', 'Wood Street'): 7003,
#  ('Walthamstow Central', 'Blackhorse Road'): 14986,
#  ('Wood Street', 'Highams Park'): 5510,
#  ('Highams Park', 'Chingford'): 2277,
#  ('Richmond', 'Kew Gardens'): 10554,
#  ('Kew Gardens', 'Gunnersbury'): 12513,
#  ('Gunnersbury', 'South Acton'): 13918,
#  ('Gunnersbury', 'Turnham Green'): 15118,
#  ('South Acton', 'Acton Central'): 14815,
#  ('Harrow & Wealdstone', 'Kenton'): 5132,
#  ('Harrow & Wealdstone', 'Headstone Lane'): 3456,
#  ('Kenton', 'South Kenton'): 5933,
#  ('South Kenton', 'North Wembley'): 6707,
#  ('North Wembley', 'Wembley Central'): 7477,
#  ('Wembley Central', 'Stonebridge Park'): 9134,
#  ('Stonebridge Park', 'Harlesden'): 10125,
#  ('Harlesden', 'Willesden Junction'): 11103,
#  ('Willesden Junction', 'Kensal Green'): 36380,
#  ('Willesden Junction', 'Acton Central'): 15559,
#  ('Willesden Junction', 'Kensal Rise'): 11015,
#  ('Willesden Junction', "Shepherd's Bush"): 26126,
#  ('Kensal Green', "Queen's Park"): 37043,
#  ("Queen's Park", 'Kilburn High Road'): 40037,
#  ("Queen's Park", 'Kilburn Park'): 4642,
#  ('Kilburn High Road', 'South Hampstead'): 40116,
#  ('Kensal Rise', 'Brondesbury Park'): 9892,
#  ('Brondesbury Park', 'Brondesbury'): 10124,
#  ('Brondesbury', 'West Hampstead'): 9755,
#  ('West Hampstead', 'Finchley Road & Frognal'): 7453,
#  ('West Hampstead', 'Kilburn'): 11936,
#  ('West Hampstead', 'Finchley Road'): 23719,
#  ('Finchley Road & Frognal', 'Hampstead Heath'): 7454,
#  ('Hampstead Heath', 'Gospel Oak'): 7183,
#  ('Gospel Oak', 'Kentish Town West'): 5915,
#  ('Gospel Oak', 'Upper Holloway'): 1932,
#  ('Kentish Town West', 'Camden Road'): 4577,
#  ('Camden Road', 'Caledonian Road & Barnsbury'): 7516,
#  ('Caledonian Road & Barnsbury', 'Highbury & Islington'): 9057,
#  ('Highbury & Islington', 'Canonbury'): 23479,
#  ('Highbury & Islington', "King's Cross St. Pancras"): 120053,
#  ('Highbury & Islington', 'Finsbury Park'): 108014,
#  ('Canonbury', 'Dalston Kingsland'): 17743,
#  ('Canonbury', 'Dalston Junction'): 5702,
#  ('Dalston Kingsland', 'Hackney Central'): 16680,
#  ('Hackney Central', 'Homerton'): 15054,
#  ('Homerton', 'Hackney Wick'): 14381,
#  ('Hackney Wick', 'Stratford'): 14051,
#  ('Stratford', 'Stratford High Street'): 1089,
#  ('Stratford', 'Pudding Mill Lane'): 4261,
#  ('Stratford', 'Stratford International'): 3833,
#  ('Stratford', 'West Ham'): 90511,
#  ('Stratford', 'Mile End'): 12008,
#  ('Stratford', 'Leyton'): 56082,
#  ('Stratford', 'Maryland'): 34442,
#  ('Whitechapel', 'Shadwell'): 28908,
#  ('Whitechapel', 'Shoreditch High Street'): 15838,
#  ('Whitechapel', 'Aldgate East'): 4162,
#  ('Whitechapel', 'Stepney Green'): 10824,
#  ('Shadwell', 'Wapping'): 21039,
#  ('Shadwell', 'Bank and Monument'): 22035,
#  ('Shadwell', 'Limehouse'): 11897,
#  ('Shadwell', 'Tower Gateway'): 4195,
#  ('Wapping', 'Rotherhithe'): 21396,
#  ('Rotherhithe', 'Canada Water'): 20868,
#  ('Canada Water', 'Surrey Quays'): 36805,
#  ('Canada Water', 'Canary Wharf'): 74368,
#  ('Canada Water', 'Bermondsey'): 76162,
#  ('Surrey Quays', 'New Cross Gate'): 16779,
#  ('Surrey Quays', 'New Cross'): 2467,
#  ('Surrey Quays', 'Queens Road Peckham'): 14663,
#  ('New Cross Gate', 'Brockley'): 15071,
#  ('Shoreditch High Street', 'Hoxton'): 10622,
#  ('Sydenham', 'Crystal Palace'): 2434,
#  ('Sydenham', 'Forest Hill'): 9134,
#  ('Sydenham', 'Penge West'): 4981,
#  ('Queens Road Peckham', 'Peckham Rye'): 13372,
#  ('Peckham Rye', 'Denmark Hill'): 12869,
#  ('Denmark Hill', 'Clapham High Street'): 13237,
#  ('Clapham High Street', 'Wandsworth Road'): 12577,
#  ('Wandsworth Road', 'Clapham Junction'): 12012,
#  ('Wandsworth Road', 'Battersea Park'): 0,
#  ('Clapham Junction', 'Imperial Wharf'): 13982,
#  ('West Brompton', 'Imperial Wharf'): 14609,
#  ('West Brompton', 'Kensington'): 16163,
#  ('West Brompton', "Earl's Court"): 33978,
#  ('West Brompton', 'Fulham Broadway'): 34820,
#  ('South Hampstead', 'Euston'): 40052,
#  ('Euston', 'Warren Street'): 118799,
#  ('Euston', "King's Cross St. Pancras"): 142551,
#  ('Euston', 'Camden Town'): 73814,
#  ('Euston', 'Mornington Crescent'): 2542,
#  ('Bushey', 'Watford High Street'): 2871,
#  ('Bushey', 'Carpenders Park'): 3311,
#  ('Watford High Street', 'Watford Junction'): 1858,
#  ('Carpenders Park', 'Hatch End'): 3234,
#  ('Hatch End', 'Headstone Lane'): 3223,
#  ('Upper Holloway', 'Crouch Hill'): 2708,
#  ('Crouch Hill', 'Harringay Green Lanes'): 2912,
#  ('Harringay Green Lanes', 'South Tottenham'): 3235,
#  ('South Tottenham', 'Blackhorse Road'): 3631,
#  ('Blackhorse Road', 'Walthamstow Queens Road'): 4832,
#  ('Blackhorse Road', 'Tottenham Hale'): 23117,
#  ('Walthamstow Queens Road', 'Leyton Midland Road'): 5730,
#  ('Leyton Midland Road', 'Leytonstone High Road'): 5411,
#  ('Leytonstone High Road', 'Wanstead Park'): 4835,
#  ('Wanstead Park', 'Woodgrange Park'): 3996,
#  ('Woodgrange Park', 'Barking'): 3386,
#  ('Barking', 'East Ham'): 18028,
#  ('Barking', 'Upney'): 15044,
#  ('Brockley', 'Honor Oak Park'): 12935,
#  ('Honor Oak Park', 'Forest Hill'): 11486,
#  ('Penge West', 'Anerley'): 4685,
#  ('Anerley', 'Norwood Junction'): 4259,
#  ('Norwood Junction', 'West Croydon'): 3380,
#  ('Dalston Junction', 'Haggerston'): 8145,
#  ('Haggerston', 'Hoxton'): 9064,
#  ('Kensington', "Shepherd's Bush"): 30388,
#  ('Kensington', "Earl's Court"): 14637,
#  ("Shepherd's Bush", 'White City'): 31767,
#  ("Shepherd's Bush", 'Holland Park'): 14148,
#  ('Stratford High Street', 'Abbey Road'): 1206,
#  ('Abbey Road', 'West Ham'): 996,
#  ('West Ham', 'Star Lane'): 1038,
#  ('West Ham', 'Canning Town'): 59947,
#  ('West Ham', 'Bromley-by-Bow'): 4266,
#  ('West Ham', 'Plaistow'): 33714,
#  ('Star Lane', 'Canning Town'): 452,
#  ('Canning Town', 'Royal Victoria'): 11357,
#  ('Canning Town', 'East India'): 5502,
#  ('Canning Town', 'West Silvertown'): 20147,
#  ('Canning Town', 'North Greenwich'): 31846,
#  ('Royal Victoria', 'Custom House'): 8797,
#  ('Bank and Monument', 'Cannon Street'): 21169,
#  ('Bank and Monument', 'Tower Hill'): 22620,
#  ('Bank and Monument', "St. Paul's"): 38009,
#  ('Bank and Monument', 'Waterloo'): 213941,
#  ('Bank and Monument', 'Moorgate'): 78617,
#  ('Bank and Monument', 'London Bridge'): 48427,
#  ('Limehouse', 'Westferry'): 12362,
#  ('Westferry', 'West India Quay'): 6368,
#  ('Westferry', 'Poplar'): 4573,
#  ('West India Quay', 'Canary Wharf'): 9717,
#  ('West India Quay', 'Poplar'): 3187,
#  ('Canary Wharf', 'Heron Quays'): 24482,
#  ('Canary Wharf', 'North Greenwich'): 29141,
#  ('Heron Quays', 'South Quay'): 25055,
#  ('South Quay', 'Crossharbour'): 21483,
#  ('Crossharbour', 'Mudchute'): 19821,
#  ('Mudchute', 'Island Gardens'): 18634,
#  ('Island Gardens', 'Cutty Sark'): 17428,
#  ('Cutty Sark', 'Greenwich'): 14480,
#  ('Greenwich', 'Deptford Bridge'): 13695,
#  ('Deptford Bridge', 'Elverson Road'): 11341,
#  ('Elverson Road', 'Lewisham'): 10268,
#  ('Poplar', 'All Saints'): 4189,
#  ('Poplar', 'Blackwall'): 4097,
#  ('All Saints', 'Langdon Park'): 4329,
#  ('Blackwall', 'East India'): 3270,
#  ('Custom House', 'Prince Regent'): 7305,
#  ('Prince Regent', 'Royal Albert'): 5759,
#  ('Royal Albert', 'Beckton Park'): 4511,
#  ('Beckton Park', 'Cyprus'): 4140,
#  ('Cyprus', 'Gallions Reach'): 2802,
#  ('Gallions Reach', 'Beckton'): 1621,
#  ('Langdon Park', 'Devons Road'): 4282,
#  ('Devons Road', 'Bow Church'): 4576,
#  ('Bow Church', 'Pudding Mill Lane'): 3620,
#  ('Woolwich Arsenal', 'King George V'): 12320,
#  ('King George V', 'London City Airport'): 13285,
#  ('West Silvertown', 'Pontoon Dock'): 18747,
#  ('Pontoon Dock', 'London City Airport'): 16218,
#  ('Wembley Park', 'Kingsbury'): 12356,
#  ('Wembley Park', 'Neasden'): 6744,
#  ('Wembley Park', 'Preston Road'): 36608,
#  ('Wembley Park', 'Finchley Road'): 55223,
#  ('Kingsbury', 'Queensbury'): 9419,
#  ('Queensbury', 'Canons Park'): 6385,
#  ('Canons Park', 'Stanmore'): 3624,
#  ('Bermondsey', 'London Bridge'): 79558,
#  ('London Bridge', 'Southwark'): 63202,
#  ('London Bridge', 'Borough'): 11620,
#  ('Southwark', 'Waterloo'): 68620,
#  ('Waterloo', 'Westminster'): 215297,
#  ('Waterloo', 'Embankment'): 17097,
#  ('Waterloo', 'Lambeth North'): 15112,
#  ('Waterloo', 'Kennington'): 50907,
#  ('Westminster', 'Green Park'): 177652,
#  ('Westminster', "St. James's Park"): 58339,
#  ('Westminster', 'Embankment'): 16217,
#  ('Green Park', 'Bond Street'): 130481,
#  ('Green Park', 'Hyde Park Corner'): 33643,
#  ('Green Park', 'Piccadilly Circus'): 20232,
#  ('Green Park', 'Victoria'): 130978,
#  ('Green Park', 'Oxford Circus'): 132470,
#  ('Bond Street', 'Baker Street'): 113780,
#  ('Bond Street', 'Marble Arch'): 28923,
#  ('Bond Street', 'Oxford Circus'): 17903,
#  ('Baker Street', "St. John's Wood"): 10477,
#  ('Baker Street', 'Great Portland Street'): 47201,
#  ('Baker Street', 'Finchley Road'): 71701,
#  ('Baker Street', 'Edgware Road'): 63303,
#  ('Baker Street', 'Marylebone'): 9148,
#  ('Baker Street', "Regent's Park"): 953,
#  ("St. John's Wood", 'Swiss Cottage'): 5975,
#  ('Swiss Cottage', 'Finchley Road'): 2736,
#  ('Neasden', 'Dollis Hill'): 4019,
#  ('Dollis Hill', 'Willesden Green'): 1482,
#  ('Willesden Green', 'Kilburn'): 6029,
#  ('Uxbridge', 'Hillingdon'): 7080,
#  ('Hillingdon', 'Ickenham'): 8453,
#  ('Ickenham', 'Ruislip'): 8984,
#  ('Ruislip', 'Ruislip Manor'): 9700,
#  ('Ruislip Manor', 'Eastcote'): 10497,
#  ('Eastcote', 'Rayners Lane'): 12414,
#  ('Rayners Lane', 'West Harrow'): 13798,
#  ('Rayners Lane', 'South Harrow'): 5268,
#  ('West Harrow', 'Harrow-on-the-Hill'): 14429,
#  ('Aldgate', 'Tower Hill'): 4767,
#  ('Great Portland Street', 'Euston Square'): 47121,
#  ('Euston Square', "King's Cross St. Pancras"): 49766,
#  ("King's Cross St. Pancras", 'Farringdon'): 103014,
#  ("King's Cross St. Pancras", 'Russell Square'): 23189,
#  ("King's Cross St. Pancras", 'Caledonian Road'): 9962,
#  ("King's Cross St. Pancras", 'Angel'): 13854,
#  ('Farringdon', 'Barbican'): 96782,
#  ('Barbican', 'Moorgate'): 95939,
#  ('Moorgate', 'Old Street'): 19409,
#  ('Harrow-on-the-Hill', 'North Harrow'): 15498,
#  ('Harrow-on-the-Hill', 'Northwick Park'): 33032,
#  ('Amersham', 'Chalfont & Latimer'): 1446,
#  ('Chalfont & Latimer', 'Chorleywood'): 3319,
#  ('Chalfont & Latimer', 'Chesham'): 1175,
#  ('Chorleywood', 'Rickmansworth'): 4587,
#  ('Rickmansworth', 'Moor Park'): 5990,
#  ('Moor Park', 'Northwood'): 9606,
#  ('Moor Park', 'Croxley'): 3414,
#  ('Northwood', 'Northwood Hills'): 11621,
#  ('Northwood Hills', 'Pinner'): 12581,
#  ('Pinner', 'North Harrow'): 14326,
#  ('Northwick Park', 'Preston Road'): 35297,
#  ('Croxley', 'Watford'): 2361,
#  ('South Kensington', 'Sloane Square'): 81301,
#  ('South Kensington', 'Gloucester Road'): 100342,
#  ('South Kensington', 'Knightsbridge'): 29412,
#  ('Sloane Square', 'Victoria'): 87777,
#  ('Gloucester Road', 'High Street Kensington'): 6926,
#  ('Gloucester Road', "Earl's Court"): 89401,
#  ('High Street Kensington', 'Notting Hill Gate'): 20618,
#  ('High Street Kensington', "Earl's Court"): 17018,
#  ('Notting Hill Gate', 'Bayswater'): 22114,
#  ('Notting Hill Gate', 'Holland Park'): 15921,
#  ('Notting Hill Gate', 'Queensway'): 16512,
#  ('Bayswater', 'Paddington'): 21706,
#  ('Paddington', 'Edgware Road'): 60513,
#  ('Paddington', 'Royal Oak'): 11508,
#  ('Paddington', 'Warwick Avenue'): 6534,
#  ('Edgware Road', 'Marylebone'): 1227,
#  ('Victoria', "St. James's Park"): 52097,
#  ('Victoria', 'Pimlico'): 75182,
#  ('Embankment', 'Temple'): 17749,
#  ('Embankment', 'Charing Cross'): 7380,
#  ('Temple', 'Blackfriars'): 11586,
#  ('Blackfriars', 'Mansion House'): 7674,
#  ('Mansion House', 'Cannon Street'): 14345,
#  ('Tower Hill', 'Aldgate East'): 4642,
#  ('Hammersmith', 'Goldhawk Road'): 5563,
#  ('Hammersmith', 'Barons Court'): 63763,
#  ('Hammersmith', 'Ravenscourt Park'): 4414,
#  ('Hammersmith', 'Turnham Green'): 48728,
#  ('Goldhawk Road', "Shepherd's Bush Market"): 4280,
#  ("Shepherd's Bush Market", 'Wood Lane'): 4892,
#  ('Wood Lane', 'Latimer Road'): 5984,
#  ('Latimer Road', 'Ladbroke Grove'): 6632,
#  ('Ladbroke Grove', 'Westbourne Park'): 8736,
#  ('Westbourne Park', 'Royal Oak'): 10395,
#  ('Stepney Green', 'Mile End'): 9182,
#  ('Mile End', 'Bow Road'): 4964,
#  ('Bow Road', 'Bromley-by-Bow'): 1484,
#  ('Plaistow', 'Upton Park'): 30835,
#  ('Upton Park', 'East Ham'): 25446,
#  ("Earl's Court", 'West Kensington'): 3196,
#  ("Earl's Court", 'Barons Court'): 66333,
#  ('West Kensington', 'Barons Court'): 864,
#  ('Ravenscourt Park', 'Stamford Brook'): 2595,
#  ('Stamford Brook', 'Turnham Green'): 1652,
#  ('Turnham Green', 'Chiswick Park'): 1710,
#  ('Turnham Green', 'Acton Town'): 42463,
#  ('Chiswick Park', 'Acton Town'): 1090,
#  ('Acton Town', 'Ealing Common'): 21572,
#  ('Acton Town', 'South Ealing'): 23406,
#  ('Ealing Common', 'Ealing Broadway'): 12203,
#  ('Ealing Common', 'North Ealing'): 8725,
#  ('Ealing Broadway', 'West Acton'): 6534,
#  ('Wimbledon', 'Wimbledon Park'): 13368,
#  ('Wimbledon Park', 'Southfields'): 14088,
#  ('Southfields', 'East Putney'): 17370,
#  ('East Putney', 'Putney Bridge'): 22123,
#  ('Putney Bridge', 'Parsons Green'): 25641,
#  ('Parsons Green', 'Fulham Broadway'): 30177,
#  ('Upney', 'Becontree'): 13312,
#  ('Becontree', 'Dagenham Heathway'): 11305,
#  ('Dagenham Heathway', 'Dagenham East'): 7623,
#  ('Dagenham East', 'Elm Park'): 5556,
#  ('Elm Park', 'Hornchurch'): 3139,
#  ('Hornchurch', 'Upminster Bridge'): 1488,
#  ('South Ealing', 'Northfields'): 21492,
#  ('Knightsbridge', 'Hyde Park Corner'): 32754,
#  ('Piccadilly Circus', 'Leicester Square'): 5480,
#  ('Piccadilly Circus', 'Oxford Circus'): 10164,
#  ('Piccadilly Circus', 'Charing Cross'): 10926,
#  ('Leicester Square', 'Covent Garden'): 5066,
#  ('Leicester Square', 'Tottenham Court Road'): 3147,
#  ('Leicester Square', 'Charing Cross'): 4323,
#  ('Covent Garden', 'Holborn'): 5795,
#  ('Holborn', 'Russell Square'): 21448,
#  ('Holborn', 'Tottenham Court Road'): 22903,
#  ('Holborn', 'Chancery Lane'): 27352,
#  ('Caledonian Road', 'Holloway Road'): 6858,
#  ('Holloway Road', 'Arsenal'): 3711,
#  ('Arsenal', 'Finsbury Park'): 1806,
#  ('Finsbury Park', 'Manor House'): 34661,
#  ('Manor House', 'Turnpike Lane'): 29359,
#  ('Turnpike Lane', 'Wood Green'): 22737,
#  ('Wood Green', 'Bounds Green'): 15448,
#  ('Bounds Green', 'Arnos Grove'): 10697,
#  ('Arnos Grove', 'Southgate'): 7501,
#  ('Southgate', 'Oakwood'): 3391,
#  ('Oakwood', 'Cockfosters'): 1262,
#  ('South Harrow', 'Sudbury Hill'): 6011,
#  ('Sudbury Hill', 'Sudbury Town'): 6301,
#  ('Sudbury Town', 'Alperton'): 6832,
#  ('Alperton', 'Park Royal'): 7665,
#  ('Park Royal', 'North Ealing'): 8454,
#  ('Heathrow Terminal 4', 'Hatton Cross'): 1194,
#  ('Heathrow Terminal 4', 'Heathrow Terminals 2 & 3'): 310,
#  ('Hatton Cross', 'Heathrow Terminals 2 & 3'): 5964,
#  ('Hatton Cross', 'Hounslow West'): 9260,
#  ('Heathrow Terminals 2 & 3', 'Heathrow Terminal 5'): 1913,
#  ('Hounslow West', 'Hounslow Central'): 11234,
#  ('Hounslow Central', 'Hounslow East'): 13469,
#  ('Hounslow East', 'Osterley'): 15935,
#  ('Osterley', 'Boston Manor'): 17445,
#  ('Boston Manor', 'Northfields'): 18598,
#  ('West Acton', 'North Acton'): 7580,
#  ('North Acton', 'Hanger Lane'): 14837,
#  ('North Acton', 'East Acton'): 24621,
#  ('West Ruislip', 'Ruislip Gardens'): 1277,
#  ('Ruislip Gardens', 'South Ruislip'): 2279,
#  ('South Ruislip', 'Northolt'): 3810,
#  ('Northolt', 'Greenford'): 7682,
#  ('Greenford', 'Perivale'): 10792,
#  ('Perivale', 'Hanger Lane'): 12330,
#  ('East Acton', 'White City'): 26292,
#  ('Queensway', 'Lancaster Gate'): 20006,
#  ('Lancaster Gate', 'Marble Arch'): 24274,
#  ('Oxford Circus', 'Tottenham Court Road'): 30017,
#  ('Oxford Circus', "Regent's Park"): 2782,
#  ('Oxford Circus', 'Warren Street'): 118412,
#  ('Tottenham Court Road', 'Goodge Street'): 4298,
#  ('Chancery Lane', "St. Paul's"): 28921,
#  ('Leyton', 'Leytonstone'): 48704,
#  ('Leytonstone', 'Snaresbrook'): 22990,
#  ('Leytonstone', 'Wanstead'): 19670,
#  ('Snaresbrook', 'South Woodford'): 21268,
#  ('South Woodford', 'Woodford'): 17198,
#  ('Woodford', 'Buckhurst Hill'): 10634,
#  ('Woodford', 'Roding Valley'): 2132,
#  ('Buckhurst Hill', 'Loughton'): 9118,
#  ('Loughton', 'Debden'): 6185,
#  ('Debden', 'Theydon Bois'): 4072,
#  ('Theydon Bois', 'Epping'): 3397,
#  ('Wanstead', 'Redbridge'): 17788,
#  ('Redbridge', 'Gants Hill'): 15670,
#  ('Gants Hill', 'Newbury Park'): 10086,
#  ('Newbury Park', 'Barkingside'): 5715,
#  ('Barkingside', 'Fairlop'): 4224,
#  ('Fairlop', 'Hainault'): 3129,
#  ('Hainault', 'Grange Hill'): 504,
#  ('Grange Hill', 'Chigwell'): 1184,
#  ('Chigwell', 'Roding Valley'): 1757,
#  ('Kilburn Park', 'Maida Vale'): 3397,
#  ('Maida Vale', 'Warwick Avenue'): 3994,
#  ('Lambeth North', 'Elephant & Castle'): 12867,
#  ('Elephant & Castle', 'Borough'): 9804,
#  ('Elephant & Castle', 'Kennington'): 10633,
#  ('Maryland', 'Forest Gate'): 33938,
#  ('Forest Gate', 'Manor Park'): 31879,
#  ('Manor Park', 'Ilford'): 30542,
#  ('Ilford', 'Seven Kings'): 25313,
#  ('Seven Kings', 'Goodmayes'): 21970,
#  ('Goodmayes', 'Chadwell Heath'): 18594,
#  ('Gidea Park', 'Harold Wood'): 5522,
#  ('Harold Wood', 'Brentwood'): 2789,
#  ('Brentwood', 'Shenfield'): 1181,
#  ('Brixton', 'Stockwell'): 28465,
#  ('Stockwell', 'Vauxhall'): 55294,
#  ('Stockwell', 'Oval'): 54283,
#  ('Stockwell', 'Clapham North'): 59928,
#  ('Vauxhall', 'Pimlico'): 68732,
#  ('Warren Street', 'Goodge Street'): 2525,
#  ('Edgware', 'Burnt Oak'): 4177,
#  ('Burnt Oak', 'Colindale'): 7651,
#  ('Colindale', 'Hendon Central'): 14377,
#  ('Hendon Central', 'Brent Cross'): 19124,
#  ('Brent Cross', 'Golders Green'): 20220,
#  ('Golders Green', 'Hampstead'): 24767,
#  ('Hampstead', 'Belsize Park'): 27009,
#  ('Belsize Park', 'Chalk Farm'): 30238,
#  ('Chalk Farm', 'Camden Town'): 33160,
#  ('Camden Town', 'Kentish Town'): 40446,
#  ('Camden Town', 'Mornington Crescent'): 1076,
#  ('Angel', 'Old Street'): 15058,
#  ('Kennington', 'Oval'): 57626,
#  ('Kennington', 'Nine Elms'): 0,
#  ('Clapham North', 'Clapham Common'): 57688,
#  ('Clapham Common', 'Clapham South'): 52799,
#  ('Clapham South', 'Balham'): 46040,
#  ('Balham', 'Tooting Bec'): 37941,
#  ('Tooting Bec', 'Tooting Broadway'): 31330,
#  ('Tooting Broadway', 'Colliers Wood'): 20004,
#  ('Colliers Wood', 'South Wimbledon'): 14194,
#  ('South Wimbledon', 'Morden'): 9482,
#  ('Finchley Central', 'Mill Hill East'): 1974,
#  ('Finchley Central', 'West Finchley'): 11555,
#  ('Finchley Central', 'East Finchley'): 19938,
#  ('High Barnet', 'Totteridge & Whetstone'): 4224,
#  ('Totteridge & Whetstone', 'Woodside Park'): 6700,
#  ('Woodside Park', 'West Finchley'): 10150,
#  ('East Finchley', 'Highgate'): 25789,
#  ('Highgate', 'Archway'): 30286,
#  ('Archway', 'Tufnell Park'): 35715,
#  ('Tufnell Park', 'Kentish Town'): 38298,
#  ('Battersea Power Station', 'Nine Elms'): 0}

# %% [markdown]
# ### IMPORTANT!!! (INTEGRATION BETWEEN NETWORK AND WEIGHT)

# %%
#assumption, uniform velocity x different distance = time
#time = distance / velocity

# %%
#creating the new weight, time and flows (travel time)
#travel_time = f(flows, time) # finding the formula

# %%
#inputting the new weight into the network

# %%
#set this as a network attribute (change flow to new weight)
nx.set_edge_attributes(G, flows, 'flows') # <- change into travel_time

# %%
for edge, data in dict(G.edges).items():
    print(f"Edge: {edge}, Data: {data}")
# Out:
# Edge: ('Cambridge Heath', 'Bethnal Green'), Data: {'length': 13816, 'line_name': 'London Overground', 'flows': 13816, 'velocity': 60, 'time': 230.26666666666668}
# Edge: ('Cambridge Heath', 'London Fields'), Data: {'length': 14266, 'line_name': 'London Overground', 'flows': 14266, 'velocity': 60, 'time': 237.76666666666668}
# Edge: ('Bethnal Green', 'Liverpool Street'), Data: {'length': 31564, 'line_name': 'Central', 'flows': 31564, 'velocity': 60, 'time': 526.0666666666667}
# Edge: ('Bethnal Green', 'Mile End'), Data: {'length': 12930, 'line_name': 'Central', 'flows': 12930, 'velocity': 60, 'time': 215.5}
# Edge: ('London Fields', 'Hackney Downs'), Data: {'length': 14238, 'line_name': 'London Overground', 'flows': 14238, 'velocity': 60, 'time': 237.3}
# Edge: ('Hackney Downs', 'Rectory Road'), Data: {'length': 3890, 'line_name': 'London Overground', 'flows': 3890, 'velocity': 60, 'time': 64.83333333333333}
# Edge: ('Hackney Downs', 'Clapton'), Data: {'length': 10816, 'line_name': 'London Overground', 'flows': 10816, 'velocity': 60, 'time': 180.26666666666668}
# Edge: ('Rectory Road', 'Stoke Newington'), Data: {'length': 3888, 'line_name': 'London Overground', 'flows': 3888, 'velocity': 60, 'time': 64.8}
# Edge: ('Stoke Newington', 'Stamford Hill'), Data: {'length': 3913, 'line_name': 'London Overground', 'flows': 3913, 'velocity': 60, 'time': 65.21666666666667}
# Edge: ('Stamford Hill', 'Seven Sisters'), Data: {'length': 3814, 'line_name': 'London Overground', 'flows': 3814, 'velocity': 60, 'time': 63.56666666666667}
# Edge: ('Seven Sisters', 'Bruce Grove'), Data: {'length': 12361, 'line_name': 'London Overground', 'flows': 12361, 'velocity': 60, 'time': 206.01666666666668}
# Edge: ('Seven Sisters', 'Finsbury Park'), Data: {'length': 54607, 'line_name': 'Victoria', 'flows': 54607, 'velocity': 60, 'time': 910.1166666666667}
# Edge: ('Seven Sisters', 'Tottenham Hale'), Data: {'length': 33279, 'line_name': 'Victoria', 'flows': 33279, 'velocity': 60, 'time': 554.65}
# Edge: ('Bruce Grove', 'White Hart Lane'), Data: {'length': 11728, 'line_name': 'London Overground', 'flows': 11728, 'velocity': 60, 'time': 195.46666666666667}
# Edge: ('White Hart Lane', 'Silver Street'), Data: {'length': 10497, 'line_name': 'London Overground', 'flows': 10497, 'velocity': 60, 'time': 174.95}
# Edge: ('Silver Street', 'Edmonton Green'), Data: {'length': 8985, 'line_name': 'London Overground', 'flows': 8985, 'velocity': 60, 'time': 149.75}
# Edge: ('Edmonton Green', 'Southbury'), Data: {'length': 2937, 'line_name': 'London Overground', 'flows': 2937, 'velocity': 60, 'time': 48.95}
# Edge: ('Edmonton Green', 'Bush Hill Park'), Data: {'length': 4062, 'line_name': 'London Overground', 'flows': 4062, 'velocity': 60, 'time': 67.7}
# Edge: ('Southbury', 'Turkey Street'), Data: {'length': 2083, 'line_name': 'London Overground', 'flows': 2083, 'velocity': 60, 'time': 34.71666666666667}
# Edge: ('Turkey Street', 'Theobalds Grove'), Data: {'length': 934, 'line_name': 'London Overground', 'flows': 934, 'velocity': 60, 'time': 15.566666666666666}
# Edge: ('Theobalds Grove', 'Cheshunt'), Data: {'length': 287, 'line_name': 'London Overground', 'flows': 287, 'velocity': 60, 'time': 4.783333333333333}
# Edge: ('Liverpool Street', 'Aldgate'), Data: {'length': 8087, 'line_name': 'Circle', 'flows': 8087, 'velocity': 60, 'time': 134.78333333333333}
# Edge: ('Liverpool Street', 'Moorgate'), Data: {'length': 46909, 'line_name': 'Hammersmith & City', 'flows': 46909, 'velocity': 60, 'time': 781.8166666666667}
# Edge: ('Liverpool Street', 'Aldgate East'), Data: {'length': 8178, 'line_name': 'Hammersmith & City', 'flows': 8178, 'velocity': 60, 'time': 136.3}
# Edge: ('Liverpool Street', 'Bank and Monument'), Data: {'length': 149143, 'line_name': 'Central', 'flows': 149143, 'velocity': 60, 'time': 2485.7166666666667}
# Edge: ('Liverpool Street', 'Stratford'), Data: {'length': 145962, 'line_name': 'TfL Rail', 'flows': 145962, 'velocity': 60, 'time': 2432.7}
# Edge: ('Enfield Town', 'Bush Hill Park'), Data: {'length': 2552, 'line_name': 'London Overground', 'flows': 2552, 'velocity': 60, 'time': 42.53333333333333}
# Edge: ('Romford', 'Emerson Park'), Data: {'length': 1184, 'line_name': 'London Overground', 'flows': 1184, 'velocity': 60, 'time': 19.733333333333334}
# Edge: ('Romford', 'Chadwell Heath'), Data: {'length': 14919, 'line_name': 'TfL Rail', 'flows': 14919, 'velocity': 60, 'time': 248.65}
# Edge: ('Romford', 'Gidea Park'), Data: {'length': 8884, 'line_name': 'TfL Rail', 'flows': 8884, 'velocity': 60, 'time': 148.06666666666666}
# Edge: ('Emerson Park', 'Upminster'), Data: {'length': 1211, 'line_name': 'London Overground', 'flows': 1211, 'velocity': 60, 'time': 20.183333333333334}
# Edge: ('Upminster', 'Upminster Bridge'), Data: {'length': 1330, 'line_name': 'District', 'flows': 1330, 'velocity': 60, 'time': 22.166666666666668}
# Edge: ('Clapton', 'St James Street'), Data: {'length': 10403, 'line_name': 'London Overground', 'flows': 10403, 'velocity': 60, 'time': 173.38333333333333}
# Edge: ('St James Street', 'Walthamstow Central'), Data: {'length': 9581, 'line_name': 'London Overground', 'flows': 9581, 'velocity': 60, 'time': 159.68333333333334}
# Edge: ('Walthamstow Central', 'Wood Street'), Data: {'length': 7003, 'line_name': 'London Overground', 'flows': 7003, 'velocity': 60, 'time': 116.71666666666667}
# Edge: ('Walthamstow Central', 'Blackhorse Road'), Data: {'length': 14986, 'line_name': 'Victoria', 'flows': 14986, 'velocity': 60, 'time': 249.76666666666668}
# Edge: ('Wood Street', 'Highams Park'), Data: {'length': 5510, 'line_name': 'London Overground', 'flows': 5510, 'velocity': 60, 'time': 91.83333333333333}
# Edge: ('Highams Park', 'Chingford'), Data: {'length': 2277, 'line_name': 'London Overground', 'flows': 2277, 'velocity': 60, 'time': 37.95}
# Edge: ('Richmond', 'Kew Gardens'), Data: {'length': 10554, 'line_name': 'District', 'flows': 10554, 'velocity': 60, 'time': 175.9}
# Edge: ('Kew Gardens', 'Gunnersbury'), Data: {'length': 12513, 'line_name': 'District', 'flows': 12513, 'velocity': 60, 'time': 208.55}
# Edge: ('Gunnersbury', 'South Acton'), Data: {'length': 13918, 'line_name': 'London Overground', 'flows': 13918, 'velocity': 60, 'time': 231.96666666666667}
# Edge: ('Gunnersbury', 'Turnham Green'), Data: {'length': 15118, 'line_name': 'District', 'flows': 15118, 'velocity': 60, 'time': 251.96666666666667}
# Edge: ('South Acton', 'Acton Central'), Data: {'length': 14815, 'line_name': 'London Overground', 'flows': 14815, 'velocity': 60, 'time': 246.91666666666666}
# Edge: ('Harrow & Wealdstone', 'Kenton'), Data: {'length': 5132, 'line_name': 'Bakerloo', 'flows': 5132, 'velocity': 60, 'time': 85.53333333333333}
# Edge: ('Harrow & Wealdstone', 'Headstone Lane'), Data: {'length': 3456, 'line_name': 'London Overground', 'flows': 3456, 'velocity': 60, 'time': 57.6}
# Edge: ('Kenton', 'South Kenton'), Data: {'length': 5933, 'line_name': 'Bakerloo', 'flows': 5933, 'velocity': 60, 'time': 98.88333333333334}
# Edge: ('South Kenton', 'North Wembley'), Data: {'length': 6707, 'line_name': 'Bakerloo', 'flows': 6707, 'velocity': 60, 'time': 111.78333333333333}
# Edge: ('North Wembley', 'Wembley Central'), Data: {'length': 7477, 'line_name': 'Bakerloo', 'flows': 7477, 'velocity': 60, 'time': 124.61666666666666}
# Edge: ('Wembley Central', 'Stonebridge Park'), Data: {'length': 9134, 'line_name': 'Bakerloo', 'flows': 9134, 'velocity': 60, 'time': 152.23333333333332}
# Edge: ('Stonebridge Park', 'Harlesden'), Data: {'length': 10125, 'line_name': 'Bakerloo', 'flows': 10125, 'velocity': 60, 'time': 168.75}
# Edge: ('Harlesden', 'Willesden Junction'), Data: {'length': 11103, 'line_name': 'Bakerloo', 'flows': 11103, 'velocity': 60, 'time': 185.05}
# Edge: ('Willesden Junction', 'Kensal Green'), Data: {'length': 36380, 'line_name': 'Bakerloo', 'flows': 36380, 'velocity': 60, 'time': 606.3333333333334}
# Edge: ('Willesden Junction', 'Acton Central'), Data: {'length': 15559, 'line_name': 'London Overground', 'flows': 15559, 'velocity': 60, 'time': 259.31666666666666}
# Edge: ('Willesden Junction', 'Kensal Rise'), Data: {'length': 11015, 'line_name': 'London Overground', 'flows': 11015, 'velocity': 60, 'time': 183.58333333333334}
# Edge: ('Willesden Junction', "Shepherd's Bush"), Data: {'length': 26126, 'line_name': 'London Overground', 'flows': 26126, 'velocity': 60, 'time': 435.43333333333334}
# Edge: ('Kensal Green', "Queen's Park"), Data: {'length': 37043, 'line_name': 'Bakerloo', 'flows': 37043, 'velocity': 60, 'time': 617.3833333333333}
# Edge: ("Queen's Park", 'Kilburn High Road'), Data: {'length': 40037, 'line_name': 'London Overground', 'flows': 40037, 'velocity': 60, 'time': 667.2833333333333}
# Edge: ("Queen's Park", 'Kilburn Park'), Data: {'length': 4642, 'line_name': 'Bakerloo', 'flows': 4642, 'velocity': 60, 'time': 77.36666666666666}
# Edge: ('Kilburn High Road', 'South Hampstead'), Data: {'length': 40116, 'line_name': 'London Overground', 'flows': 40116, 'velocity': 60, 'time': 668.6}
# Edge: ('Kensal Rise', 'Brondesbury Park'), Data: {'length': 9892, 'line_name': 'London Overground', 'flows': 9892, 'velocity': 60, 'time': 164.86666666666667}
# Edge: ('Brondesbury Park', 'Brondesbury'), Data: {'length': 10124, 'line_name': 'London Overground', 'flows': 10124, 'velocity': 60, 'time': 168.73333333333332}
# Edge: ('Brondesbury', 'West Hampstead'), Data: {'length': 9755, 'line_name': 'London Overground', 'flows': 9755, 'velocity': 60, 'time': 162.58333333333334}
# Edge: ('West Hampstead', 'Finchley Road & Frognal'), Data: {'length': 7453, 'line_name': 'London Overground', 'flows': 7453, 'velocity': 60, 'time': 124.21666666666667}
# Edge: ('West Hampstead', 'Kilburn'), Data: {'length': 11936, 'line_name': 'Jubilee', 'flows': 11936, 'velocity': 60, 'time': 198.93333333333334}
# Edge: ('West Hampstead', 'Finchley Road'), Data: {'length': 23719, 'line_name': 'Jubilee', 'flows': 23719, 'velocity': 60, 'time': 395.31666666666666}
# Edge: ('Finchley Road & Frognal', 'Hampstead Heath'), Data: {'length': 7454, 'line_name': 'London Overground', 'flows': 7454, 'velocity': 60, 'time': 124.23333333333333}
# Edge: ('Hampstead Heath', 'Gospel Oak'), Data: {'length': 7183, 'line_name': 'London Overground', 'flows': 7183, 'velocity': 60, 'time': 119.71666666666667}
# Edge: ('Gospel Oak', 'Kentish Town West'), Data: {'length': 5915, 'line_name': 'London Overground', 'flows': 5915, 'velocity': 60, 'time': 98.58333333333333}
# Edge: ('Gospel Oak', 'Upper Holloway'), Data: {'length': 1932, 'line_name': 'London Overground', 'flows': 1932, 'velocity': 60, 'time': 32.2}
# Edge: ('Kentish Town West', 'Camden Road'), Data: {'length': 4577, 'line_name': 'London Overground', 'flows': 4577, 'velocity': 60, 'time': 76.28333333333333}
# Edge: ('Camden Road', 'Caledonian Road & Barnsbury'), Data: {'length': 7516, 'line_name': 'London Overground', 'flows': 7516, 'velocity': 60, 'time': 125.26666666666667}
# Edge: ('Caledonian Road & Barnsbury', 'Highbury & Islington'), Data: {'length': 9057, 'line_name': 'London Overground', 'flows': 9057, 'velocity': 60, 'time': 150.95}
# Edge: ('Highbury & Islington', 'Canonbury'), Data: {'length': 23479, 'line_name': 'London Overground', 'flows': 23479, 'velocity': 60, 'time': 391.31666666666666}
# Edge: ('Highbury & Islington', "King's Cross St. Pancras"), Data: {'length': 120053, 'line_name': 'Victoria', 'flows': 120053, 'velocity': 60, 'time': 2000.8833333333334}
# Edge: ('Highbury & Islington', 'Finsbury Park'), Data: {'length': 108014, 'line_name': 'Victoria', 'flows': 108014, 'velocity': 60, 'time': 1800.2333333333333}
# Edge: ('Canonbury', 'Dalston Kingsland'), Data: {'length': 17743, 'line_name': 'London Overground', 'flows': 17743, 'velocity': 60, 'time': 295.71666666666664}
# Edge: ('Canonbury', 'Dalston Junction'), Data: {'length': 5702, 'line_name': 'London Overground', 'flows': 5702, 'velocity': 60, 'time': 95.03333333333333}
# Edge: ('Dalston Kingsland', 'Hackney Central'), Data: {'length': 16680, 'line_name': 'London Overground', 'flows': 16680, 'velocity': 60, 'time': 278.0}
# Edge: ('Hackney Central', 'Homerton'), Data: {'length': 15054, 'line_name': 'London Overground', 'flows': 15054, 'velocity': 60, 'time': 250.9}
# Edge: ('Homerton', 'Hackney Wick'), Data: {'length': 14381, 'line_name': 'London Overground', 'flows': 14381, 'velocity': 60, 'time': 239.68333333333334}
# Edge: ('Hackney Wick', 'Stratford'), Data: {'length': 14051, 'line_name': 'London Overground', 'flows': 14051, 'velocity': 60, 'time': 234.18333333333334}
# Edge: ('Stratford', 'Stratford High Street'), Data: {'length': 1089, 'line_name': 'DLR', 'flows': 1089, 'velocity': 60, 'time': 18.15}
# Edge: ('Stratford', 'Pudding Mill Lane'), Data: {'length': 4261, 'line_name': 'DLR', 'flows': 4261, 'velocity': 60, 'time': 71.01666666666667}
# Edge: ('Stratford', 'Stratford International'), Data: {'length': 3833, 'line_name': 'DLR', 'flows': 3833, 'velocity': 60, 'time': 63.88333333333333}
# Edge: ('Stratford', 'West Ham'), Data: {'length': 90511, 'line_name': 'Jubilee', 'flows': 90511, 'velocity': 60, 'time': 1508.5166666666667}
# Edge: ('Stratford', 'Mile End'), Data: {'length': 12008, 'line_name': 'Central', 'flows': 12008, 'velocity': 60, 'time': 200.13333333333333}
# Edge: ('Stratford', 'Leyton'), Data: {'length': 56082, 'line_name': 'Central', 'flows': 56082, 'velocity': 60, 'time': 934.7}
# Edge: ('Stratford', 'Maryland'), Data: {'length': 34442, 'line_name': 'TfL Rail', 'flows': 34442, 'velocity': 60, 'time': 574.0333333333333}
# Edge: ('Whitechapel', 'Shadwell'), Data: {'length': 28908, 'line_name': 'London Overground', 'flows': 28908, 'velocity': 60, 'time': 481.8}
# Edge: ('Whitechapel', 'Shoreditch High Street'), Data: {'length': 15838, 'line_name': 'London Overground', 'flows': 15838, 'velocity': 60, 'time': 263.96666666666664}
# Edge: ('Whitechapel', 'Aldgate East'), Data: {'length': 4162, 'line_name': 'District', 'flows': 4162, 'velocity': 60, 'time': 69.36666666666666}
# Edge: ('Whitechapel', 'Stepney Green'), Data: {'length': 10824, 'line_name': 'District', 'flows': 10824, 'velocity': 60, 'time': 180.4}
# Edge: ('Shadwell', 'Wapping'), Data: {'length': 21039, 'line_name': 'London Overground', 'flows': 21039, 'velocity': 60, 'time': 350.65}
# Edge: ('Shadwell', 'Bank and Monument'), Data: {'length': 22035, 'line_name': 'DLR', 'flows': 22035, 'velocity': 60, 'time': 367.25}
# Edge: ('Shadwell', 'Limehouse'), Data: {'length': 11897, 'line_name': 'DLR', 'flows': 11897, 'velocity': 60, 'time': 198.28333333333333}
# Edge: ('Shadwell', 'Tower Gateway'), Data: {'length': 4195, 'line_name': 'DLR', 'flows': 4195, 'velocity': 60, 'time': 69.91666666666667}
# Edge: ('Wapping', 'Rotherhithe'), Data: {'length': 21396, 'line_name': 'London Overground', 'flows': 21396, 'velocity': 60, 'time': 356.6}
# Edge: ('Rotherhithe', 'Canada Water'), Data: {'length': 20868, 'line_name': 'London Overground', 'flows': 20868, 'velocity': 60, 'time': 347.8}
# Edge: ('Canada Water', 'Surrey Quays'), Data: {'length': 36805, 'line_name': 'London Overground', 'flows': 36805, 'velocity': 60, 'time': 613.4166666666666}
# Edge: ('Canada Water', 'Canary Wharf'), Data: {'length': 74368, 'line_name': 'Jubilee', 'flows': 74368, 'velocity': 60, 'time': 1239.4666666666667}
# Edge: ('Canada Water', 'Bermondsey'), Data: {'length': 76162, 'line_name': 'Jubilee', 'flows': 76162, 'velocity': 60, 'time': 1269.3666666666666}
# Edge: ('Surrey Quays', 'New Cross Gate'), Data: {'length': 16779, 'line_name': 'London Overground', 'flows': 16779, 'velocity': 60, 'time': 279.65}
# Edge: ('Surrey Quays', 'New Cross'), Data: {'length': 2467, 'line_name': 'London Overground', 'flows': 2467, 'velocity': 60, 'time': 41.11666666666667}
# Edge: ('Surrey Quays', 'Queens Road Peckham'), Data: {'length': 14663, 'line_name': 'London Overground', 'flows': 14663, 'velocity': 60, 'time': 244.38333333333333}
# Edge: ('New Cross Gate', 'Brockley'), Data: {'length': 15071, 'line_name': 'London Overground', 'flows': 15071, 'velocity': 60, 'time': 251.18333333333334}
# Edge: ('Shoreditch High Street', 'Hoxton'), Data: {'length': 10622, 'line_name': 'London Overground', 'flows': 10622, 'velocity': 60, 'time': 177.03333333333333}
# Edge: ('Sydenham', 'Crystal Palace'), Data: {'length': 2434, 'line_name': 'London Overground', 'flows': 2434, 'velocity': 60, 'time': 40.56666666666667}
# Edge: ('Sydenham', 'Forest Hill'), Data: {'length': 9134, 'line_name': 'London Overground', 'flows': 9134, 'velocity': 60, 'time': 152.23333333333332}
# Edge: ('Sydenham', 'Penge West'), Data: {'length': 4981, 'line_name': 'London Overground', 'flows': 4981, 'velocity': 60, 'time': 83.01666666666667}
# Edge: ('Queens Road Peckham', 'Peckham Rye'), Data: {'length': 13372, 'line_name': 'London Overground', 'flows': 13372, 'velocity': 60, 'time': 222.86666666666667}
# Edge: ('Peckham Rye', 'Denmark Hill'), Data: {'length': 12869, 'line_name': 'London Overground', 'flows': 12869, 'velocity': 60, 'time': 214.48333333333332}
# Edge: ('Denmark Hill', 'Clapham High Street'), Data: {'length': 13237, 'line_name': 'London Overground', 'flows': 13237, 'velocity': 60, 'time': 220.61666666666667}
# Edge: ('Clapham High Street', 'Wandsworth Road'), Data: {'length': 12577, 'line_name': 'London Overground', 'flows': 12577, 'velocity': 60, 'time': 209.61666666666667}
# Edge: ('Wandsworth Road', 'Clapham Junction'), Data: {'length': 12012, 'line_name': 'London Overground', 'flows': 12012, 'velocity': 60, 'time': 200.2}
# Edge: ('Wandsworth Road', 'Battersea Park'), Data: {'length': 0, 'line_name': 'London Overground', 'flows': 0, 'velocity': 60, 'time': 0.0}
# Edge: ('Clapham Junction', 'Imperial Wharf'), Data: {'length': 13982, 'line_name': 'London Overground', 'flows': 13982, 'velocity': 60, 'time': 233.03333333333333}
# Edge: ('West Brompton', 'Imperial Wharf'), Data: {'length': 14609, 'line_name': 'London Overground', 'flows': 14609, 'velocity': 60, 'time': 243.48333333333332}
# Edge: ('West Brompton', 'Kensington'), Data: {'length': 16163, 'line_name': 'London Overground', 'flows': 16163, 'velocity': 60, 'time': 269.3833333333333}
# Edge: ('West Brompton', "Earl's Court"), Data: {'length': 33978, 'line_name': 'District', 'flows': 33978, 'velocity': 60, 'time': 566.3}
# Edge: ('West Brompton', 'Fulham Broadway'), Data: {'length': 34820, 'line_name': 'District', 'flows': 34820, 'velocity': 60, 'time': 580.3333333333334}
# Edge: ('South Hampstead', 'Euston'), Data: {'length': 40052, 'line_name': 'London Overground', 'flows': 40052, 'velocity': 60, 'time': 667.5333333333333}
# Edge: ('Euston', 'Warren Street'), Data: {'length': 118799, 'line_name': 'Northern', 'flows': 118799, 'velocity': 60, 'time': 1979.9833333333333}
# Edge: ('Euston', "King's Cross St. Pancras"), Data: {'length': 142551, 'line_name': 'Northern', 'flows': 142551, 'velocity': 60, 'time': 2375.85}
# Edge: ('Euston', 'Camden Town'), Data: {'length': 73814, 'line_name': 'Northern', 'flows': 73814, 'velocity': 60, 'time': 1230.2333333333333}
# Edge: ('Euston', 'Mornington Crescent'), Data: {'length': 2542, 'line_name': 'Northern', 'flows': 2542, 'velocity': 60, 'time': 42.36666666666667}
# Edge: ('Bushey', 'Watford High Street'), Data: {'length': 2871, 'line_name': 'London Overground', 'flows': 2871, 'velocity': 60, 'time': 47.85}
# Edge: ('Bushey', 'Carpenders Park'), Data: {'length': 3311, 'line_name': 'London Overground', 'flows': 3311, 'velocity': 60, 'time': 55.18333333333333}
# Edge: ('Watford High Street', 'Watford Junction'), Data: {'length': 1858, 'line_name': 'London Overground', 'flows': 1858, 'velocity': 60, 'time': 30.966666666666665}
# Edge: ('Carpenders Park', 'Hatch End'), Data: {'length': 3234, 'line_name': 'London Overground', 'flows': 3234, 'velocity': 60, 'time': 53.9}
# Edge: ('Hatch End', 'Headstone Lane'), Data: {'length': 3223, 'line_name': 'London Overground', 'flows': 3223, 'velocity': 60, 'time': 53.71666666666667}
# Edge: ('Upper Holloway', 'Crouch Hill'), Data: {'length': 2708, 'line_name': 'London Overground', 'flows': 2708, 'velocity': 60, 'time': 45.13333333333333}
# Edge: ('Crouch Hill', 'Harringay Green Lanes'), Data: {'length': 2912, 'line_name': 'London Overground', 'flows': 2912, 'velocity': 60, 'time': 48.53333333333333}
# Edge: ('Harringay Green Lanes', 'South Tottenham'), Data: {'length': 3235, 'line_name': 'London Overground', 'flows': 3235, 'velocity': 60, 'time': 53.916666666666664}
# Edge: ('South Tottenham', 'Blackhorse Road'), Data: {'length': 3631, 'line_name': 'London Overground', 'flows': 3631, 'velocity': 60, 'time': 60.516666666666666}
# Edge: ('Blackhorse Road', 'Walthamstow Queens Road'), Data: {'length': 4832, 'line_name': 'London Overground', 'flows': 4832, 'velocity': 60, 'time': 80.53333333333333}
# Edge: ('Blackhorse Road', 'Tottenham Hale'), Data: {'length': 23117, 'line_name': 'Victoria', 'flows': 23117, 'velocity': 60, 'time': 385.28333333333336}
# Edge: ('Walthamstow Queens Road', 'Leyton Midland Road'), Data: {'length': 5730, 'line_name': 'London Overground', 'flows': 5730, 'velocity': 60, 'time': 95.5}
# Edge: ('Leyton Midland Road', 'Leytonstone High Road'), Data: {'length': 5411, 'line_name': 'London Overground', 'flows': 5411, 'velocity': 60, 'time': 90.18333333333334}
# Edge: ('Leytonstone High Road', 'Wanstead Park'), Data: {'length': 4835, 'line_name': 'London Overground', 'flows': 4835, 'velocity': 60, 'time': 80.58333333333333}
# Edge: ('Wanstead Park', 'Woodgrange Park'), Data: {'length': 3996, 'line_name': 'London Overground', 'flows': 3996, 'velocity': 60, 'time': 66.6}
# Edge: ('Woodgrange Park', 'Barking'), Data: {'length': 3386, 'line_name': 'London Overground', 'flows': 3386, 'velocity': 60, 'time': 56.43333333333333}
# Edge: ('Barking', 'East Ham'), Data: {'length': 18028, 'line_name': 'District', 'flows': 18028, 'velocity': 60, 'time': 300.46666666666664}
# Edge: ('Barking', 'Upney'), Data: {'length': 15044, 'line_name': 'District', 'flows': 15044, 'velocity': 60, 'time': 250.73333333333332}
# Edge: ('Brockley', 'Honor Oak Park'), Data: {'length': 12935, 'line_name': 'London Overground', 'flows': 12935, 'velocity': 60, 'time': 215.58333333333334}
# Edge: ('Honor Oak Park', 'Forest Hill'), Data: {'length': 11486, 'line_name': 'London Overground', 'flows': 11486, 'velocity': 60, 'time': 191.43333333333334}
# Edge: ('Penge West', 'Anerley'), Data: {'length': 4685, 'line_name': 'London Overground', 'flows': 4685, 'velocity': 60, 'time': 78.08333333333333}
# Edge: ('Anerley', 'Norwood Junction'), Data: {'length': 4259, 'line_name': 'London Overground', 'flows': 4259, 'velocity': 60, 'time': 70.98333333333333}
# Edge: ('Norwood Junction', 'West Croydon'), Data: {'length': 3380, 'line_name': 'London Overground', 'flows': 3380, 'velocity': 60, 'time': 56.333333333333336}
# Edge: ('Dalston Junction', 'Haggerston'), Data: {'length': 8145, 'line_name': 'London Overground', 'flows': 8145, 'velocity': 60, 'time': 135.75}
# Edge: ('Haggerston', 'Hoxton'), Data: {'length': 9064, 'line_name': 'London Overground', 'flows': 9064, 'velocity': 60, 'time': 151.06666666666666}
# Edge: ('Kensington', "Shepherd's Bush"), Data: {'length': 30388, 'line_name': 'London Overground', 'flows': 30388, 'velocity': 60, 'time': 506.46666666666664}
# Edge: ('Kensington', "Earl's Court"), Data: {'length': 14637, 'line_name': 'District', 'flows': 14637, 'velocity': 60, 'time': 243.95}
# Edge: ("Shepherd's Bush", 'White City'), Data: {'length': 31767, 'line_name': 'Central', 'flows': 31767, 'velocity': 60, 'time': 529.45}
# Edge: ("Shepherd's Bush", 'Holland Park'), Data: {'length': 14148, 'line_name': 'Central', 'flows': 14148, 'velocity': 60, 'time': 235.8}
# Edge: ('Stratford High Street', 'Abbey Road'), Data: {'length': 1206, 'line_name': 'DLR', 'flows': 1206, 'velocity': 60, 'time': 20.1}
# Edge: ('Abbey Road', 'West Ham'), Data: {'length': 996, 'line_name': 'DLR', 'flows': 996, 'velocity': 60, 'time': 16.6}
# Edge: ('West Ham', 'Star Lane'), Data: {'length': 1038, 'line_name': 'DLR', 'flows': 1038, 'velocity': 60, 'time': 17.3}
# Edge: ('West Ham', 'Canning Town'), Data: {'length': 59947, 'line_name': 'Jubilee', 'flows': 59947, 'velocity': 60, 'time': 999.1166666666667}
# Edge: ('West Ham', 'Bromley-by-Bow'), Data: {'length': 4266, 'line_name': 'District', 'flows': 4266, 'velocity': 60, 'time': 71.1}
# Edge: ('West Ham', 'Plaistow'), Data: {'length': 33714, 'line_name': 'District', 'flows': 33714, 'velocity': 60, 'time': 561.9}
# Edge: ('Star Lane', 'Canning Town'), Data: {'length': 452, 'line_name': 'DLR', 'flows': 452, 'velocity': 60, 'time': 7.533333333333333}
# Edge: ('Canning Town', 'Royal Victoria'), Data: {'length': 11357, 'line_name': 'DLR', 'flows': 11357, 'velocity': 60, 'time': 189.28333333333333}
# Edge: ('Canning Town', 'East India'), Data: {'length': 5502, 'line_name': 'DLR', 'flows': 5502, 'velocity': 60, 'time': 91.7}
# Edge: ('Canning Town', 'West Silvertown'), Data: {'length': 20147, 'line_name': 'DLR', 'flows': 20147, 'velocity': 60, 'time': 335.78333333333336}
# Edge: ('Canning Town', 'North Greenwich'), Data: {'length': 31846, 'line_name': 'Jubilee', 'flows': 31846, 'velocity': 60, 'time': 530.7666666666667}
# Edge: ('Royal Victoria', 'Custom House'), Data: {'length': 8797, 'line_name': 'DLR', 'flows': 8797, 'velocity': 60, 'time': 146.61666666666667}
# Edge: ('Bank and Monument', 'Cannon Street'), Data: {'length': 21169, 'line_name': 'District', 'flows': 21169, 'velocity': 60, 'time': 352.81666666666666}
# Edge: ('Bank and Monument', 'Tower Hill'), Data: {'length': 22620, 'line_name': 'District', 'flows': 22620, 'velocity': 60, 'time': 377.0}
# Edge: ('Bank and Monument', "St. Paul's"), Data: {'length': 38009, 'line_name': 'Central', 'flows': 38009, 'velocity': 60, 'time': 633.4833333333333}
# Edge: ('Bank and Monument', 'Waterloo'), Data: {'length': 213941, 'line_name': 'Waterloo & City', 'flows': 213941, 'velocity': 60, 'time': 3565.6833333333334}
# Edge: ('Bank and Monument', 'Moorgate'), Data: {'length': 78617, 'line_name': 'Northern', 'flows': 78617, 'velocity': 60, 'time': 1310.2833333333333}
# Edge: ('Bank and Monument', 'London Bridge'), Data: {'length': 48427, 'line_name': 'Northern', 'flows': 48427, 'velocity': 60, 'time': 807.1166666666667}
# Edge: ('Limehouse', 'Westferry'), Data: {'length': 12362, 'line_name': 'DLR', 'flows': 12362, 'velocity': 60, 'time': 206.03333333333333}
# Edge: ('Westferry', 'West India Quay'), Data: {'length': 6368, 'line_name': 'DLR', 'flows': 6368, 'velocity': 60, 'time': 106.13333333333334}
# Edge: ('Westferry', 'Poplar'), Data: {'length': 4573, 'line_name': 'DLR', 'flows': 4573, 'velocity': 60, 'time': 76.21666666666667}
# Edge: ('West India Quay', 'Canary Wharf'), Data: {'length': 9717, 'line_name': 'DLR', 'flows': 9717, 'velocity': 60, 'time': 161.95}
# Edge: ('West India Quay', 'Poplar'), Data: {'length': 3187, 'line_name': 'DLR', 'flows': 3187, 'velocity': 60, 'time': 53.11666666666667}
# Edge: ('Canary Wharf', 'Heron Quays'), Data: {'length': 24482, 'line_name': 'DLR', 'flows': 24482, 'velocity': 60, 'time': 408.03333333333336}
# Edge: ('Canary Wharf', 'North Greenwich'), Data: {'length': 29141, 'line_name': 'Jubilee', 'flows': 29141, 'velocity': 60, 'time': 485.68333333333334}
# Edge: ('Heron Quays', 'South Quay'), Data: {'length': 25055, 'line_name': 'DLR', 'flows': 25055, 'velocity': 60, 'time': 417.5833333333333}
# Edge: ('South Quay', 'Crossharbour'), Data: {'length': 21483, 'line_name': 'DLR', 'flows': 21483, 'velocity': 60, 'time': 358.05}
# Edge: ('Crossharbour', 'Mudchute'), Data: {'length': 19821, 'line_name': 'DLR', 'flows': 19821, 'velocity': 60, 'time': 330.35}
# Edge: ('Mudchute', 'Island Gardens'), Data: {'length': 18634, 'line_name': 'DLR', 'flows': 18634, 'velocity': 60, 'time': 310.56666666666666}
# Edge: ('Island Gardens', 'Cutty Sark'), Data: {'length': 17428, 'line_name': 'DLR', 'flows': 17428, 'velocity': 60, 'time': 290.46666666666664}
# Edge: ('Cutty Sark', 'Greenwich'), Data: {'length': 14480, 'line_name': 'DLR', 'flows': 14480, 'velocity': 60, 'time': 241.33333333333334}
# Edge: ('Greenwich', 'Deptford Bridge'), Data: {'length': 13695, 'line_name': 'DLR', 'flows': 13695, 'velocity': 60, 'time': 228.25}
# Edge: ('Deptford Bridge', 'Elverson Road'), Data: {'length': 11341, 'line_name': 'DLR', 'flows': 11341, 'velocity': 60, 'time': 189.01666666666668}
# Edge: ('Elverson Road', 'Lewisham'), Data: {'length': 10268, 'line_name': 'DLR', 'flows': 10268, 'velocity': 60, 'time': 171.13333333333333}
# Edge: ('Poplar', 'All Saints'), Data: {'length': 4189, 'line_name': 'DLR', 'flows': 4189, 'velocity': 60, 'time': 69.81666666666666}
# Edge: ('Poplar', 'Blackwall'), Data: {'length': 4097, 'line_name': 'DLR', 'flows': 4097, 'velocity': 60, 'time': 68.28333333333333}
# Edge: ('All Saints', 'Langdon Park'), Data: {'length': 4329, 'line_name': 'DLR', 'flows': 4329, 'velocity': 60, 'time': 72.15}
# Edge: ('Blackwall', 'East India'), Data: {'length': 3270, 'line_name': 'DLR', 'flows': 3270, 'velocity': 60, 'time': 54.5}
# Edge: ('Custom House', 'Prince Regent'), Data: {'length': 7305, 'line_name': 'DLR', 'flows': 7305, 'velocity': 60, 'time': 121.75}
# Edge: ('Prince Regent', 'Royal Albert'), Data: {'length': 5759, 'line_name': 'DLR', 'flows': 5759, 'velocity': 60, 'time': 95.98333333333333}
# Edge: ('Royal Albert', 'Beckton Park'), Data: {'length': 4511, 'line_name': 'DLR', 'flows': 4511, 'velocity': 60, 'time': 75.18333333333334}
# Edge: ('Beckton Park', 'Cyprus'), Data: {'length': 4140, 'line_name': 'DLR', 'flows': 4140, 'velocity': 60, 'time': 69.0}
# Edge: ('Cyprus', 'Gallions Reach'), Data: {'length': 2802, 'line_name': 'DLR', 'flows': 2802, 'velocity': 60, 'time': 46.7}
# Edge: ('Gallions Reach', 'Beckton'), Data: {'length': 1621, 'line_name': 'DLR', 'flows': 1621, 'velocity': 60, 'time': 27.016666666666666}
# Edge: ('Langdon Park', 'Devons Road'), Data: {'length': 4282, 'line_name': 'DLR', 'flows': 4282, 'velocity': 60, 'time': 71.36666666666666}
# Edge: ('Devons Road', 'Bow Church'), Data: {'length': 4576, 'line_name': 'DLR', 'flows': 4576, 'velocity': 60, 'time': 76.26666666666667}
# Edge: ('Bow Church', 'Pudding Mill Lane'), Data: {'length': 3620, 'line_name': 'DLR', 'flows': 3620, 'velocity': 60, 'time': 60.333333333333336}
# Edge: ('Woolwich Arsenal', 'King George V'), Data: {'length': 12320, 'line_name': 'DLR', 'flows': 12320, 'velocity': 60, 'time': 205.33333333333334}
# Edge: ('King George V', 'London City Airport'), Data: {'length': 13285, 'line_name': 'DLR', 'flows': 13285, 'velocity': 60, 'time': 221.41666666666666}
# Edge: ('West Silvertown', 'Pontoon Dock'), Data: {'length': 18747, 'line_name': 'DLR', 'flows': 18747, 'velocity': 60, 'time': 312.45}
# Edge: ('Pontoon Dock', 'London City Airport'), Data: {'length': 16218, 'line_name': 'DLR', 'flows': 16218, 'velocity': 60, 'time': 270.3}
# Edge: ('Wembley Park', 'Kingsbury'), Data: {'length': 12356, 'line_name': 'Jubilee', 'flows': 12356, 'velocity': 60, 'time': 205.93333333333334}
# Edge: ('Wembley Park', 'Neasden'), Data: {'length': 6744, 'line_name': 'Jubilee', 'flows': 6744, 'velocity': 60, 'time': 112.4}
# Edge: ('Wembley Park', 'Preston Road'), Data: {'length': 36608, 'line_name': 'Metropolitan', 'flows': 36608, 'velocity': 60, 'time': 610.1333333333333}
# Edge: ('Wembley Park', 'Finchley Road'), Data: {'length': 55223, 'line_name': 'Metropolitan', 'flows': 55223, 'velocity': 60, 'time': 920.3833333333333}
# Edge: ('Kingsbury', 'Queensbury'), Data: {'length': 9419, 'line_name': 'Jubilee', 'flows': 9419, 'velocity': 60, 'time': 156.98333333333332}
# Edge: ('Queensbury', 'Canons Park'), Data: {'length': 6385, 'line_name': 'Jubilee', 'flows': 6385, 'velocity': 60, 'time': 106.41666666666667}
# Edge: ('Canons Park', 'Stanmore'), Data: {'length': 3624, 'line_name': 'Jubilee', 'flows': 3624, 'velocity': 60, 'time': 60.4}
# Edge: ('Bermondsey', 'London Bridge'), Data: {'length': 79558, 'line_name': 'Jubilee', 'flows': 79558, 'velocity': 60, 'time': 1325.9666666666667}
# Edge: ('London Bridge', 'Southwark'), Data: {'length': 63202, 'line_name': 'Jubilee', 'flows': 63202, 'velocity': 60, 'time': 1053.3666666666666}
# Edge: ('London Bridge', 'Borough'), Data: {'length': 11620, 'line_name': 'Northern', 'flows': 11620, 'velocity': 60, 'time': 193.66666666666666}
# Edge: ('Southwark', 'Waterloo'), Data: {'length': 68620, 'line_name': 'Jubilee', 'flows': 68620, 'velocity': 60, 'time': 1143.6666666666667}
# Edge: ('Waterloo', 'Westminster'), Data: {'length': 215297, 'line_name': 'Jubilee', 'flows': 215297, 'velocity': 60, 'time': 3588.2833333333333}
# Edge: ('Waterloo', 'Embankment'), Data: {'length': 17097, 'line_name': 'Northern', 'flows': 17097, 'velocity': 60, 'time': 284.95}
# Edge: ('Waterloo', 'Lambeth North'), Data: {'length': 15112, 'line_name': 'Bakerloo', 'flows': 15112, 'velocity': 60, 'time': 251.86666666666667}
# Edge: ('Waterloo', 'Kennington'), Data: {'length': 50907, 'line_name': 'Northern', 'flows': 50907, 'velocity': 60, 'time': 848.45}
# Edge: ('Westminster', 'Green Park'), Data: {'length': 177652, 'line_name': 'Jubilee', 'flows': 177652, 'velocity': 60, 'time': 2960.866666666667}
# Edge: ('Westminster', "St. James's Park"), Data: {'length': 58339, 'line_name': 'District', 'flows': 58339, 'velocity': 60, 'time': 972.3166666666667}
# Edge: ('Westminster', 'Embankment'), Data: {'length': 16217, 'line_name': 'District', 'flows': 16217, 'velocity': 60, 'time': 270.28333333333336}
# Edge: ('Green Park', 'Bond Street'), Data: {'length': 130481, 'line_name': 'Jubilee', 'flows': 130481, 'velocity': 60, 'time': 2174.6833333333334}
# Edge: ('Green Park', 'Hyde Park Corner'), Data: {'length': 33643, 'line_name': 'Piccadilly', 'flows': 33643, 'velocity': 60, 'time': 560.7166666666667}
# Edge: ('Green Park', 'Piccadilly Circus'), Data: {'length': 20232, 'line_name': 'Piccadilly', 'flows': 20232, 'velocity': 60, 'time': 337.2}
# Edge: ('Green Park', 'Victoria'), Data: {'length': 130978, 'line_name': 'Victoria', 'flows': 130978, 'velocity': 60, 'time': 2182.9666666666667}
# Edge: ('Green Park', 'Oxford Circus'), Data: {'length': 132470, 'line_name': 'Victoria', 'flows': 132470, 'velocity': 60, 'time': 2207.8333333333335}
# Edge: ('Bond Street', 'Baker Street'), Data: {'length': 113780, 'line_name': 'Jubilee', 'flows': 113780, 'velocity': 60, 'time': 1896.3333333333333}
# Edge: ('Bond Street', 'Marble Arch'), Data: {'length': 28923, 'line_name': 'Central', 'flows': 28923, 'velocity': 60, 'time': 482.05}
# Edge: ('Bond Street', 'Oxford Circus'), Data: {'length': 17903, 'line_name': 'Central', 'flows': 17903, 'velocity': 60, 'time': 298.3833333333333}
# Edge: ('Baker Street', "St. John's Wood"), Data: {'length': 10477, 'line_name': 'Jubilee', 'flows': 10477, 'velocity': 60, 'time': 174.61666666666667}
# Edge: ('Baker Street', 'Great Portland Street'), Data: {'length': 47201, 'line_name': 'Hammersmith & City', 'flows': 47201, 'velocity': 60, 'time': 786.6833333333333}
# Edge: ('Baker Street', 'Finchley Road'), Data: {'length': 71701, 'line_name': 'Metropolitan', 'flows': 71701, 'velocity': 60, 'time': 1195.0166666666667}
# Edge: ('Baker Street', 'Edgware Road'), Data: {'length': 63303, 'line_name': 'Hammersmith & City', 'flows': 63303, 'velocity': 60, 'time': 1055.05}
# Edge: ('Baker Street', 'Marylebone'), Data: {'length': 9148, 'line_name': 'Bakerloo', 'flows': 9148, 'velocity': 60, 'time': 152.46666666666667}
# Edge: ('Baker Street', "Regent's Park"), Data: {'length': 953, 'line_name': 'Bakerloo', 'flows': 953, 'velocity': 60, 'time': 15.883333333333333}
# Edge: ("St. John's Wood", 'Swiss Cottage'), Data: {'length': 5975, 'line_name': 'Jubilee', 'flows': 5975, 'velocity': 60, 'time': 99.58333333333333}
# Edge: ('Swiss Cottage', 'Finchley Road'), Data: {'length': 2736, 'line_name': 'Jubilee', 'flows': 2736, 'velocity': 60, 'time': 45.6}
# Edge: ('Neasden', 'Dollis Hill'), Data: {'length': 4019, 'line_name': 'Jubilee', 'flows': 4019, 'velocity': 60, 'time': 66.98333333333333}
# Edge: ('Dollis Hill', 'Willesden Green'), Data: {'length': 1482, 'line_name': 'Jubilee', 'flows': 1482, 'velocity': 60, 'time': 24.7}
# Edge: ('Willesden Green', 'Kilburn'), Data: {'length': 6029, 'line_name': 'Jubilee', 'flows': 6029, 'velocity': 60, 'time': 100.48333333333333}
# Edge: ('Uxbridge', 'Hillingdon'), Data: {'length': 7080, 'line_name': 'Piccadilly', 'flows': 7080, 'velocity': 60, 'time': 118.0}
# Edge: ('Hillingdon', 'Ickenham'), Data: {'length': 8453, 'line_name': 'Piccadilly', 'flows': 8453, 'velocity': 60, 'time': 140.88333333333333}
# Edge: ('Ickenham', 'Ruislip'), Data: {'length': 8984, 'line_name': 'Piccadilly', 'flows': 8984, 'velocity': 60, 'time': 149.73333333333332}
# Edge: ('Ruislip', 'Ruislip Manor'), Data: {'length': 9700, 'line_name': 'Piccadilly', 'flows': 9700, 'velocity': 60, 'time': 161.66666666666666}
# Edge: ('Ruislip Manor', 'Eastcote'), Data: {'length': 10497, 'line_name': 'Piccadilly', 'flows': 10497, 'velocity': 60, 'time': 174.95}
# Edge: ('Eastcote', 'Rayners Lane'), Data: {'length': 12414, 'line_name': 'Piccadilly', 'flows': 12414, 'velocity': 60, 'time': 206.9}
# Edge: ('Rayners Lane', 'West Harrow'), Data: {'length': 13798, 'line_name': 'Metropolitan', 'flows': 13798, 'velocity': 60, 'time': 229.96666666666667}
# Edge: ('Rayners Lane', 'South Harrow'), Data: {'length': 5268, 'line_name': 'Piccadilly', 'flows': 5268, 'velocity': 60, 'time': 87.8}
# Edge: ('West Harrow', 'Harrow-on-the-Hill'), Data: {'length': 14429, 'line_name': 'Metropolitan', 'flows': 14429, 'velocity': 60, 'time': 240.48333333333332}
# Edge: ('Aldgate', 'Tower Hill'), Data: {'length': 4767, 'line_name': 'Circle', 'flows': 4767, 'velocity': 60, 'time': 79.45}
# Edge: ('Great Portland Street', 'Euston Square'), Data: {'length': 47121, 'line_name': 'Hammersmith & City', 'flows': 47121, 'velocity': 60, 'time': 785.35}
# Edge: ('Euston Square', "King's Cross St. Pancras"), Data: {'length': 49766, 'line_name': 'Hammersmith & City', 'flows': 49766, 'velocity': 60, 'time': 829.4333333333333}
# Edge: ("King's Cross St. Pancras", 'Farringdon'), Data: {'length': 103014, 'line_name': 'Hammersmith & City', 'flows': 103014, 'velocity': 60, 'time': 1716.9}
# Edge: ("King's Cross St. Pancras", 'Russell Square'), Data: {'length': 23189, 'line_name': 'Piccadilly', 'flows': 23189, 'velocity': 60, 'time': 386.48333333333335}
# Edge: ("King's Cross St. Pancras", 'Caledonian Road'), Data: {'length': 9962, 'line_name': 'Piccadilly', 'flows': 9962, 'velocity': 60, 'time': 166.03333333333333}
# Edge: ("King's Cross St. Pancras", 'Angel'), Data: {'length': 13854, 'line_name': 'Northern', 'flows': 13854, 'velocity': 60, 'time': 230.9}
# Edge: ('Farringdon', 'Barbican'), Data: {'length': 96782, 'line_name': 'Hammersmith & City', 'flows': 96782, 'velocity': 60, 'time': 1613.0333333333333}
# Edge: ('Barbican', 'Moorgate'), Data: {'length': 95939, 'line_name': 'Hammersmith & City', 'flows': 95939, 'velocity': 60, 'time': 1598.9833333333333}
# Edge: ('Moorgate', 'Old Street'), Data: {'length': 19409, 'line_name': 'Northern', 'flows': 19409, 'velocity': 60, 'time': 323.48333333333335}
# Edge: ('Harrow-on-the-Hill', 'North Harrow'), Data: {'length': 15498, 'line_name': 'Metropolitan', 'flows': 15498, 'velocity': 60, 'time': 258.3}
# Edge: ('Harrow-on-the-Hill', 'Northwick Park'), Data: {'length': 33032, 'line_name': 'Metropolitan', 'flows': 33032, 'velocity': 60, 'time': 550.5333333333333}
# Edge: ('Amersham', 'Chalfont & Latimer'), Data: {'length': 1446, 'line_name': 'Metropolitan', 'flows': 1446, 'velocity': 60, 'time': 24.1}
# Edge: ('Chalfont & Latimer', 'Chorleywood'), Data: {'length': 3319, 'line_name': 'Metropolitan', 'flows': 3319, 'velocity': 60, 'time': 55.31666666666667}
# Edge: ('Chalfont & Latimer', 'Chesham'), Data: {'length': 1175, 'line_name': 'Metropolitan', 'flows': 1175, 'velocity': 60, 'time': 19.583333333333332}
# Edge: ('Chorleywood', 'Rickmansworth'), Data: {'length': 4587, 'line_name': 'Metropolitan', 'flows': 4587, 'velocity': 60, 'time': 76.45}
# Edge: ('Rickmansworth', 'Moor Park'), Data: {'length': 5990, 'line_name': 'Metropolitan', 'flows': 5990, 'velocity': 60, 'time': 99.83333333333333}
# Edge: ('Moor Park', 'Northwood'), Data: {'length': 9606, 'line_name': 'Metropolitan', 'flows': 9606, 'velocity': 60, 'time': 160.1}
# Edge: ('Moor Park', 'Croxley'), Data: {'length': 3414, 'line_name': 'Metropolitan', 'flows': 3414, 'velocity': 60, 'time': 56.9}
# Edge: ('Northwood', 'Northwood Hills'), Data: {'length': 11621, 'line_name': 'Metropolitan', 'flows': 11621, 'velocity': 60, 'time': 193.68333333333334}
# Edge: ('Northwood Hills', 'Pinner'), Data: {'length': 12581, 'line_name': 'Metropolitan', 'flows': 12581, 'velocity': 60, 'time': 209.68333333333334}
# Edge: ('Pinner', 'North Harrow'), Data: {'length': 14326, 'line_name': 'Metropolitan', 'flows': 14326, 'velocity': 60, 'time': 238.76666666666668}
# Edge: ('Northwick Park', 'Preston Road'), Data: {'length': 35297, 'line_name': 'Metropolitan', 'flows': 35297, 'velocity': 60, 'time': 588.2833333333333}
# Edge: ('Croxley', 'Watford'), Data: {'length': 2361, 'line_name': 'Metropolitan', 'flows': 2361, 'velocity': 60, 'time': 39.35}
# Edge: ('South Kensington', 'Sloane Square'), Data: {'length': 81301, 'line_name': 'District', 'flows': 81301, 'velocity': 60, 'time': 1355.0166666666667}
# Edge: ('South Kensington', 'Gloucester Road'), Data: {'length': 100342, 'line_name': 'Piccadilly', 'flows': 100342, 'velocity': 60, 'time': 1672.3666666666666}
# Edge: ('South Kensington', 'Knightsbridge'), Data: {'length': 29412, 'line_name': 'Piccadilly', 'flows': 29412, 'velocity': 60, 'time': 490.2}
# Edge: ('Sloane Square', 'Victoria'), Data: {'length': 87777, 'line_name': 'District', 'flows': 87777, 'velocity': 60, 'time': 1462.95}
# Edge: ('Gloucester Road', 'High Street Kensington'), Data: {'length': 6926, 'line_name': 'Circle', 'flows': 6926, 'velocity': 60, 'time': 115.43333333333334}
# Edge: ('Gloucester Road', "Earl's Court"), Data: {'length': 89401, 'line_name': 'Piccadilly', 'flows': 89401, 'velocity': 60, 'time': 1490.0166666666667}
# Edge: ('High Street Kensington', 'Notting Hill Gate'), Data: {'length': 20618, 'line_name': 'District', 'flows': 20618, 'velocity': 60, 'time': 343.6333333333333}
# Edge: ('High Street Kensington', "Earl's Court"), Data: {'length': 17018, 'line_name': 'District', 'flows': 17018, 'velocity': 60, 'time': 283.6333333333333}
# Edge: ('Notting Hill Gate', 'Bayswater'), Data: {'length': 22114, 'line_name': 'District', 'flows': 22114, 'velocity': 60, 'time': 368.56666666666666}
# Edge: ('Notting Hill Gate', 'Holland Park'), Data: {'length': 15921, 'line_name': 'Central', 'flows': 15921, 'velocity': 60, 'time': 265.35}
# Edge: ('Notting Hill Gate', 'Queensway'), Data: {'length': 16512, 'line_name': 'Central', 'flows': 16512, 'velocity': 60, 'time': 275.2}
# Edge: ('Bayswater', 'Paddington'), Data: {'length': 21706, 'line_name': 'District', 'flows': 21706, 'velocity': 60, 'time': 361.76666666666665}
# Edge: ('Paddington', 'Edgware Road'), Data: {'length': 60513, 'line_name': 'Bakerloo', 'flows': 60513, 'velocity': 60, 'time': 1008.55}
# Edge: ('Paddington', 'Royal Oak'), Data: {'length': 11508, 'line_name': 'Hammersmith & City', 'flows': 11508, 'velocity': 60, 'time': 191.8}
# Edge: ('Paddington', 'Warwick Avenue'), Data: {'length': 6534, 'line_name': 'Bakerloo', 'flows': 6534, 'velocity': 60, 'time': 108.9}
# Edge: ('Edgware Road', 'Marylebone'), Data: {'length': 1227, 'line_name': 'Bakerloo', 'flows': 1227, 'velocity': 60, 'time': 20.45}
# Edge: ('Victoria', "St. James's Park"), Data: {'length': 52097, 'line_name': 'District', 'flows': 52097, 'velocity': 60, 'time': 868.2833333333333}
# Edge: ('Victoria', 'Pimlico'), Data: {'length': 75182, 'line_name': 'Victoria', 'flows': 75182, 'velocity': 60, 'time': 1253.0333333333333}
# Edge: ('Embankment', 'Temple'), Data: {'length': 17749, 'line_name': 'District', 'flows': 17749, 'velocity': 60, 'time': 295.81666666666666}
# Edge: ('Embankment', 'Charing Cross'), Data: {'length': 7380, 'line_name': 'Northern', 'flows': 7380, 'velocity': 60, 'time': 123.0}
# Edge: ('Temple', 'Blackfriars'), Data: {'length': 11586, 'line_name': 'District', 'flows': 11586, 'velocity': 60, 'time': 193.1}
# Edge: ('Blackfriars', 'Mansion House'), Data: {'length': 7674, 'line_name': 'District', 'flows': 7674, 'velocity': 60, 'time': 127.9}
# Edge: ('Mansion House', 'Cannon Street'), Data: {'length': 14345, 'line_name': 'District', 'flows': 14345, 'velocity': 60, 'time': 239.08333333333334}
# Edge: ('Tower Hill', 'Aldgate East'), Data: {'length': 4642, 'line_name': 'District', 'flows': 4642, 'velocity': 60, 'time': 77.36666666666666}
# Edge: ('Hammersmith', 'Goldhawk Road'), Data: {'length': 5563, 'line_name': 'Hammersmith & City', 'flows': 5563, 'velocity': 60, 'time': 92.71666666666667}
# Edge: ('Hammersmith', 'Barons Court'), Data: {'length': 63763, 'line_name': 'Piccadilly', 'flows': 63763, 'velocity': 60, 'time': 1062.7166666666667}
# Edge: ('Hammersmith', 'Ravenscourt Park'), Data: {'length': 4414, 'line_name': 'District', 'flows': 4414, 'velocity': 60, 'time': 73.56666666666666}
# Edge: ('Hammersmith', 'Turnham Green'), Data: {'length': 48728, 'line_name': 'Piccadilly', 'flows': 48728, 'velocity': 60, 'time': 812.1333333333333}
# Edge: ('Goldhawk Road', "Shepherd's Bush Market"), Data: {'length': 4280, 'line_name': 'Hammersmith & City', 'flows': 4280, 'velocity': 60, 'time': 71.33333333333333}
# Edge: ("Shepherd's Bush Market", 'Wood Lane'), Data: {'length': 4892, 'line_name': 'Hammersmith & City', 'flows': 4892, 'velocity': 60, 'time': 81.53333333333333}
# Edge: ('Wood Lane', 'Latimer Road'), Data: {'length': 5984, 'line_name': 'Hammersmith & City', 'flows': 5984, 'velocity': 60, 'time': 99.73333333333333}
# Edge: ('Latimer Road', 'Ladbroke Grove'), Data: {'length': 6632, 'line_name': 'Hammersmith & City', 'flows': 6632, 'velocity': 60, 'time': 110.53333333333333}
# Edge: ('Ladbroke Grove', 'Westbourne Park'), Data: {'length': 8736, 'line_name': 'Hammersmith & City', 'flows': 8736, 'velocity': 60, 'time': 145.6}
# Edge: ('Westbourne Park', 'Royal Oak'), Data: {'length': 10395, 'line_name': 'Hammersmith & City', 'flows': 10395, 'velocity': 60, 'time': 173.25}
# Edge: ('Stepney Green', 'Mile End'), Data: {'length': 9182, 'line_name': 'District', 'flows': 9182, 'velocity': 60, 'time': 153.03333333333333}
# Edge: ('Mile End', 'Bow Road'), Data: {'length': 4964, 'line_name': 'District', 'flows': 4964, 'velocity': 60, 'time': 82.73333333333333}
# Edge: ('Bow Road', 'Bromley-by-Bow'), Data: {'length': 1484, 'line_name': 'District', 'flows': 1484, 'velocity': 60, 'time': 24.733333333333334}
# Edge: ('Plaistow', 'Upton Park'), Data: {'length': 30835, 'line_name': 'District', 'flows': 30835, 'velocity': 60, 'time': 513.9166666666666}
# Edge: ('Upton Park', 'East Ham'), Data: {'length': 25446, 'line_name': 'District', 'flows': 25446, 'velocity': 60, 'time': 424.1}
# Edge: ("Earl's Court", 'West Kensington'), Data: {'length': 3196, 'line_name': 'District', 'flows': 3196, 'velocity': 60, 'time': 53.266666666666666}
# Edge: ("Earl's Court", 'Barons Court'), Data: {'length': 66333, 'line_name': 'Piccadilly', 'flows': 66333, 'velocity': 60, 'time': 1105.55}
# Edge: ('West Kensington', 'Barons Court'), Data: {'length': 864, 'line_name': 'District', 'flows': 864, 'velocity': 60, 'time': 14.4}
# Edge: ('Ravenscourt Park', 'Stamford Brook'), Data: {'length': 2595, 'line_name': 'District', 'flows': 2595, 'velocity': 60, 'time': 43.25}
# Edge: ('Stamford Brook', 'Turnham Green'), Data: {'length': 1652, 'line_name': 'District', 'flows': 1652, 'velocity': 60, 'time': 27.533333333333335}
# Edge: ('Turnham Green', 'Chiswick Park'), Data: {'length': 1710, 'line_name': 'District', 'flows': 1710, 'velocity': 60, 'time': 28.5}
# Edge: ('Turnham Green', 'Acton Town'), Data: {'length': 42463, 'line_name': 'Piccadilly', 'flows': 42463, 'velocity': 60, 'time': 707.7166666666667}
# Edge: ('Chiswick Park', 'Acton Town'), Data: {'length': 1090, 'line_name': 'District', 'flows': 1090, 'velocity': 60, 'time': 18.166666666666668}
# Edge: ('Acton Town', 'Ealing Common'), Data: {'length': 21572, 'line_name': 'Piccadilly', 'flows': 21572, 'velocity': 60, 'time': 359.53333333333336}
# Edge: ('Acton Town', 'South Ealing'), Data: {'length': 23406, 'line_name': 'Piccadilly', 'flows': 23406, 'velocity': 60, 'time': 390.1}
# Edge: ('Ealing Common', 'Ealing Broadway'), Data: {'length': 12203, 'line_name': 'District', 'flows': 12203, 'velocity': 60, 'time': 203.38333333333333}
# ...
# Edge: ('Turnpike Lane', 'Wood Green'), Data: {'length': 22737, 'line_name': 'Piccadilly', 'flows': 22737, 'velocity': 60, 'time': 378.95}
# Edge: ('Wood Green', 'Bounds Green'), Data: {'length': 15448, 'line_name': 'Piccadilly', 'flows': 15448, 'velocity': 60, 'time': 257.46666666666664}
# Edge: ('Bounds Green', 'Arnos Grove'), Data: {'length': 10697, 'line_name': 'Piccadilly', 'flows': 10697, 'velocity': 60, 'time': 178.28333333333333}
# Edge: ('Arnos Grove', 'Southgate'), Data: {'length': 7501, 'line_name': 'Piccadilly', 'flows': 7501, 'velocity': 60, 'time': 125.01666666666667}
# Edge: ('Southgate', 'Oakwood'), Data: {'length': 3391, 'line_name': 'Piccadilly', 'flows': 3391, 'velocity': 60, 'time': 56.516666666666666}
# Edge: ('Oakwood', 'Cockfosters'), Data: {'length': 1262, 'line_name': 'Piccadilly', 'flows': 1262, 'velocity': 60, 'time': 21.033333333333335}
# Edge: ('South Harrow', 'Sudbury Hill'), Data: {'length': 6011, 'line_name': 'Piccadilly', 'flows': 6011, 'velocity': 60, 'time': 100.18333333333334}
# Edge: ('Sudbury Hill', 'Sudbury Town'), Data: {'length': 6301, 'line_name': 'Piccadilly', 'flows': 6301, 'velocity': 60, 'time': 105.01666666666667}
# Edge: ('Sudbury Town', 'Alperton'), Data: {'length': 6832, 'line_name': 'Piccadilly', 'flows': 6832, 'velocity': 60, 'time': 113.86666666666666}
# Edge: ('Alperton', 'Park Royal'), Data: {'length': 7665, 'line_name': 'Piccadilly', 'flows': 7665, 'velocity': 60, 'time': 127.75}
# Edge: ('Park Royal', 'North Ealing'), Data: {'length': 8454, 'line_name': 'Piccadilly', 'flows': 8454, 'velocity': 60, 'time': 140.9}
# Edge: ('Heathrow Terminal 4', 'Hatton Cross'), Data: {'length': 1194, 'line_name': 'Piccadilly', 'flows': 1194, 'velocity': 60, 'time': 19.9}
# Edge: ('Heathrow Terminal 4', 'Heathrow Terminals 2 & 3'), Data: {'length': 310, 'line_name': 'Piccadilly', 'flows': 310, 'velocity': 60, 'time': 5.166666666666667}
# Edge: ('Hatton Cross', 'Heathrow Terminals 2 & 3'), Data: {'length': 5964, 'line_name': 'Piccadilly', 'flows': 5964, 'velocity': 60, 'time': 99.4}
# Edge: ('Hatton Cross', 'Hounslow West'), Data: {'length': 9260, 'line_name': 'Piccadilly', 'flows': 9260, 'velocity': 60, 'time': 154.33333333333334}
# Edge: ('Heathrow Terminals 2 & 3', 'Heathrow Terminal 5'), Data: {'length': 1913, 'line_name': 'Piccadilly', 'flows': 1913, 'velocity': 60, 'time': 31.883333333333333}
# Edge: ('Hounslow West', 'Hounslow Central'), Data: {'length': 11234, 'line_name': 'Piccadilly', 'flows': 11234, 'velocity': 60, 'time': 187.23333333333332}
# Edge: ('Hounslow Central', 'Hounslow East'), Data: {'length': 13469, 'line_name': 'Piccadilly', 'flows': 13469, 'velocity': 60, 'time': 224.48333333333332}
# Edge: ('Hounslow East', 'Osterley'), Data: {'length': 15935, 'line_name': 'Piccadilly', 'flows': 15935, 'velocity': 60, 'time': 265.5833333333333}
# Edge: ('Osterley', 'Boston Manor'), Data: {'length': 17445, 'line_name': 'Piccadilly', 'flows': 17445, 'velocity': 60, 'time': 290.75}
# Edge: ('Boston Manor', 'Northfields'), Data: {'length': 18598, 'line_name': 'Piccadilly', 'flows': 18598, 'velocity': 60, 'time': 309.96666666666664}
# Edge: ('West Acton', 'North Acton'), Data: {'length': 7580, 'line_name': 'Central', 'flows': 7580, 'velocity': 60, 'time': 126.33333333333333}
# Edge: ('North Acton', 'Hanger Lane'), Data: {'length': 14837, 'line_name': 'Central', 'flows': 14837, 'velocity': 60, 'time': 247.28333333333333}
# Edge: ('North Acton', 'East Acton'), Data: {'length': 24621, 'line_name': 'Central', 'flows': 24621, 'velocity': 60, 'time': 410.35}
# Edge: ('West Ruislip', 'Ruislip Gardens'), Data: {'length': 1277, 'line_name': 'Central', 'flows': 1277, 'velocity': 60, 'time': 21.283333333333335}
# Edge: ('Ruislip Gardens', 'South Ruislip'), Data: {'length': 2279, 'line_name': 'Central', 'flows': 2279, 'velocity': 60, 'time': 37.983333333333334}
# Edge: ('South Ruislip', 'Northolt'), Data: {'length': 3810, 'line_name': 'Central', 'flows': 3810, 'velocity': 60, 'time': 63.5}
# Edge: ('Northolt', 'Greenford'), Data: {'length': 7682, 'line_name': 'Central', 'flows': 7682, 'velocity': 60, 'time': 128.03333333333333}
# Edge: ('Greenford', 'Perivale'), Data: {'length': 10792, 'line_name': 'Central', 'flows': 10792, 'velocity': 60, 'time': 179.86666666666667}
# Edge: ('Perivale', 'Hanger Lane'), Data: {'length': 12330, 'line_name': 'Central', 'flows': 12330, 'velocity': 60, 'time': 205.5}
# Edge: ('East Acton', 'White City'), Data: {'length': 26292, 'line_name': 'Central', 'flows': 26292, 'velocity': 60, 'time': 438.2}
# Edge: ('Queensway', 'Lancaster Gate'), Data: {'length': 20006, 'line_name': 'Central', 'flows': 20006, 'velocity': 60, 'time': 333.43333333333334}
# Edge: ('Lancaster Gate', 'Marble Arch'), Data: {'length': 24274, 'line_name': 'Central', 'flows': 24274, 'velocity': 60, 'time': 404.56666666666666}
# Edge: ('Oxford Circus', 'Tottenham Court Road'), Data: {'length': 30017, 'line_name': 'Central', 'flows': 30017, 'velocity': 60, 'time': 500.28333333333336}
# Edge: ('Oxford Circus', "Regent's Park"), Data: {'length': 2782, 'line_name': 'Bakerloo', 'flows': 2782, 'velocity': 60, 'time': 46.36666666666667}
# Edge: ('Oxford Circus', 'Warren Street'), Data: {'length': 118412, 'line_name': 'Victoria', 'flows': 118412, 'velocity': 60, 'time': 1973.5333333333333}
# Edge: ('Tottenham Court Road', 'Goodge Street'), Data: {'length': 4298, 'line_name': 'Northern', 'flows': 4298, 'velocity': 60, 'time': 71.63333333333334}
# Edge: ('Chancery Lane', "St. Paul's"), Data: {'length': 28921, 'line_name': 'Central', 'flows': 28921, 'velocity': 60, 'time': 482.01666666666665}
# Edge: ('Leyton', 'Leytonstone'), Data: {'length': 48704, 'line_name': 'Central', 'flows': 48704, 'velocity': 60, 'time': 811.7333333333333}
# Edge: ('Leytonstone', 'Snaresbrook'), Data: {'length': 22990, 'line_name': 'Central', 'flows': 22990, 'velocity': 60, 'time': 383.1666666666667}
# Edge: ('Leytonstone', 'Wanstead'), Data: {'length': 19670, 'line_name': 'Central', 'flows': 19670, 'velocity': 60, 'time': 327.8333333333333}
# Edge: ('Snaresbrook', 'South Woodford'), Data: {'length': 21268, 'line_name': 'Central', 'flows': 21268, 'velocity': 60, 'time': 354.46666666666664}
# Edge: ('South Woodford', 'Woodford'), Data: {'length': 17198, 'line_name': 'Central', 'flows': 17198, 'velocity': 60, 'time': 286.6333333333333}
# Edge: ('Woodford', 'Buckhurst Hill'), Data: {'length': 10634, 'line_name': 'Central', 'flows': 10634, 'velocity': 60, 'time': 177.23333333333332}
# Edge: ('Woodford', 'Roding Valley'), Data: {'length': 2132, 'line_name': 'Central', 'flows': 2132, 'velocity': 60, 'time': 35.53333333333333}
# Edge: ('Buckhurst Hill', 'Loughton'), Data: {'length': 9118, 'line_name': 'Central', 'flows': 9118, 'velocity': 60, 'time': 151.96666666666667}
# Edge: ('Loughton', 'Debden'), Data: {'length': 6185, 'line_name': 'Central', 'flows': 6185, 'velocity': 60, 'time': 103.08333333333333}
# Edge: ('Debden', 'Theydon Bois'), Data: {'length': 4072, 'line_name': 'Central', 'flows': 4072, 'velocity': 60, 'time': 67.86666666666666}
# Edge: ('Theydon Bois', 'Epping'), Data: {'length': 3397, 'line_name': 'Central', 'flows': 3397, 'velocity': 60, 'time': 56.61666666666667}
# Edge: ('Wanstead', 'Redbridge'), Data: {'length': 17788, 'line_name': 'Central', 'flows': 17788, 'velocity': 60, 'time': 296.46666666666664}
# Edge: ('Redbridge', 'Gants Hill'), Data: {'length': 15670, 'line_name': 'Central', 'flows': 15670, 'velocity': 60, 'time': 261.1666666666667}
# Edge: ('Gants Hill', 'Newbury Park'), Data: {'length': 10086, 'line_name': 'Central', 'flows': 10086, 'velocity': 60, 'time': 168.1}
# Edge: ('Newbury Park', 'Barkingside'), Data: {'length': 5715, 'line_name': 'Central', 'flows': 5715, 'velocity': 60, 'time': 95.25}
# Edge: ('Barkingside', 'Fairlop'), Data: {'length': 4224, 'line_name': 'Central', 'flows': 4224, 'velocity': 60, 'time': 70.4}
# Edge: ('Fairlop', 'Hainault'), Data: {'length': 3129, 'line_name': 'Central', 'flows': 3129, 'velocity': 60, 'time': 52.15}
# Edge: ('Hainault', 'Grange Hill'), Data: {'length': 504, 'line_name': 'Central', 'flows': 504, 'velocity': 60, 'time': 8.4}
# Edge: ('Grange Hill', 'Chigwell'), Data: {'length': 1184, 'line_name': 'Central', 'flows': 1184, 'velocity': 60, 'time': 19.733333333333334}
# Edge: ('Chigwell', 'Roding Valley'), Data: {'length': 1757, 'line_name': 'Central', 'flows': 1757, 'velocity': 60, 'time': 29.283333333333335}
# Edge: ('Kilburn Park', 'Maida Vale'), Data: {'length': 3397, 'line_name': 'Bakerloo', 'flows': 3397, 'velocity': 60, 'time': 56.61666666666667}
# Edge: ('Maida Vale', 'Warwick Avenue'), Data: {'length': 3994, 'line_name': 'Bakerloo', 'flows': 3994, 'velocity': 60, 'time': 66.56666666666666}
# Edge: ('Lambeth North', 'Elephant & Castle'), Data: {'length': 12867, 'line_name': 'Bakerloo', 'flows': 12867, 'velocity': 60, 'time': 214.45}
# Edge: ('Elephant & Castle', 'Borough'), Data: {'length': 9804, 'line_name': 'Northern', 'flows': 9804, 'velocity': 60, 'time': 163.4}
# Edge: ('Elephant & Castle', 'Kennington'), Data: {'length': 10633, 'line_name': 'Northern', 'flows': 10633, 'velocity': 60, 'time': 177.21666666666667}
# Edge: ('Maryland', 'Forest Gate'), Data: {'length': 33938, 'line_name': 'TfL Rail', 'flows': 33938, 'velocity': 60, 'time': 565.6333333333333}
# Edge: ('Forest Gate', 'Manor Park'), Data: {'length': 31879, 'line_name': 'TfL Rail', 'flows': 31879, 'velocity': 60, 'time': 531.3166666666667}
# Edge: ('Manor Park', 'Ilford'), Data: {'length': 30542, 'line_name': 'TfL Rail', 'flows': 30542, 'velocity': 60, 'time': 509.03333333333336}
# Edge: ('Ilford', 'Seven Kings'), Data: {'length': 25313, 'line_name': 'TfL Rail', 'flows': 25313, 'velocity': 60, 'time': 421.8833333333333}
# Edge: ('Seven Kings', 'Goodmayes'), Data: {'length': 21970, 'line_name': 'TfL Rail', 'flows': 21970, 'velocity': 60, 'time': 366.1666666666667}
# Edge: ('Goodmayes', 'Chadwell Heath'), Data: {'length': 18594, 'line_name': 'TfL Rail', 'flows': 18594, 'velocity': 60, 'time': 309.9}
# Edge: ('Gidea Park', 'Harold Wood'), Data: {'length': 5522, 'line_name': 'TfL Rail', 'flows': 5522, 'velocity': 60, 'time': 92.03333333333333}
# Edge: ('Harold Wood', 'Brentwood'), Data: {'length': 2789, 'line_name': 'TfL Rail', 'flows': 2789, 'velocity': 60, 'time': 46.483333333333334}
# Edge: ('Brentwood', 'Shenfield'), Data: {'length': 1181, 'line_name': 'TfL Rail', 'flows': 1181, 'velocity': 60, 'time': 19.683333333333334}
# Edge: ('Brixton', 'Stockwell'), Data: {'length': 28465, 'line_name': 'Victoria', 'flows': 28465, 'velocity': 60, 'time': 474.4166666666667}
# Edge: ('Stockwell', 'Vauxhall'), Data: {'length': 55294, 'line_name': 'Victoria', 'flows': 55294, 'velocity': 60, 'time': 921.5666666666667}
# Edge: ('Stockwell', 'Oval'), Data: {'length': 54283, 'line_name': 'Northern', 'flows': 54283, 'velocity': 60, 'time': 904.7166666666667}
# Edge: ('Stockwell', 'Clapham North'), Data: {'length': 59928, 'line_name': 'Northern', 'flows': 59928, 'velocity': 60, 'time': 998.8}
# Edge: ('Vauxhall', 'Pimlico'), Data: {'length': 68732, 'line_name': 'Victoria', 'flows': 68732, 'velocity': 60, 'time': 1145.5333333333333}
# Edge: ('Warren Street', 'Goodge Street'), Data: {'length': 2525, 'line_name': 'Northern', 'flows': 2525, 'velocity': 60, 'time': 42.083333333333336}
# Edge: ('Edgware', 'Burnt Oak'), Data: {'length': 4177, 'line_name': 'Northern', 'flows': 4177, 'velocity': 60, 'time': 69.61666666666666}
# Edge: ('Burnt Oak', 'Colindale'), Data: {'length': 7651, 'line_name': 'Northern', 'flows': 7651, 'velocity': 60, 'time': 127.51666666666667}
# Edge: ('Colindale', 'Hendon Central'), Data: {'length': 14377, 'line_name': 'Northern', 'flows': 14377, 'velocity': 60, 'time': 239.61666666666667}
# Edge: ('Hendon Central', 'Brent Cross'), Data: {'length': 19124, 'line_name': 'Northern', 'flows': 19124, 'velocity': 60, 'time': 318.73333333333335}
# Edge: ('Brent Cross', 'Golders Green'), Data: {'length': 20220, 'line_name': 'Northern', 'flows': 20220, 'velocity': 60, 'time': 337.0}
# Edge: ('Golders Green', 'Hampstead'), Data: {'length': 24767, 'line_name': 'Northern', 'flows': 24767, 'velocity': 60, 'time': 412.78333333333336}
# Edge: ('Hampstead', 'Belsize Park'), Data: {'length': 27009, 'line_name': 'Northern', 'flows': 27009, 'velocity': 60, 'time': 450.15}
# Edge: ('Belsize Park', 'Chalk Farm'), Data: {'length': 30238, 'line_name': 'Northern', 'flows': 30238, 'velocity': 60, 'time': 503.96666666666664}
# Edge: ('Chalk Farm', 'Camden Town'), Data: {'length': 33160, 'line_name': 'Northern', 'flows': 33160, 'velocity': 60, 'time': 552.6666666666666}
# Edge: ('Camden Town', 'Kentish Town'), Data: {'length': 40446, 'line_name': 'Northern', 'flows': 40446, 'velocity': 60, 'time': 674.1}
# Edge: ('Camden Town', 'Mornington Crescent'), Data: {'length': 1076, 'line_name': 'Northern', 'flows': 1076, 'velocity': 60, 'time': 17.933333333333334}
# Edge: ('Angel', 'Old Street'), Data: {'length': 15058, 'line_name': 'Northern', 'flows': 15058, 'velocity': 60, 'time': 250.96666666666667}
# Edge: ('Kennington', 'Oval'), Data: {'length': 57626, 'line_name': 'Northern', 'flows': 57626, 'velocity': 60, 'time': 960.4333333333333}
# Edge: ('Kennington', 'Nine Elms'), Data: {'length': 0, 'line_name': 'Northern', 'flows': 0, 'velocity': 60, 'time': 0.0}
# Edge: ('Clapham North', 'Clapham Common'), Data: {'length': 57688, 'line_name': 'Northern', 'flows': 57688, 'velocity': 60, 'time': 961.4666666666667}
# Edge: ('Clapham Common', 'Clapham South'), Data: {'length': 52799, 'line_name': 'Northern', 'flows': 52799, 'velocity': 60, 'time': 879.9833333333333}
# Edge: ('Clapham South', 'Balham'), Data: {'length': 46040, 'line_name': 'Northern', 'flows': 46040, 'velocity': 60, 'time': 767.3333333333334}
# Edge: ('Balham', 'Tooting Bec'), Data: {'length': 37941, 'line_name': 'Northern', 'flows': 37941, 'velocity': 60, 'time': 632.35}
# Edge: ('Tooting Bec', 'Tooting Broadway'), Data: {'length': 31330, 'line_name': 'Northern', 'flows': 31330, 'velocity': 60, 'time': 522.1666666666666}
# Edge: ('Tooting Broadway', 'Colliers Wood'), Data: {'length': 20004, 'line_name': 'Northern', 'flows': 20004, 'velocity': 60, 'time': 333.4}
# Edge: ('Colliers Wood', 'South Wimbledon'), Data: {'length': 14194, 'line_name': 'Northern', 'flows': 14194, 'velocity': 60, 'time': 236.56666666666666}
# Edge: ('South Wimbledon', 'Morden'), Data: {'length': 9482, 'line_name': 'Northern', 'flows': 9482, 'velocity': 60, 'time': 158.03333333333333}
# Edge: ('Finchley Central', 'Mill Hill East'), Data: {'length': 1974, 'line_name': 'Northern', 'flows': 1974, 'velocity': 60, 'time': 32.9}
# Edge: ('Finchley Central', 'West Finchley'), Data: {'length': 11555, 'line_name': 'Northern', 'flows': 11555, 'velocity': 60, 'time': 192.58333333333334}
# Edge: ('Finchley Central', 'East Finchley'), Data: {'length': 19938, 'line_name': 'Northern', 'flows': 19938, 'velocity': 60, 'time': 332.3}
# Edge: ('High Barnet', 'Totteridge & Whetstone'), Data: {'length': 4224, 'line_name': 'Northern', 'flows': 4224, 'velocity': 60, 'time': 70.4}
# Edge: ('Totteridge & Whetstone', 'Woodside Park'), Data: {'length': 6700, 'line_name': 'Northern', 'flows': 6700, 'velocity': 60, 'time': 111.66666666666667}
# Edge: ('Woodside Park', 'West Finchley'), Data: {'length': 10150, 'line_name': 'Northern', 'flows': 10150, 'velocity': 60, 'time': 169.16666666666666}
# Edge: ('East Finchley', 'Highgate'), Data: {'length': 25789, 'line_name': 'Northern', 'flows': 25789, 'velocity': 60, 'time': 429.81666666666666}
# Edge: ('Highgate', 'Archway'), Data: {'length': 30286, 'line_name': 'Northern', 'flows': 30286, 'velocity': 60, 'time': 504.76666666666665}
# Edge: ('Archway', 'Tufnell Park'), Data: {'length': 35715, 'line_name': 'Northern', 'flows': 35715, 'velocity': 60, 'time': 595.25}
# Edge: ('Tufnell Park', 'Kentish Town'), Data: {'length': 38298, 'line_name': 'Northern', 'flows': 38298, 'velocity': 60, 'time': 638.3}
# Edge: ('Battersea Power Station', 'Nine Elms'), Data: {'length': 0, 'line_name': 'Northern', 'flows': 0, 'velocity': 60, 'time': 0.0}

# %%
# Add 'velocity' field to each edge with value 60
for u, v, data in G.edges(data=True):
    data['velocity'] = 60

# %%
# Add 'time' field to each edge, where time = distance / velocity
for u, v, data in G.edges(data=True):
    data['time'] = data['length']/data['velocity']

# %%
max_time
# Out:
# 3588.2833333333333

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Assuming 'time' attribute exists in edges
max_time = max(data['time'] for u, v, data in G.edges(data=True))
time_color = [(i[2]['time'] / max_time) for i in G.edges(data=True)]
time_width = [(i[2]['time'] / max_time * 10) for i in G.edges(data=True)]

# Plot graph
fig, ax = plt.subplots(figsize=(12, 12))

#pos=nx.spring_layout(X)
edg=nx.draw_networkx_edges(G, pos,edge_color=flow_color, width=flow_width)

# Draw nodes
nx.draw_networkx_nodes(G, 
                       pos = pos, 
                       node_color='black', 
                       node_size=1)

# Adding a colorbar for the edge colors
plt.colorbar(edg, label="Passenger Time Travel", orientation="horizontal", shrink=0.5)

plt.axis("off")
plt.title("London Network Passenger Time Travel", fontsize=15)
plt.show()


plt.colorbar(edg,label="Passenger Flows",orientation="horizontal", shrink=0.5)
plt.axis("off")
plt.title("London network Passenger Flows",fontsize=15)
plt.show()

# %%
#plot our calcuated flows
flows_values = flows.values()
flow_color=[(i[2]['flows']/max(flows_values)) for i in G.edges(data=True)]
flow_width=[(i[2]['flows']/max(flows_values)*10) for i in G.edges(data=True)]

# Plot graph
fig, ax = plt.subplots(figsize=(12,12))

#pos=nx.spring_layout(X)
edg=nx.draw_networkx_edges(G, pos,edge_color=flow_color, width=flow_width)

nx.draw_networkx_nodes(G,
        pos = pos,
        node_color= 'black',
        node_size= 1)

plt.colorbar(edg,label="Passenger Flows",orientation="horizontal", shrink=0.5)
plt.axis("off")
plt.title("London network Passenger Flows",fontsize=15)
plt.show()

# %%
# weighted alternatives
## 1. time and flow = weight

# %% [markdown]
# # II. Average Shortest Path Length (APL) Analysis

# %%
## a. Scenario 1: Business As Usual

# %%
## b. Scenario 2: Winter Disruption without Government Intervention

# %%
## c. Scenario 3: Winter Disruption with Government Intervention

# %%
## d. APL Comparison between Scenarios

# %% [markdown]
# # III. Betweeness Centrality (BC) Analysis

# %%
## a. Scenario 1: Business As Usual

# %%
## b. Scenario 2: Winter Disruption without Government Intervention

# %%
## c. Scenario 3: Winter Disruption with Government Intervention

# %%
## d. BC Comparison between Scenarios

# %% [markdown]
# # IV. Intervention Recommendation
