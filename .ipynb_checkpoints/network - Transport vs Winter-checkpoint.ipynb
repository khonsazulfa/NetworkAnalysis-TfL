# %% [markdown]
# # I. DATA PREPARATION

# %%
# we will import all the necessary libraries
import pandas as pd
import numpy as np
import geopandas as gpd
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import json
import re
from shapely.geometry import Point, LineString #this library is for manipulating geometric objects, and it is what geopandas uses to store geometries
from scipy.spatial import distance

# %%
#tlf provides passenger flow data for each network separately
#we need to create a list of all the different files we need
df_dlr = pd.read_csv('https://www.dropbox.com/scl/fi/xkf9ttbop2wyypp8bttgw/NBT19MTT2b_od__DLR_tb_wf.csv?rlkey=me22ozynt7i13ah9hvh9f157m&dl=1')
df_ezl = pd.read_csv('https://www.dropbox.com/scl/fi/vizzmmz5u1mhhxignbwei/NBT19MTT2b_od__EZL_tb_wf.csv?rlkey=nz69dj4n7x02389gl7gc95knw&dl=1')
df_lo = pd.read_csv('https://www.dropbox.com/scl/fi/rhofj793lzlh6ptheo0ui/NBT19MTT2b_od__LO_tb_wf.csv?rlkey=btj1o5i02dx9paqhpkhk1chlo&dl=1')
df_lu = pd.read_csv('https://www.dropbox.com/scl/fi/572yutkebg3pa4pjn42d9/NBT19MTT2b_od__LU_tb_wf.csv?rlkey=0rfklc4u7nxcwbtsjsko0i3xd&dl=1')

files = [df_dlr, df_ezl, df_lo, df_lu]
london_OD = pd.concat(files, ignore_index=True)

# %%
london_OD
# Out:
#        mode_mnlc_o  mode_mnlc_d          2         3        4        5  \
# 0              504          523    8.03300    16.430   24.563   28.555
# 1              504          533   30.71900    40.105   61.571   57.881
# 2              504          538    5.94100    17.238   37.493   43.158
# 3              504          559    5.79500    26.397   27.285   24.065
# 4              504          573   77.78600   113.750  143.938  387.562
# ...            ...          ...        ...       ...      ...      ...
# 62575          884          784   97.99600   538.180  298.849  173.856
# 62576          884          787  115.91900   281.952  149.409  138.607
# 62577          884          788  139.04400   682.340  768.051  504.189
# 62578          884          789  156.23601   481.302  702.600  595.686
# 62579          884          852  283.30700  1191.298  809.155  366.224
#
#              6        7 mode    1    8
# 0       13.023    2.263  DLR  NaN  NaN
# 1       15.573    0.317  DLR  NaN  NaN
# 2       33.890   10.429  DLR  NaN  NaN
# 3       15.213    8.508  DLR  NaN  NaN
# 4      165.776   65.283  DLR  NaN  NaN
# ...        ...      ...  ...  ...  ...
# 62575   51.263   14.653   LU  0.0  0.0
# 62576   64.885   25.433   LU  0.0  0.0
# 62577  345.944  113.663   LU  0.0  0.0
# 62578  317.113   63.273   LU  0.0  0.0
# 62579  177.616   34.625   LU  0.0  0.0
#
# [62580 rows x 11 columns]

# %%
definition_df = pd.read_excel('https://www.dropbox.com/scl/fi/8rvd82qd4ald2yyt2bz6m/NBT19_Definitions.xlsx?rlkey=5jcia5kufnlmictzcs9nc2qia&dl=1', 'Stations')

# %%
#we will drop any missing values from our dataframe
definition_df.dropna(inplace=True)

#transform mnlc codes from floats to int
definition_df.MNLC = definition_df.MNLC.astype(int)

# %%
#add the station names
london_OD['station_origin'] = london_OD['mode_mnlc_o'].apply(lambda x: definition_df[definition_df.MNLC==x]['StationName'].values[0])
london_OD['station_destination'] = london_OD['mode_mnlc_d'].apply(lambda x: definition_df[definition_df.MNLC==x]['StationName'].values[0])

# %%
# we will only keep passenger flows for the timeband we are interested in
london_OD_AMpeak = london_OD[['station_origin', 'station_destination', '3']].copy()

# %%
#rename column
london_OD_AMpeak.rename({'3':'flows'}, axis=1, inplace=True)

#since the flows are averages the are stored as flows.
#for our analysis we will turn the into ints
london_OD_AMpeak.flows = london_OD_AMpeak.flows.astype(int)

# %%
station_origin = list(london_OD_AMpeak.station_origin.values)
station_destination = list(london_OD_AMpeak.station_destination.values)
all_stations = list(set(station_origin + station_destination))
all_stations = sorted(all_stations, key=str.lower)

# %%
london_OD_AMpeak['station_origin']= london_OD_AMpeak.station_origin.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )
london_OD_AMpeak['station_destination']=london_OD_AMpeak.station_destination.apply(lambda x: 
                                      re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', x)
                                     )

# %%
#group by origin and destination station and sum the flows
london_OD_AMpeak = london_OD_AMpeak.groupby(['station_origin', 'station_destination'], as_index=False).sum()

# %%
#let's sanity check and see the highest and lowest flows in and out flows
outflows = london_OD_AMpeak.groupby('station_origin', as_index=False).sum()
#let's sanity check and see the highest and lowest flows in and out flows
inflows = london_OD_AMpeak.groupby('station_destination', as_index=False).sum()

# %% [markdown]
# ### Load London Underground shapefile data

# %%
#read in the data using geopandas
stations = gpd.read_file('https://www.dropbox.com/scl/fi/j1ugr3bsub9jhp8b0btkq/tfl_stations.json?rlkey=r38t2xn9n5erc1y3jzub6tqol&dl=1')
lines = gpd.read_file('https://www.dropbox.com/scl/fi/ov98qi02qju6kcq5vxnbb/tfl_lines.json?rlkey=h9wip7f1drqn4prgf0fhkcvna&dl=1')

# %%
stations
# Out:
#               id                 name nlc_id  \
# 0    940GZZLUACT           Acton Town   0500
# 1    940GZZLUACY              Archway   0508
# 2    940GZZLUADE         Aldgate East   0503
# 3    940GZZLUAGL                Angel   0507
# 4    940GZZLUALD              Aldgate   0502
# ..           ...                  ...    ...
# 524  910GWNSTDPK        Wanstead Park   7408
# 525   910GWOLWXR             Woolwich   None
# 526  910GWRCSTRP       Worcester Park   5579
# 527      910G950         Canary Wharf   None
# 528      910G981  King's Road Chelsea   None
#
#                                                  lines  \
# 0    [ { "name": "District" }, { "name": "Piccadill...
# 1      [ { "name": "Northern", "nightopened": 2016 } ]
# 2    [ { "name": "District" }, { "name": "Hammersmi...
# 3    [ { "name": "Northern" }, { "name": "Crossrail...
# 4    [ { "name": "Circle" }, { "name": "Metropolita...
# ..                                                 ...
# 524  [ { "name": "London Overground", "opened": 200...
# 525        [ { "name": "Crossrail", "opened": 2018 } ]
# 526  [ { "name": "National Rail", "opened": 2030 },...
# 527        [ { "name": "Crossrail", "opened": 2018 } ]
# 528      [ { "name": "Crossrail 2", "opened": 2030 } ]
#
#                        cartography altmodeid alt_id altmodeid2 zone  \
# 0                   {'labelX': 30}      None      1       None    3
# 1                  {'labelX': -30}      None      8       None  2/3
# 2                   {'labelX': 30}      None      3       None    1
# 3     {'labelX': 1, 'labelY': -35}      None      7       None    1
# 4     {'labelX': 25, 'labelY': 20}      None      2       None    1
# ..                             ...       ...    ...        ...  ...
# 524   {'labelX': 1, 'labelY': -45}      None   None       None    3
# 525  {'labelX': 25, 'labelY': -20}      None   None       None    4
# 526                 {'labelX': 30}      None    WCP       None    4
# 527                 {'labelX': 30}      None   None       None    2
# 528    {'labelX': 1, 'labelY': 45}      None   None       None    1
#
#                       geometry
# 0    POINT (-0.27992 51.50264)
# 1    POINT (-0.13475 51.56537)
# 2    POINT (-0.07188 51.51515)
# 3    POINT (-0.10613 51.53182)
# 4    POINT (-0.07572 51.51410)
# ..                         ...
# 524   POINT (0.02633 51.55170)
# 525   POINT (0.07081 51.49179)
# 526  POINT (-0.24496 51.38139)
# 527  POINT (-0.01747 51.50628)
# 528  POINT (-0.16701 51.48835)
#
# [529 rows x 10 columns]

# %%
#project data to British National Grid
#we do this so we can work in meters
stations = stations.to_crs(epsg = 27700)
lines = lines.to_crs(epsg = 27700)

# %% [markdown]
# ### Clean station names
#
# We have multiple points representing one station (for example Paddington has seperate points for different entrances). We will simplify this by using RegEx make the names consistent.
#
# Once we have cleaned the names we can set the coordinate of these stations to the mean values of the coordinates of all the stations with the same name.

# %%
#get all station names
station_names = {row.id: row['name'] for i, row in stations.iterrows()}

#clean station names
for k, v in station_names.items():
    if k == 'none':
        continue
    cleaned_name = re.sub('\sLU\s?|\sLO\s?|\sNR\s?|\sTf[lL]\s?|\sDLR\s?|\s\(.*\)', '', v)
    
    #note that bank and monument are enconded as one station in our TFL data, so we will do the same
    if cleaned_name in ['Bank', 'Monument']:
        cleaned_name = 'Bank and Monument'
    station_names[k] = cleaned_name
    
stations['name'] = stations['id'].apply(lambda x: station_names[x])

#stations[['name','id']].groupby('name').count().sort_values(by='id',ascending=False)

# %% [markdown]
# **Change position of station to mean of all station with the same name**

# %%
#get position of stations as mean of x, y of stations

#create empty dict to store list of coordinates
pos = {}

#iterate through the stations
for i, station in stations.iterrows():
    xy = station.geometry.coords[0]
    
    #if station already in dict add coordinate to coordinate list
    if station['name'] in pos.keys():
        pos[station['name']].extend([xy])
    #if station is not in the dict add station to dict and set first coordinate in list
    else:
        pos[station['name']] = [xy]

#iterate through our dict and replace coordinate list with mean value
for k, v in pos.items():
    #we set axis to 0 to make sure to take mean of x and y coordinates
    pos[k] = np.mean(v, axis=0)

# %%
#set new geometry
stations['geometry'] = stations['name'].apply(lambda x: Point(pos[x]))

# %%
stations
# Out:
#               id                 name nlc_id  \
# 0    940GZZLUACT           Acton Town   0500
# 1    940GZZLUACY              Archway   0508
# 2    940GZZLUADE         Aldgate East   0503
# 3    940GZZLUAGL                Angel   0507
# 4    940GZZLUALD              Aldgate   0502
# ..           ...                  ...    ...
# 524  910GWNSTDPK        Wanstead Park   7408
# 525   910GWOLWXR             Woolwich   None
# 526  910GWRCSTRP       Worcester Park   5579
# 527      910G950         Canary Wharf   None
# 528      910G981  King's Road Chelsea   None
#
#                                                  lines  \
# 0    [ { "name": "District" }, { "name": "Piccadill...
# 1      [ { "name": "Northern", "nightopened": 2016 } ]
# 2    [ { "name": "District" }, { "name": "Hammersmi...
# 3    [ { "name": "Northern" }, { "name": "Crossrail...
# 4    [ { "name": "Circle" }, { "name": "Metropolita...
# ..                                                 ...
# 524  [ { "name": "London Overground", "opened": 200...
# 525        [ { "name": "Crossrail", "opened": 2018 } ]
# 526  [ { "name": "National Rail", "opened": 2030 },...
# 527        [ { "name": "Crossrail", "opened": 2018 } ]
# 528      [ { "name": "Crossrail 2", "opened": 2030 } ]
#
#                        cartography altmodeid alt_id altmodeid2 zone  \
# 0                   {'labelX': 30}      None      1       None    3
# 1                  {'labelX': -30}      None      8       None  2/3
# 2                   {'labelX': 30}      None      3       None    1
# 3     {'labelX': 1, 'labelY': -35}      None      7       None    1
# 4     {'labelX': 25, 'labelY': 20}      None      2       None    1
# ..                             ...       ...    ...        ...  ...
# 524   {'labelX': 1, 'labelY': -45}      None   None       None    3
# 525  {'labelX': 25, 'labelY': -20}      None   None       None    4
# 526                 {'labelX': 30}      None    WCP       None    4
# 527                 {'labelX': 30}      None   None       None    2
# 528    {'labelX': 1, 'labelY': 45}      None   None       None    1
#
#                           geometry
# 0    POINT (519484.905 179592.101)
# 1    POINT (529382.416 186814.396)
# 2    POINT (533886.853 181342.360)
# 3    POINT (531462.253 183134.536)
# 4    POINT (533623.564 181218.497)
# ..                             ...
# 524  POINT (540588.347 185591.204)
# 525  POINT (543860.265 179015.536)
# 526  POINT (522234.054 166165.818)
# 527  POINT (537586.695 180311.854)
# 528  POINT (527360.801 178192.787)
#
# [529 rows x 10 columns]

# %% [markdown]
# ### Lines file

# %%
#get all line types as a list and subset geoms by lines
line_names  = lines.lines.apply(lambda x: [x['name'] for x in json.loads(x)] )
line_names = list(set([item for sublist in line_names for item in sublist]))

# %%
#We can see that east london line is incomplete
#digging into this however we notice that it's because east london is actually part of the overground
#merge East London line and London Overground since they are one line
lines.lines = lines.lines.str.replace('East London', 'London Overground')
stations.lines = stations.lines.str.replace('East London', 'London Overground')

# %%
#Our TFL data doesn't include tramlink, emirates air lines, and crossrail is still in construction (except not really)
#exclude the lines that we are not going to use
excluded_lines = ['Thameslink 6tph line', 'East London', 'Crossrail 2', 'Emirates Air Line', 'Crossrail', 'Tramlink']

# %%
stations
# Out:
#               id                 name nlc_id  \
# 0    940GZZLUACT           Acton Town   0500
# 1    940GZZLUACY              Archway   0508
# 2    940GZZLUADE         Aldgate East   0503
# 3    940GZZLUAGL                Angel   0507
# 4    940GZZLUALD              Aldgate   0502
# ..           ...                  ...    ...
# 524  910GWNSTDPK        Wanstead Park   7408
# 525   910GWOLWXR             Woolwich   None
# 526  910GWRCSTRP       Worcester Park   5579
# 527      910G950         Canary Wharf   None
# 528      910G981  King's Road Chelsea   None
#
#                                                  lines  \
# 0    [ { "name": "District" }, { "name": "Piccadill...
# 1      [ { "name": "Northern", "nightopened": 2016 } ]
# 2    [ { "name": "District" }, { "name": "Hammersmi...
# 3    [ { "name": "Northern" }, { "name": "Crossrail...
# 4    [ { "name": "Circle" }, { "name": "Metropolita...
# ..                                                 ...
# 524  [ { "name": "London Overground", "opened": 200...
# 525        [ { "name": "Crossrail", "opened": 2018 } ]
# 526  [ { "name": "National Rail", "opened": 2030 },...
# 527        [ { "name": "Crossrail", "opened": 2018 } ]
# 528      [ { "name": "Crossrail 2", "opened": 2030 } ]
#
#                        cartography altmodeid alt_id altmodeid2 zone  \
# 0                   {'labelX': 30}      None      1       None    3
# 1                  {'labelX': -30}      None      8       None  2/3
# 2                   {'labelX': 30}      None      3       None    1
# 3     {'labelX': 1, 'labelY': -35}      None      7       None    1
# 4     {'labelX': 25, 'labelY': 20}      None      2       None    1
# ..                             ...       ...    ...        ...  ...
# 524   {'labelX': 1, 'labelY': -45}      None   None       None    3
# 525  {'labelX': 25, 'labelY': -20}      None   None       None    4
# 526                 {'labelX': 30}      None    WCP       None    4
# 527                 {'labelX': 30}      None   None       None    2
# 528    {'labelX': 1, 'labelY': 45}      None   None       None    1
#
#                           geometry
# 0    POINT (519484.905 179592.101)
# 1    POINT (529382.416 186814.396)
# 2    POINT (533886.853 181342.360)
# 3    POINT (531462.253 183134.536)
# 4    POINT (533623.564 181218.497)
# ..                             ...
# 524  POINT (540588.347 185591.204)
# 525  POINT (543860.265 179015.536)
# 526  POINT (522234.054 166165.818)
# 527  POINT (537586.695 180311.854)
# 528  POINT (527360.801 178192.787)
#
# [529 rows x 10 columns]

# %% [markdown]
# ## Create seperate graphs for each line and then join
#
# Since we don't have properly constructed line geometries because:
# * there are discontinuities in the line geometries
# * a line between two stations can actually be composed of more than one geometry
#
# We will construct geometric graphs (meaning graphs just from the line geometries where nodes are coordinates that define the line geometry). It's easy to fix the discontinuities in this manner because the can be thought of as nodes with degree = 1 that have another node with degree = 1 within a threshold distance.
#
# Once we have these discontinuties fixed we can use these geometric graphs to construct proper geometries between stations by taking the shortest paths within these networks starting from the node closest to the origin station and ending in the node closest to the destination station. The shortest path will then be a list of coordinates that define the line geometry between the two stations.

# %%
#create an empty dict to hold our geometric graphs
geometric_graphs = {}

#iterate through each line individually
for line_name in line_names:
    #skip lines that we won't be using
    if line_name in excluded_lines :
        continue
    print(line_name)
    
    #subset our line and station files for the ones the belong to a specific line
    temp_lines = lines[lines.lines.str.contains(line_name)]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #create empty graph
    G= nx.Graph()
    
    #iterate through our line geometries
    for i, line in temp_lines.iterrows():
        #get list of coordinates that define our line
        _l = list(line.geometry.coords)

        #add coordinates as edges
        G.add_edges_from(list(zip(_l,_l[1:])))
    
    #remove any self loops
    G.remove_edges_from(nx.selfloop_edges(G))
    
    #the position of the node is the name of the node
    #let's extract this to plot our graph
    pos = {n: n for n in G.nodes()}
    
    # get degree one nodes
    D = nx.degree(G)
    k1 = [node for node,degree in D if degree==1]
    #let's plot our graph and all degree one nodes
    nx.draw(G, pos=pos, node_size=0.5, node_color='grey')
    nx.draw_networkx_nodes(G, pos=pos, nodelist=k1, node_color='red', node_size=8)
    plt.show()
    
    #get distance between all points of 1-degree, this will be a matrix
    dist = distance.cdist(k1, k1)
    
    #add edges between points that are close
    for j in range(dist.shape[0]-1):
        temp = dist[j][j+1:]
        #get index of closest node
        i_min = np.argmin(temp)
        if dist[j][i_min+j+1]<50:
            G.add_edge(k1[j],k1[i_min+j+1])
    
    #recalculate degree
    D = nx.degree(G)
    k1 = [node for node,degree in D if degree==1]
    #plot new graph
    nx.draw(G, pos=pos, node_size=0.5, node_color='grey')
    nx.draw_networkx_nodes(G, pos=pos, nodelist=k1, node_color='red', node_size=8)
    plt.show()
    print(nx.number_connected_components(G))
    #store graph in dictionary
    geometric_graphs[line_name] = G
# Out:
# London Overground
# 3
# Waterloo & City
# 1
# Hammersmith & City
# 1
# Central
# 1
# Northern
# 1
# Piccadilly
# 1
# Jubilee
# 1
# TfL Rail
# 1
# Bakerloo
# 1
# Circle
# 1
# District
# 1
# Metropolitan
# 1
# DLR
# 1
# Victoria
# 1

# %% [markdown]
# Now that we have these geometric graphs we can create our final graph by using the data in the lines attribute in our lines geodataframe that contains origin and destination station. We can then use our geometric graph and find the shortest route to create our line geometries and find the length of the lines.
#
# We will store this information in a dataframe that we can use to create our final graph

# %%
#create a dataframe with all geometries from all valid lines
#this list will contain a dictionary for each edge in our graph that contains
# node pairs, line name, and a geometry (this is just for quick visualization purposes and will be replaced by true geometry)
edge_list = []
def _has_ids(k):
    #helper function to check if line contains id of start and end station
    if ('start_sid' in k.keys()) and ('end_sid' in k.keys()):
        return True
    else:
        return False

#iterate through each line seperately 
for line_name in line_names:
    if line_name in excluded_lines :
        continue
        
    #subset lines and stations
    temp_lines = lines[lines.lines.str.contains(line_name)]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #for each line in our subset dataframe get each origin and destination pair
    for i, line in temp_lines.iterrows():
        for k in json.loads(line.lines):
            if k['name'] == line_name:
                if _has_ids(k):
                    #get start and end station ids
                    start_id = k['start_sid']
                    end_id = k['end_sid']

                    #get info of start and end station
                    start_station = temp_stations[(temp_stations.id == start_id) | (temp_stations.altmodeid == start_id)].values
                    end_station = temp_stations[(temp_stations.id == end_id) | (temp_stations.altmodeid == end_id)].values
                    
                    #if no matching station exist, let's just take the starting and ending coordinate of the line for now
                    if len(start_station) >= 1 and len(end_station) >=1:
                        s_geom = start_station[0][-1].coords[0]
                        e_geom = end_station[0][-1].coords[0]
                        edge_list.append({
                            'line_name': line_name,
                            'start_id': start_id,
                            'end_id': end_id,
                            'geometry': LineString([s_geom, e_geom])
                        })

# %%
#turn our dictionary list into a geopandas df to quickly plot and sanity check our work
edge_gdf = gpd.GeoDataFrame(edge_list)
edge_gdf.crs = lines.crs

# %%
### Add geometry information back into the graph
for line_name in line_names:
    if line_name in excluded_lines :
        continue
    temp_lines = edge_gdf[edge_gdf.line_name == line_name]
    temp_stations = stations[stations.lines.str.contains(line_name)]
    
    #let's plot our lines so we can check them
    fig, ax = plt.subplots(figsize = (7,7))
    fig.suptitle(f'line: {line_name}')
    ax.set_aspect("equal")
    ax.axis('off')
    ax.margins(0.1)
    
    base = temp_lines.plot(ax=ax, color='grey')
    temp_stations.plot(ax=base, markersize=20, color='red')
    plt.show()
    
    #add real geometry back
    for i, edge in temp_lines.iterrows():
        #get start and end of line coordinates
        start = edge.geometry.coords[0]
        end = edge.geometry.coords[-1]
        
        #let's get all the coordinates in our geometric graph
        nodes = list(geometric_graphs[line_name].nodes)
        
        #find nearest node in graph to origin and destination
        s_dist = distance.cdist([start], nodes)[0]
        s_i = np.argmin(s_dist)
        source= nodes[s_i]
        
        t_dist = distance.cdist([end], nodes)[0]
        t_i = np.argmin(t_dist)
        target= nodes[t_i]
        
        #get shortest path
        sp = nx.shortest_path(geometric_graphs[line_name], source, target)
        
        #make into geometry
        #notice how I'm also adding the start and end coordinates to the line definition
        #this fixes the problem of stations and lines not matching up
        geometry = LineString([start] + sp + [end])
        edge_gdf.loc[i, 'geometry'] = geometry

# %%
#let's store the length of the real geometry
edge_gdf['length'] = edge_gdf.geometry.length

# %%
#let's replace the ids with the actual name
#get all station names
station_names_2 = {row.altmodeid: row['name'] for i, row in stations.iterrows() if row.altmodeid != None}
station_names.update(station_names_2)

# %%
edge_gdf['start_id'] = edge_gdf['start_id'].apply(lambda x: station_names[x])
edge_gdf['end_id'] = edge_gdf['end_id'].apply(lambda x: station_names[x])

# %% [markdown]
# ## IMPORTANT!!!

# %%
#now we can use this to create our network!
G = nx.from_pandas_edgelist(edge_gdf, source = 'start_id', target='end_id', edge_attr=['length', 'line_name'])

#let's plot
#notice that even though we created the real geometries, the graph still plots just straight line
#this is because networkx doesn't have a concept of a edge geometry
#however this is ok, since we only need the distance as weights, and that is already an attribute in our graph
pos = {row['name']: row.geometry.coords[0] for i, row in stations.iterrows() if row['name'] in G.nodes()}
Gcc = nx.connected_components(G)
for n in Gcc:
    G_sub = G.subgraph(n)
    lines = [data['line_name'] for u,v, data in G_sub.edges(data=True)]
    print(set(lines))
    nx.draw(G_sub, pos, node_size=4)
    plt.show()

#save position to graph
nx.set_node_attributes(G, pos, 'coords')
# Out:
# {'London Overground', 'TfL Rail', 'Metropolitan', 'District', 'Jubilee', 'Waterloo & City', 'Hammersmith & City', 'DLR', 'Piccadilly', 'Central', 'Northern', 'Bakerloo', 'Victoria', 'Circle'}

# %% [markdown]
# ### Sanity check our network

# %%
#check that all distances are greater or equal to euclidean distance
for u,v, data in G.edges(data=True):
    assert(data['length'] >= distance.euclidean(pos[u], pos[v]))

# %%
#if want to know what is the maximum distance between stations
max(dict(G.edges).items(), key=lambda x: x[1]['length'])
# Out:
# (('Wembley Park', 'Finchley Road'),
#  {'length': 7266.373927496486, 'line_name': 'Metropolitan'})

# %%
#if want to know to which stations Baker Street is directly connected to
Baker_Street = [(u,v) for  u,v in G.edges() if u == 'Baker Street' or v == 'Baker Street']
Baker_Street
# Out:
# [('Baker Street', 'Great Portland Street'),
#  ('Baker Street', 'Edgware Road'),
#  ('Baker Street', 'Bond Street'),
#  ('Baker Street', "St. John's Wood"),
#  ('Baker Street', 'Marylebone'),
#  ('Baker Street', "Regent's Park"),
#  ('Baker Street', 'Finchley Road')]

# %%
#We can also check the degree of the nodes in our network and check that they make sense
deg_london = nx.degree(G)

# %%
df = pd.DataFrame(index = dict(deg_london).keys())
df['degree'] = dict(deg_london).values()

# %%
df.sort_values('degree', ascending =False).head(20)
# Out:
#                           degree
# Stratford                      9
# Bank and Monument              8
# King's Cross St. Pancras       7
# Baker Street                   7
# Liverpool Street               6
# Canning Town                   6
# West Ham                       6
# Green Park                     6
# Waterloo                       6
# Oxford Circus                  6
# Earl's Court                   6
# Willesden Junction             5
# Shadwell                       5
# Euston                         5
# Turnham Green                  5
# Blackhorse Road                4
# Moorgate                       4
# West Brompton                  4
# Canary Wharf                   4
# Paddington                     4

# %% [markdown]
# ### Merge Network with OD data
#
# ok, we are almost done!
#
# We have processed our raw data, now we need to combine the two (TLF OD and our Network). For this we need two types of merge:
#
# 1. add flows as weights to the network (to be able to calculate disruptions to the network)
# 2. create OD with distance for our spatial interaction models (for our spatial interaction models)

# %%
#check that our OD data and network data match
OD_names = set(london_OD_AMpeak.station_origin.unique())
network_names = set([n for n in G.nodes()])

# %% [markdown]
# Ok, we have a few stations that don't match up. They are small enough that we can solve this quickly by creating a mapping between names of the stations that we can keep.
#
# * Battersea power station and Nine Elms data doesn't exist in our TFL data because the station wasn't opened when the data was collected. This was an extension of Northern line that opened recently.
# * Action Main Line, Hanwell, Hayes & Harlington, Southall, and West Ealing are part of crossrail which we are not considering

# %%
name_map = {
    'Heathrow Terminal 4 EL': 'Heathrow Terminal 4',
    'Heathrow Terminals 123': 'Heathrow Terminals 2 & 3',
    'Heathrow Terminals 2 & 3 EL': 'Heathrow Terminals 2 & 3',
    "Walthamstow Queen's Road": 'Walthamstow Queens Road'
}

# %%
london_OD_AMpeak.station_origin = london_OD_AMpeak.station_origin.apply(
    lambda x: name_map[x] if x in name_map.keys() else x
)
london_OD_AMpeak.station_destination = london_OD_AMpeak.station_destination.apply(
    lambda x: name_map[x] if x in name_map.keys() else x
)

# %%
#let's filter out the stations that we don't have in our network
OD_names = set(london_OD_AMpeak.station_origin.unique())
_filter = list(network_names.symmetric_difference(OD_names))
_filter
# Out:
# ['West Ealing',
#  'Southall',
#  'Battersea Power Station',
#  'Nine Elms',
#  'Hayes & Harlington',
#  'Acton Main Line',
#  'Hanwell']

# %%
london_OD_AMpeak = london_OD_AMpeak[~london_OD_AMpeak.station_origin.isin(_filter)]
london_OD_AMpeak = london_OD_AMpeak[~london_OD_AMpeak.station_destination.isin(_filter)]

# %% [markdown]
# **Add flow data to our network**
#
# Our TFL data contains flows for OD pairs, but we don't know the flows passing through each edge in our network. We will have to calculate this assuming fall people travelling from Origin to Destination station are taking the shortest path within the network.

# %%
#create a dictionary to store flows for all edges
flows = {(u,v): 0 for u,v in G.edges()}

# %%
#calculate shortest paths for all flows and add data to dict
for i, row in london_OD_AMpeak.iterrows():
    source = row.station_origin
    target = row.station_destination
    
    #get shortest path
    path = nx.dijkstra_path(G, source, target)
    
    #our path is a list of nodes, we need to turn this to a list of edges
    path_edges = list(zip(path,path[1:])) 
    
    #add flows to our dict
    for u,v in path_edges:
        try:
            flows[(u,v)] += row.flows
        except:
            flows[(v,u)] += row.flows

# %% [markdown]
# ### IMPORTANT!!! (INTEGRATION BETWEEN NETWORK AND WEIGHT)

# %%
#assumption, uniform speed x different distance = time
#time = distance / speed
#speed = 33kmph or 9mps

# %%
for edge, data in dict(G.edges).items():
    print(f"Edge: {edge}, Data: {data}")
# Out:
# Edge: ('Cambridge Heath', 'Bethnal Green'), Data: {'length': 831.8715882468825, 'line_name': 'London Overground'}
# Edge: ('Cambridge Heath', 'London Fields'), Data: {'length': 979.4169859715292, 'line_name': 'London Overground'}
# Edge: ('Bethnal Green', 'Liverpool Street'), Data: {'length': 2407.22114645448, 'line_name': 'Central'}
# Edge: ('Bethnal Green', 'Mile End'), Data: {'length': 1992.4218024894628, 'line_name': 'Central'}
# Edge: ('London Fields', 'Hackney Downs'), Data: {'length': 926.0127117881309, 'line_name': 'London Overground'}
# Edge: ('Hackney Downs', 'Rectory Road'), Data: {'length': 1201.0223774948356, 'line_name': 'London Overground'}
# Edge: ('Hackney Downs', 'Clapton'), Data: {'length': 1493.1171134857082, 'line_name': 'London Overground'}
# Edge: ('Rectory Road', 'Stoke Newington'), Data: {'length': 783.2557143388774, 'line_name': 'London Overground'}
# Edge: ('Stoke Newington', 'Stamford Hill'), Data: {'length': 1211.4700832725982, 'line_name': 'London Overground'}
# Edge: ('Stamford Hill', 'Seven Sisters'), Data: {'length': 1125.083404665905, 'line_name': 'London Overground'}
# Edge: ('Seven Sisters', 'Bruce Grove'), Data: {'length': 1332.2700481811246, 'line_name': 'London Overground'}
# Edge: ('Seven Sisters', 'Finsbury Park'), Data: {'length': 3405.888390028811, 'line_name': 'Victoria'}
# Edge: ('Seven Sisters', 'Tottenham Hale'), Data: {'length': 1153.5391678792378, 'line_name': 'Victoria'}
# Edge: ('Bruce Grove', 'White Hart Lane'), Data: {'length': 1213.4238875288067, 'line_name': 'London Overground'}
# Edge: ('White Hart Lane', 'Silver Street'), Data: {'length': 1199.9213592935591, 'line_name': 'London Overground'}
# Edge: ('Silver Street', 'Edmonton Green'), Data: {'length': 1198.454675885083, 'line_name': 'London Overground'}
# Edge: ('Edmonton Green', 'Southbury'), Data: {'length': 2970.5494541645353, 'line_name': 'London Overground'}
# Edge: ('Edmonton Green', 'Bush Hill Park'), Data: {'length': 1912.0054425449946, 'line_name': 'London Overground'}
# Edge: ('Southbury', 'Turkey Street'), Data: {'length': 2701.5767260364164, 'line_name': 'London Overground'}
# Edge: ('Turkey Street', 'Theobalds Grove'), Data: {'length': 2339.842151062409, 'line_name': 'London Overground'}
# Edge: ('Theobalds Grove', 'Cheshunt'), Data: {'length': 1539.905627999705, 'line_name': 'London Overground'}
# Edge: ('Liverpool Street', 'Aldgate East'), Data: {'length': 965.8659667181719, 'line_name': 'Hammersmith & City'}
# Edge: ('Liverpool Street', 'Moorgate'), Data: {'length': 434.0874486023312, 'line_name': 'Metropolitan'}
# Edge: ('Liverpool Street', 'Bank and Monument'), Data: {'length': 841.502683749556, 'line_name': 'Central'}
# Edge: ('Liverpool Street', 'Stratford'), Data: {'length': 6698.461270481002, 'line_name': 'TfL Rail'}
# Edge: ('Liverpool Street', 'Aldgate'), Data: {'length': 722.0840820475358, 'line_name': 'Metropolitan'}
# Edge: ('Enfield Town', 'Bush Hill Park'), Data: {'length': 1406.8660227786572, 'line_name': 'London Overground'}
# Edge: ('Romford', 'Emerson Park'), Data: {'length': 2920.238516197714, 'line_name': 'London Overground'}
# Edge: ('Romford', 'Chadwell Heath'), Data: {'length': 3869.588046544387, 'line_name': 'TfL Rail'}
# Edge: ('Romford', 'Gidea Park'), Data: {'length': 1693.9009368557536, 'line_name': 'TfL Rail'}
# Edge: ('Emerson Park', 'Upminster'), Data: {'length': 2626.8304525481967, 'line_name': 'London Overground'}
# Edge: ('Upminster', 'Upminster Bridge'), Data: {'length': 1310.782633781778, 'line_name': 'District'}
# Edge: ('Clapton', 'St James Street'), Data: {'length': 2772.7386645824745, 'line_name': 'London Overground'}
# Edge: ('St James Street', 'Walthamstow Central'), Data: {'length': 970.7099871668147, 'line_name': 'London Overground'}
# Edge: ('Walthamstow Central', 'Wood Street'), Data: {'length': 1367.6959005246442, 'line_name': 'London Overground'}
# Edge: ('Walthamstow Central', 'Blackhorse Road'), Data: {'length': 1559.0637437028229, 'line_name': 'Victoria'}
# Edge: ('Wood Street', 'Highams Park'), Data: {'length': 2579.1394084284793, 'line_name': 'London Overground'}
# Edge: ('Highams Park', 'Chingford'), Data: {'length': 2859.881267390292, 'line_name': 'London Overground'}
# Edge: ('Richmond', 'Kew Gardens'), Data: {'length': 2168.1632640796356, 'line_name': 'District'}
# Edge: ('Kew Gardens', 'Gunnersbury'), Data: {'length': 1780.2809189479904, 'line_name': 'District'}
# Edge: ('Gunnersbury', 'South Acton'), Data: {'length': 1016.8393795878126, 'line_name': 'London Overground'}
# Edge: ('Gunnersbury', 'Turnham Green'), Data: {'length': 1547.3179979156596, 'line_name': 'District'}
# Edge: ('South Acton', 'Acton Central'), Data: {'length': 1152.5272704397912, 'line_name': 'London Overground'}
# Edge: ('Harrow & Wealdstone', 'Kenton'), Data: {'length': 1780.6719958813244, 'line_name': 'Bakerloo'}
# Edge: ('Harrow & Wealdstone', 'Headstone Lane'), Data: {'length': 1850.9142197147085, 'line_name': 'London Overground'}
# Edge: ('Kenton', 'South Kenton'), Data: {'length': 1386.9692312837617, 'line_name': 'Bakerloo'}
# Edge: ('South Kenton', 'North Wembley'), Data: {'length': 935.7451700868527, 'line_name': 'Bakerloo'}
# Edge: ('North Wembley', 'Wembley Central'), Data: {'length': 1348.156442480471, 'line_name': 'Bakerloo'}
# Edge: ('Wembley Central', 'Stonebridge Park'), Data: {'length': 1718.0984669685454, 'line_name': 'Bakerloo'}
# Edge: ('Stonebridge Park', 'Harlesden'), Data: {'length': 1494.9487766659236, 'line_name': 'Bakerloo'}
# Edge: ('Harlesden', 'Willesden Junction'), Data: {'length': 1144.2331916335786, 'line_name': 'Bakerloo'}
# Edge: ('Willesden Junction', 'Kensal Green'), Data: {'length': 1352.2488873708176, 'line_name': 'Bakerloo'}
# Edge: ('Willesden Junction', 'Acton Central'), Data: {'length': 3065.465621352297, 'line_name': 'London Overground'}
# Edge: ('Willesden Junction', 'Kensal Rise'), Data: {'length': 1629.2437946821572, 'line_name': 'London Overground'}
# Edge: ('Willesden Junction', "Shepherd's Bush"), Data: {'length': 3906.332911932161, 'line_name': 'London Overground'}
# Edge: ('Kensal Green', "Queen's Park"), Data: {'length': 1384.6256610695687, 'line_name': 'Bakerloo'}
# Edge: ("Queen's Park", 'Kilburn High Road'), Data: {'length': 1064.503149075238, 'line_name': 'London Overground'}
# Edge: ("Queen's Park", 'Kilburn Park'), Data: {'length': 809.8309508921109, 'line_name': 'Bakerloo'}
# Edge: ('Kilburn High Road', 'South Hampstead'), Data: {'length': 976.3553884726724, 'line_name': 'London Overground'}
# Edge: ('Kensal Rise', 'Brondesbury Park'), Data: {'length': 1002.535433570864, 'line_name': 'London Overground'}
# Edge: ('Brondesbury Park', 'Brondesbury'), Data: {'length': 742.1886718422229, 'line_name': 'London Overground'}
# Edge: ('Brondesbury', 'West Hampstead'), Data: {'length': 849.2312353800593, 'line_name': 'London Overground'}
# Edge: ('West Hampstead', 'Finchley Road & Frognal'), Data: {'length': 630.6575296106906, 'line_name': 'London Overground'}
# Edge: ('West Hampstead', 'Kilburn'), Data: {'length': 1015.6216072668218, 'line_name': 'Jubilee'}
# Edge: ('West Hampstead', 'Finchley Road'), Data: {'length': 755.7345247171764, 'line_name': 'Jubilee'}
# Edge: ('Finchley Road & Frognal', 'Hampstead Heath'), Data: {'length': 1420.5331475476078, 'line_name': 'London Overground'}
# Edge: ('Hampstead Heath', 'Gospel Oak'), Data: {'length': 938.5606009702096, 'line_name': 'London Overground'}
# Edge: ('Gospel Oak', 'Kentish Town West'), Data: {'length': 1091.15942728907, 'line_name': 'London Overground'}
# Edge: ('Gospel Oak', 'Upper Holloway'), Data: {'length': 1900.2253023634726, 'line_name': 'London Overground'}
# Edge: ('Kentish Town West', 'Camden Road'), Data: {'length': 898.2449445992788, 'line_name': 'London Overground'}
# Edge: ('Camden Road', 'Caledonian Road & Barnsbury'), Data: {'length': 1764.578290487494, 'line_name': 'London Overground'}
# Edge: ('Caledonian Road & Barnsbury', 'Highbury & Islington'), Data: {'length': 813.6000250382895, 'line_name': 'London Overground'}
# Edge: ('Highbury & Islington', 'Canonbury'), Data: {'length': 981.1097681002285, 'line_name': 'London Overground'}
# Edge: ('Highbury & Islington', "King's Cross St. Pancras"), Data: {'length': 2581.853009656672, 'line_name': 'Victoria'}
# Edge: ('Highbury & Islington', 'Finsbury Park'), Data: {'length': 2057.343960440664, 'line_name': 'Victoria'}
# Edge: ('Canonbury', 'Dalston Kingsland'), Data: {'length': 1181.178340953049, 'line_name': 'London Overground'}
# Edge: ('Canonbury', 'Dalston Junction'), Data: {'length': 1363.8686463389834, 'line_name': 'London Overground'}
# Edge: ('Dalston Kingsland', 'Hackney Central'), Data: {'length': 1289.7562439979279, 'line_name': 'London Overground'}
# Edge: ('Hackney Central', 'Homerton'), Data: {'length': 1035.6155471122022, 'line_name': 'London Overground'}
# Edge: ('Homerton', 'Hackney Wick'), Data: {'length': 1343.350383060703, 'line_name': 'London Overground'}
# Edge: ('Hackney Wick', 'Stratford'), Data: {'length': 1572.923279349752, 'line_name': 'London Overground'}
# Edge: ('Stratford', 'Mile End'), Data: {'length': 2805.0013918567734, 'line_name': 'Central'}
# Edge: ('Stratford', 'Leyton'), Data: {'length': 2131.342925924301, 'line_name': 'Central'}
# Edge: ('Stratford', 'West Ham'), Data: {'length': 1673.5095151310568, 'line_name': 'Jubilee'}
# Edge: ('Stratford', 'Maryland'), Data: {'length': 951.3047206005755, 'line_name': 'TfL Rail'}
# Edge: ('Stratford', 'Stratford High Street'), Data: {'length': 519.300073543952, 'line_name': 'DLR'}
# Edge: ('Stratford', 'Pudding Mill Lane'), Data: {'length': 1137.0332570871155, 'line_name': 'DLR'}
# Edge: ('Stratford', 'Stratford International'), Data: {'length': 1321.0681171139224, 'line_name': 'DLR'}
# Edge: ('Whitechapel', 'Shadwell'), Data: {'length': 1094.3438658652442, 'line_name': 'London Overground'}
# Edge: ('Whitechapel', 'Shoreditch High Street'), Data: {'length': 1195.8214474657964, 'line_name': 'London Overground'}
# Edge: ('Whitechapel', 'Aldgate East'), Data: {'length': 963.3340688058626, 'line_name': 'District'}
# Edge: ('Whitechapel', 'Stepney Green'), Data: {'length': 1080.1641834945203, 'line_name': 'District'}
# Edge: ('Shadwell', 'Wapping'), Data: {'length': 858.7781938099081, 'line_name': 'London Overground'}
# Edge: ('Shadwell', 'Bank and Monument'), Data: {'length': 2317.101463770503, 'line_name': 'DLR'}
# Edge: ('Shadwell', 'Limehouse'), Data: {'length': 1192.5037329452541, 'line_name': 'DLR'}
# Edge: ('Shadwell', 'Tower Gateway'), Data: {'length': 1277.3034866933224, 'line_name': 'DLR'}
# Edge: ('Wapping', 'Rotherhithe'), Data: {'length': 450.55636194478814, 'line_name': 'London Overground'}
# Edge: ('Rotherhithe', 'Canada Water'), Data: {'length': 435.2544814876285, 'line_name': 'London Overground'}
# Edge: ('Canada Water', 'Surrey Quays'), Data: {'length': 549.5162309595552, 'line_name': 'London Overground'}
# Edge: ('Canada Water', 'Canary Wharf'), Data: {'length': 2601.8662764926153, 'line_name': 'Jubilee'}
# Edge: ('Canada Water', 'Bermondsey'), Data: {'length': 989.5169205602908, 'line_name': 'Jubilee'}
# Edge: ('Surrey Quays', 'New Cross Gate'), Data: {'length': 2081.7685848768274, 'line_name': 'London Overground'}
# Edge: ('Surrey Quays', 'New Cross'), Data: {'length': 2316.997521079707, 'line_name': 'London Overground'}
# Edge: ('Surrey Quays', 'Queens Road Peckham'), Data: {'length': 2392.258374234857, 'line_name': 'London Overground'}
# Edge: ('New Cross Gate', 'Brockley'), Data: {'length': 1229.0796568850708, 'line_name': 'London Overground'}
# Edge: ('Shoreditch High Street', 'Hoxton'), Data: {'length': 1075.252398134154, 'line_name': 'London Overground'}
# Edge: ('Sydenham', 'Crystal Palace'), Data: {'length': 1979.8329341857207, 'line_name': 'London Overground'}
# Edge: ('Sydenham', 'Forest Hill'), Data: {'length': 1415.1049911533883, 'line_name': 'London Overground'}
# Edge: ('Sydenham', 'Penge West'), Data: {'length': 1185.270598549146, 'line_name': 'London Overground'}
# Edge: ('Queens Road Peckham', 'Peckham Rye'), Data: {'length': 1130.560878083332, 'line_name': 'London Overground'}
# Edge: ('Peckham Rye', 'Denmark Hill'), Data: {'length': 1335.5866109262497, 'line_name': 'London Overground'}
# Edge: ('Denmark Hill', 'Clapham High Street'), Data: {'length': 3241.98511254321, 'line_name': 'London Overground'}
# Edge: ('Clapham High Street', 'Wandsworth Road'), Data: {'length': 621.9703299905578, 'line_name': 'London Overground'}
# Edge: ('Wandsworth Road', 'Clapham Junction'), Data: {'length': 2876.435508263358, 'line_name': 'London Overground'}
# Edge: ('Wandsworth Road', 'Battersea Park'), Data: {'length': 1168.4892614627925, 'line_name': 'London Overground'}
# Edge: ('Clapham Junction', 'Imperial Wharf'), Data: {'length': 2203.7682304786213, 'line_name': 'London Overground'}
# Edge: ('West Brompton', 'Imperial Wharf'), Data: {'length': 1577.1942937848828, 'line_name': 'London Overground'}
# Edge: ('West Brompton', 'Kensington'), Data: {'length': 1545.6914875144848, 'line_name': 'London Overground'}
# Edge: ('West Brompton', "Earl's Court"), Data: {'length': 567.389191763215, 'line_name': 'District'}
# Edge: ('West Brompton', 'Fulham Broadway'), Data: {'length': 942.7618764086681, 'line_name': 'District'}
# Edge: ('South Hampstead', 'Euston'), Data: {'length': 3831.445184198609, 'line_name': 'London Overground'}
# Edge: ('Euston', 'Camden Town'), Data: {'length': 1373.598810172985, 'line_name': 'Northern'}
# Edge: ('Euston', "King's Cross St. Pancras"), Data: {'length': 863.3696737515771, 'line_name': 'Victoria'}
# Edge: ('Euston', 'Mornington Crescent'), Data: {'length': 783.388597357072, 'line_name': 'Northern'}
# Edge: ('Euston', 'Warren Street'), Data: {'length': 546.2012018841854, 'line_name': 'Victoria'}
# Edge: ('Bushey', 'Watford High Street'), Data: {'length': 1314.2502642277932, 'line_name': 'London Overground'}
# Edge: ('Bushey', 'Carpenders Park'), Data: {'length': 1962.9784655331114, 'line_name': 'London Overground'}
# Edge: ('Watford High Street', 'Watford Junction'), Data: {'length': 1406.0375315796248, 'line_name': 'London Overground'}
# Edge: ('Carpenders Park', 'Hatch End'), Data: {'length': 2443.342296917783, 'line_name': 'London Overground'}
# Edge: ('Hatch End', 'Headstone Lane'), Data: {'length': 1146.1498418244364, 'line_name': 'London Overground'}
# Edge: ('Upper Holloway', 'Crouch Hill'), Data: {'length': 1214.8963405680036, 'line_name': 'London Overground'}
# Edge: ('Crouch Hill', 'Harringay Green Lanes'), Data: {'length': 1506.577799946524, 'line_name': 'London Overground'}
# Edge: ('Harringay Green Lanes', 'South Tottenham'), Data: {'length': 1858.7650958291101, 'line_name': 'London Overground'}
# Edge: ('South Tottenham', 'Blackhorse Road'), Data: {'length': 2291.1399207657278, 'line_name': 'London Overground'}
# Edge: ('Blackhorse Road', 'Walthamstow Queens Road'), Data: {'length': 1422.7370347035717, 'line_name': 'London Overground'}
# Edge: ('Blackhorse Road', 'Tottenham Hale'), Data: {'length': 1414.2057308806673, 'line_name': 'Victoria'}
# Edge: ('Walthamstow Queens Road', 'Leyton Midland Road'), Data: {'length': 1781.9840512516762, 'line_name': 'London Overground'}
# Edge: ('Leyton Midland Road', 'Leytonstone High Road'), Data: {'length': 1214.0970069086518, 'line_name': 'London Overground'}
# Edge: ('Leytonstone High Road', 'Wanstead Park'), Data: {'length': 1919.3048072770791, 'line_name': 'London Overground'}
# Edge: ('Wanstead Park', 'Woodgrange Park'), Data: {'length': 1320.7732927901427, 'line_name': 'London Overground'}
# Edge: ('Woodgrange Park', 'Barking'), Data: {'length': 2808.655162001238, 'line_name': 'London Overground'}
# Edge: ('Barking', 'East Ham'), Data: {'length': 2424.925792945743, 'line_name': 'District'}
# Edge: ('Barking', 'Upney'), Data: {'length': 1367.2954815493517, 'line_name': 'District'}
# Edge: ('Brockley', 'Honor Oak Park'), Data: {'length': 1734.321174338685, 'line_name': 'London Overground'}
# Edge: ('Honor Oak Park', 'Forest Hill'), Data: {'length': 1258.06397398924, 'line_name': 'London Overground'}
# Edge: ('Penge West', 'Anerley'), Data: {'length': 682.1023245902426, 'line_name': 'London Overground'}
# Edge: ('Anerley', 'Norwood Junction'), Data: {'length': 1798.4480565963026, 'line_name': 'London Overground'}
# Edge: ('Norwood Junction', 'West Croydon'), Data: {'length': 2935.5862436031935, 'line_name': 'London Overground'}
# Edge: ('Dalston Junction', 'Haggerston'), Data: {'length': 808.0082953159692, 'line_name': 'London Overground'}
# Edge: ('Haggerston', 'Hoxton'), Data: {'length': 834.5786379628204, 'line_name': 'London Overground'}
# Edge: ('Kensington', "Shepherd's Bush"), Data: {'length': 998.7301384897747, 'line_name': 'London Overground'}
# Edge: ('Kensington', "Earl's Court"), Data: {'length': 1546.6911759759273, 'line_name': 'District'}
# Edge: ("Shepherd's Bush", 'White City'), Data: {'length': 1300.5010932596006, 'line_name': 'Central'}
# Edge: ("Shepherd's Bush", 'Holland Park'), Data: {'length': 911.6794212851544, 'line_name': 'Central'}
# Edge: ('Waterloo', 'Bank and Monument'), Data: {'length': 2542.9544438569455, 'line_name': 'Waterloo & City'}
# Edge: ('Waterloo', 'Embankment'), Data: {'length': 769.4283320889064, 'line_name': 'Bakerloo'}
# Edge: ('Waterloo', 'Kennington'), Data: {'length': 1760.1985166073966, 'line_name': 'Northern'}
# Edge: ('Waterloo', 'Southwark'), Data: {'length': 656.4269295165988, 'line_name': 'Jubilee'}
# Edge: ('Waterloo', 'Westminster'), Data: {'length': 850.3600263608909, 'line_name': 'Jubilee'}
# Edge: ('Waterloo', 'Lambeth North'), Data: {'length': 573.6890561750304, 'line_name': 'Bakerloo'}
# Edge: ('Bank and Monument', "St. Paul's"), Data: {'length': 849.5248408807965, 'line_name': 'Central'}
# Edge: ('Bank and Monument', 'Moorgate'), Data: {'length': 776.8294614297943, 'line_name': 'Northern'}
# Edge: ('Bank and Monument', 'London Bridge'), Data: {'length': 886.7283711455896, 'line_name': 'Northern'}
# Edge: ('Bank and Monument', 'Cannon Street'), Data: {'length': 329.3127160939519, 'line_name': 'District'}
# Edge: ('Bank and Monument', 'Tower Hill'), Data: {'length': 839.7304432545451, 'line_name': 'District'}
# Edge: ('Aldgate East', 'Tower Hill'), Data: {'length': 839.2339844118476, 'line_name': 'District'}
# Edge: ('Stepney Green', 'Mile End'), Data: {'length': 1029.2723772707482, 'line_name': 'District'}
# Edge: ('Mile End', 'Bow Road'), Data: {'length': 624.9321658959916, 'line_name': 'District'}
# Edge: ('Bow Road', 'Bromley-by-Bow'), Data: {'length': 1008.7699093618664, 'line_name': 'District'}
# Edge: ('Bromley-by-Bow', 'West Ham'), Data: {'length': 1212.245542674775, 'line_name': 'District'}
# Edge: ('West Ham', 'Plaistow'), Data: {'length': 929.835493558581, 'line_name': 'District'}
# Edge: ('West Ham', 'Canning Town'), Data: {'length': 1695.080745633354, 'line_name': 'Jubilee'}
# Edge: ('West Ham', 'Abbey Road'), Data: {'length': 533.8424216961267, 'line_name': 'DLR'}
# Edge: ('West Ham', 'Star Lane'), Data: {'length': 863.6516633001042, 'line_name': 'DLR'}
# Edge: ('Plaistow', 'Upton Park'), Data: {'length': 1321.0786434318884, 'line_name': 'District'}
# Edge: ('Upton Park', 'East Ham'), Data: {'length': 1300.2458265804771, 'line_name': 'District'}
# Edge: ('Baker Street', 'Great Portland Street'), Data: {'length': 829.5435436430772, 'line_name': 'Metropolitan'}
# Edge: ('Baker Street', 'Edgware Road'), Data: {'length': 1034.8403674645297, 'line_name': 'Circle'}
# Edge: ('Baker Street', 'Bond Street'), Data: {'length': 1744.278230707794, 'line_name': 'Jubilee'}
# Edge: ('Baker Street', "St. John's Wood"), Data: {'length': 2138.930092928456, 'line_name': 'Jubilee'}
# Edge: ('Baker Street', 'Marylebone'), Data: {'length': 538.2983257941668, 'line_name': 'Bakerloo'}
# Edge: ('Baker Street', "Regent's Park"), Data: {'length': 795.5400496350412, 'line_name': 'Bakerloo'}
# Edge: ('Baker Street', 'Finchley Road'), Data: {'length': 3534.63724731488, 'line_name': 'Metropolitan'}
# Edge: ('Great Portland Street', 'Euston Square'), Data: {'length': 619.9602182594983, 'line_name': 'Metropolitan'}
# Edge: ('Euston Square', "King's Cross St. Pancras"), Data: {'length': 1039.478679695354, 'line_name': 'Metropolitan'}
# Edge: ("King's Cross St. Pancras", 'Farringdon'), Data: {'length': 1857.9984375577433, 'line_name': 'Metropolitan'}
# Edge: ("King's Cross St. Pancras", 'Angel'), Data: {'length': 1180.318720730565, 'line_name': 'Northern'}
# Edge: ("King's Cross St. Pancras", 'Russell Square'), Data: {'length': 870.500704742627, 'line_name': 'Piccadilly'}
# Edge: ("King's Cross St. Pancras", 'Caledonian Road'), Data: {'length': 2034.7003654004757, 'line_name': 'Piccadilly'}
# Edge: ('Farringdon', 'Barbican'), Data: {'length': 460.9099437416139, 'line_name': 'Metropolitan'}
# Edge: ('Barbican', 'Moorgate'), Data: {'length': 707.2883661951114, 'line_name': 'Metropolitan'}
# Edge: ('Moorgate', 'Old Street'), Data: {'length': 853.5197187449882, 'line_name': 'Northern'}
# Edge: ('Edgware Road', 'Paddington'), Data: {'length': 865.6743421093056, 'line_name': 'District'}
# Edge: ('Edgware Road', 'Marylebone'), Data: {'length': 602.8833428859415, 'line_name': 'Bakerloo'}
# Edge: ('Hammersmith', 'Goldhawk Road'), Data: {'length': 1005.5893352451155, 'line_name': 'Circle'}
# Edge: ('Hammersmith', 'Barons Court'), Data: {'length': 893.8320859206598, 'line_name': 'District'}
# Edge: ('Hammersmith', 'Turnham Green'), Data: {'length': 2154.1567167489743, 'line_name': 'Piccadilly'}
# Edge: ('Hammersmith', 'Ravenscourt Park'), Data: {'length': 840.1029182544273, 'line_name': 'District'}
# Edge: ('Goldhawk Road', "Shepherd's Bush Market"), Data: {'length': 439.28942248745847, 'line_name': 'Circle'}
# Edge: ("Shepherd's Bush Market", 'Wood Lane'), Data: {'length': 526.2629552444622, 'line_name': 'Circle'}
# Edge: ('Wood Lane', 'Latimer Road'), Data: {'length': 553.8620754401683, 'line_name': 'Circle'}
# Edge: ('Latimer Road', 'Ladbroke Grove'), Data: {'length': 659.5805348395729, 'line_name': 'Circle'}
# Edge: ('Ladbroke Grove', 'Westbourne Park'), Data: {'length': 805.9399274327974, 'line_name': 'Circle'}
# Edge: ('Westbourne Park', 'Royal Oak'), Data: {'length': 969.4042460432015, 'line_name': 'Circle'}
# Edge: ('Royal Oak', 'Paddington'), Data: {'length': 937.2965127136043, 'line_name': 'Circle'}
# Edge: ('Paddington', 'Warwick Avenue'), Data: {'length': 932.6259398243872, 'line_name': 'Bakerloo'}
# Edge: ('Paddington', 'Bayswater'), Data: {'length': 1164.5036982271358, 'line_name': 'District'}
# Edge: ('West Acton', 'Ealing Broadway'), Data: {'length': 1616.9021668206203, 'line_name': 'Central'}
# Edge: ('West Acton', 'North Acton'), Data: {'length': 1811.4947747426338, 'line_name': 'Central'}
# Edge: ('Ealing Broadway', 'Ealing Common'), Data: {'length': 1565.2970829542974, 'line_name': 'District'}
# Edge: ('North Acton', 'Hanger Lane'), Data: {'length': 2454.2933486674083, 'line_name': 'Central'}
# Edge: ('North Acton', 'East Acton'), Data: {'length': 1180.5193163423162, 'line_name': 'Central'}
# Edge: ('West Ruislip', 'Ruislip Gardens'), Data: {'length': 2124.393196486327, 'line_name': 'Central'}
# Edge: ('Ruislip Gardens', 'South Ruislip'), Data: {'length': 885.8857261563876, 'line_name': 'Central'}
# Edge: ('South Ruislip', 'Northolt'), Data: {'length': 2323.990520709929, 'line_name': 'Central'}
# Edge: ('Northolt', 'Greenford'), Data: {'length': 1818.4662603471857, 'line_name': 'Central'}
# Edge: ('Greenford', 'Perivale'), Data: {'length': 1596.4351211843311, 'line_name': 'Central'}
# Edge: ('Perivale', 'Hanger Lane'), Data: {'length': 2229.885214801866, 'line_name': 'Central'}
# Edge: ('East Acton', 'White City'), Data: {'length': 1957.1845158845322, 'line_name': 'Central'}
# Edge: ('Holland Park', 'Notting Hill Gate'), Data: {'length': 699.7334629696009, 'line_name': 'Central'}
# Edge: ('Notting Hill Gate', 'Queensway'), Data: {'length': 638.3229308800298, 'line_name': 'Central'}
# Edge: ('Notting Hill Gate', 'High Street Kensington'), Data: {'length': 960.6455349941442, 'line_name': 'District'}
# Edge: ('Notting Hill Gate', 'Bayswater'), Data: {'length': 750.0482410997464, 'line_name': 'District'}
# Edge: ('Queensway', 'Lancaster Gate'), Data: {'length': 858.1496214616731, 'line_name': 'Central'}
# Edge: ('Lancaster Gate', 'Marble Arch'), Data: {'length': 1218.6021847604447, 'line_name': 'Central'}
# Edge: ('Marble Arch', 'Bond Street'), Data: {'length': 683.4362347682816, 'line_name': 'Central'}
# Edge: ('Bond Street', 'Oxford Circus'), Data: {'length': 554.3405652906343, 'line_name': 'Central'}
# Edge: ('Bond Street', 'Green Park'), Data: {'length': 1148.9123131606116, 'line_name': 'Jubilee'}
# Edge: ('Oxford Circus', 'Tottenham Court Road'), Data: {'length': 874.3023056336489, 'line_name': 'Central'}
# Edge: ('Oxford Circus', "Regent's Park"), Data: {'length': 978.0506280250825, 'line_name': 'Bakerloo'}
# Edge: ('Oxford Circus', 'Piccadilly Circus'), Data: {'length': 963.8300743985062, 'line_name': 'Bakerloo'}
# Edge: ('Oxford Circus', 'Green Park'), Data: {'length': 1010.5664752575062, 'line_name': 'Victoria'}
# Edge: ('Oxford Circus', 'Warren Street'), Data: {'length': 1149.7144464130404, 'line_name': 'Victoria'}
# Edge: ('Tottenham Court Road', 'Holborn'), Data: {'length': 797.0616575604356, 'line_name': 'Central'}
# Edge: ('Tottenham Court Road', 'Goodge Street'), Data: {'length': 644.4723699965093, 'line_name': 'Northern'}
# Edge: ('Tottenham Court Road', 'Leicester Square'), Data: {'length': 585.9403705631092, 'line_name': 'Northern'}
# Edge: ('Holborn', 'Chancery Lane'), Data: {'length': 565.4837123767416, 'line_name': 'Central'}
# Edge: ('Holborn', 'Covent Garden'), Data: {'length': 632.9405713228314, 'line_name': 'Piccadilly'}
# Edge: ('Holborn', 'Russell Square'), Data: {'length': 706.4343152148972, 'line_name': 'Piccadilly'}
# Edge: ('Chancery Lane', "St. Paul's"), Data: {'length': 1095.1511969319665, 'line_name': 'Central'}
# Edge: ('Leyton', 'Leytonstone'), Data: {'length': 1663.8435602914835, 'line_name': 'Central'}
# Edge: ('Leytonstone', 'Snaresbrook'), Data: {'length': 1658.1506175069483, 'line_name': 'Central'}
# Edge: ('Leytonstone', 'Wanstead'), Data: {'length': 1667.4505513987058, 'line_name': 'Central'}
# Edge: ('Snaresbrook', 'South Woodford'), Data: {'length': 1315.8207360680212, 'line_name': 'Central'}
# Edge: ('South Woodford', 'Woodford'), Data: {'length': 1711.9549160130312, 'line_name': 'Central'}
# Edge: ('Woodford', 'Buckhurst Hill'), Data: {'length': 2333.6093461223836, 'line_name': 'Central'}
# Edge: ('Woodford', 'Roding Valley'), Data: {'length': 1392.430132825825, 'line_name': 'Central'}
# Edge: ('Buckhurst Hill', 'Loughton'), Data: {'length': 1835.4744031274895, 'line_name': 'Central'}
# Edge: ('Loughton', 'Debden'), Data: {'length': 2052.1170899150698, 'line_name': 'Central'}
# Edge: ('Debden', 'Theydon Bois'), Data: {'length': 3322.111158031306, 'line_name': 'Central'}
# Edge: ('Theydon Bois', 'Epping'), Data: {'length': 2625.4836875124006, 'line_name': 'Central'}
# Edge: ('Wanstead', 'Redbridge'), Data: {'length': 1180.385556374102, 'line_name': 'Central'}
# Edge: ('Redbridge', 'Gants Hill'), Data: {'length': 1457.7437616270238, 'line_name': 'Central'}
# Edge: ('Gants Hill', 'Newbury Park'), Data: {'length': 2357.7571209039966, 'line_name': 'Central'}
# Edge: ('Newbury Park', 'Barkingside'), Data: {'length': 1130.5544216561539, 'line_name': 'Central'}
# Edge: ('Barkingside', 'Fairlop'), Data: {'length': 1168.7298360119833, 'line_name': 'Central'}
# Edge: ('Fairlop', 'Hainault'), Data: {'length': 878.6835661434217, 'line_name': 'Central'}
# Edge: ('Hainault', 'Grange Hill'), Data: {'length': 1107.648609974149, 'line_name': 'Central'}
# Edge: ('Grange Hill', 'Chigwell'), Data: {'length': 1346.912730621657, 'line_name': 'Central'}
# Edge: ('Chigwell', 'Roding Valley'), Data: {'length': 2188.659365740107, 'line_name': 'Central'}
# Edge: ('Edgware', 'Burnt Oak'), Data: {'length': 1518.129678863641, 'line_name': 'Northern'}
# Edge: ('Burnt Oak', 'Colindale'), Data: {'length': 1306.4220496936987, 'line_name': 'Northern'}
# Edge: ('Colindale', 'Hendon Central'), Data: {'length': 2152.513378983135, 'line_name': 'Northern'}
# Edge: ('Hendon Central', 'Brent Cross'), Data: {'length': 1133.6073424740214, 'line_name': 'Northern'}
# Edge: ('Brent Cross', 'Golders Green'), Data: {'length': 1515.0891033189582, 'line_name': 'Northern'}
# Edge: ('Golders Green', 'Hampstead'), Data: {'length': 2385.7259071813814, 'line_name': 'Northern'}
# Edge: ('Hampstead', 'Belsize Park'), Data: {'length': 1178.003104093141, 'line_name': 'Northern'}
# Edge: ('Belsize Park', 'Chalk Farm'), Data: {'length': 1038.1009394876469, 'line_name': 'Northern'}
# Edge: ('Chalk Farm', 'Camden Town'), Data: {'length': 993.7771470066834, 'line_name': 'Northern'}
# Edge: ('Camden Town', 'Kentish Town'), Data: {'length': 1277.9656427690122, 'line_name': 'Northern'}
# Edge: ('Camden Town', 'Mornington Crescent'), Data: {'length': 593.8127865687215, 'line_name': 'Northern'}
# Edge: ('Angel', 'Old Street'), Data: {'length': 1520.654760289358, 'line_name': 'Northern'}
# Edge: ('London Bridge', 'Borough'), Data: {'length': 514.5938672619455, 'line_name': 'Northern'}
# Edge: ('London Bridge', 'Bermondsey'), Data: {'length': 2087.8265384222937, 'line_name': 'Jubilee'}
# Edge: ('London Bridge', 'Southwark'), Data: {'length': 1098.3490851025024, 'line_name': 'Jubilee'}
# Edge: ('Borough', 'Elephant & Castle'), Data: {'length': 821.1401522027518, 'line_name': 'Northern'}
# Edge: ('Elephant & Castle', 'Kennington'), Data: {'length': 839.5683892248398, 'line_name': 'Northern'}
# Edge: ('Elephant & Castle', 'Lambeth North'), Data: {'length': 995.7202823035962, 'line_name': 'Bakerloo'}
# Edge: ('Kennington', 'Oval'), Data: {'length': 915.1576843385167, 'line_name': 'Northern'}
# Edge: ('Kennington', 'Nine Elms'), Data: {'length': 2030.621842856102, 'line_name': 'Northern'}
# Edge: ('Oval', 'Stockwell'), Data: {'length': 1284.024538401056, 'line_name': 'Northern'}
# Edge: ('Stockwell', 'Clapham North'), Data: {'length': 952.3018787751389, 'line_name': 'Northern'}
# Edge: ('Stockwell', 'Brixton'), Data: {'length': 1586.7375413017655, 'line_name': 'Victoria'}
# Edge: ('Stockwell', 'Vauxhall'), Data: {'length': 1506.8557095093613, 'line_name': 'Victoria'}
# Edge: ('Clapham North', 'Clapham Common'), Data: {'length': 642.7574913784013, 'line_name': 'Northern'}
# Edge: ('Clapham Common', 'Clapham South'), Data: {'length': 1252.3182327348222, 'line_name': 'Northern'}
# Edge: ('Clapham South', 'Balham'), Data: {'length': 1172.6346008163105, 'line_name': 'Northern'}
# Edge: ('Balham', 'Tooting Bec'), Data: {'length': 975.1654216105981, 'line_name': 'Northern'}
# Edge: ('Tooting Bec', 'Tooting Broadway'), Data: {'length': 1074.961442345419, 'line_name': 'Northern'}
# Edge: ('Tooting Broadway', 'Colliers Wood'), Data: {'length': 1280.4196837865097, 'line_name': 'Northern'}
# Edge: ('Colliers Wood', 'South Wimbledon'), Data: {'length': 1078.4681359938227, 'line_name': 'Northern'}
# Edge: ('South Wimbledon', 'Morden'), Data: {'length': 1533.2463105578936, 'line_name': 'Northern'}
# Edge: ('Finchley Central', 'Mill Hill East'), Data: {'length': 1522.202442550613, 'line_name': 'Northern'}
# Edge: ('Finchley Central', 'West Finchley'), Data: {'length': 1236.790948157093, 'line_name': 'Northern'}
# Edge: ('Finchley Central', 'East Finchley'), Data: {'length': 2370.5565452766623, 'line_name': 'Northern'}
# Edge: ('Charing Cross', 'Embankment'), Data: {'length': 340.3308204587722, 'line_name': 'Bakerloo'}
# Edge: ('Charing Cross', 'Leicester Square'), Data: {'length': 462.0748168446405, 'line_name': 'Northern'}
# Edge: ('Charing Cross', 'Piccadilly Circus'), Data: {'length': 571.8084397484674, 'line_name': 'Bakerloo'}
# Edge: ('Embankment', 'Westminster'), Data: {'length': 753.7645436403577, 'line_name': 'District'}
# Edge: ('Embankment', 'Temple'), Data: {'length': 794.594002561262, 'line_name': 'District'}
# Edge: ('High Barnet', 'Totteridge & Whetstone'), Data: {'length': 2592.6305011470527, 'line_name': 'Northern'}
# Edge: ('Totteridge & Whetstone', 'Woodside Park'), Data: {'length': 1477.101696750776, 'line_name': 'Northern'}
# Edge: ('Woodside Park', 'West Finchley'), Data: {'length': 946.4743468962849, 'line_name': 'Northern'}
# Edge: ('East Finchley', 'Highgate'), Data: {'length': 1749.0206582100698, 'line_name': 'Northern'}
# Edge: ('Highgate', 'Archway'), Data: {'length': 1590.2047962152337, 'line_name': 'Northern'}
# Edge: ('Archway', 'Tufnell Park'), Data: {'length': 993.5361118865152, 'line_name': 'Northern'}
# Edge: ('Tufnell Park', 'Kentish Town'), Data: {'length': 764.6010081567557, 'line_name': 'Northern'}
# Edge: ('Warren Street', 'Goodge Street'), Data: {'length': 532.5730091543625, 'line_name': 'Northern'}
# Edge: ('Leicester Square', 'Piccadilly Circus'), Data: {'length': 374.6914057698147, 'line_name': 'Piccadilly'}
# Edge: ('Leicester Square', 'Covent Garden'), Data: {'length': 365.53129908227436, 'line_name': 'Piccadilly'}
# Edge: ('Battersea Power Station', 'Nine Elms'), Data: {'length': 1073.4653619689052, 'line_name': 'Northern'}
# Edge: ("Earl's Court", 'Gloucester Road'), Data: {'length': 910.1212138490864, 'line_name': 'District'}
# Edge: ("Earl's Court", 'Barons Court'), Data: {'length': 1504.7980653620925, 'line_name': 'Piccadilly'}
# Edge: ("Earl's Court", 'West Kensington'), Data: {'length': 944.0652943047372, 'line_name': 'District'}
# Edge: ("Earl's Court", 'High Street Kensington'), Data: {'length': 1300.860111181769, 'line_name': 'District'}
# Edge: ('Gloucester Road', 'South Kensington'), Data: {'length': 751.3334794399693, 'line_name': 'District'}
# Edge: ('Gloucester Road', 'High Street Kensington'), Data: {'length': 1005.1187862236483, 'line_name': 'Circle'}
# Edge: ('Barons Court', 'West Kensington'), Data: {'length': 563.6761451115776, 'line_name': 'District'}
# Edge: ('Turnham Green', 'Acton Town'), Data: {'length': 2222.542223351653, 'line_name': 'Piccadilly'}
# Edge: ('Turnham Green', 'Stamford Brook'), Data: {'length': 610.2892102797041, 'line_name': 'District'}
# Edge: ('Turnham Green', 'Chiswick Park'), Data: {'length': 950.3729810236479, 'line_name': 'District'}
# Edge: ('Acton Town', 'South Ealing'), Data: {'length': 2127.939214032974, 'line_name': 'Piccadilly'}
# Edge: ('Acton Town', 'Ealing Common'), Data: {'length': 1026.622829137713, 'line_name': 'District'}
# Edge: ('Acton Town', 'Chiswick Park'), Data: {'length': 1274.9448068885617, 'line_name': 'District'}
# Edge: ('South Ealing', 'Northfields'), Data: {'length': 452.9452906768383, 'line_name': 'Piccadilly'}
# Edge: ('Knightsbridge', 'South Kensington'), Data: {'length': 1300.815318533093, 'line_name': 'Piccadilly'}
# Edge: ('Knightsbridge', 'Hyde Park Corner'), Data: {'length': 583.9535882999706, 'line_name': 'Piccadilly'}
# Edge: ('South Kensington', 'Sloane Square'), Data: {'length': 1173.2223716014348, 'line_name': 'District'}
# Edge: ('Hyde Park Corner', 'Green Park'), Data: {'length': 779.8893002668186, 'line_name': 'Piccadilly'}
# Edge: ('Green Park', 'Piccadilly Circus'), Data: {'length': 777.6260868051975, 'line_name': 'Piccadilly'}
# Edge: ('Green Park', 'Westminster'), Data: {'length': 1423.7801946060954, 'line_name': 'Jubilee'}
# Edge: ('Green Park', 'Victoria'), Data: {'length': 1209.5998088020804, 'line_name': 'Victoria'}
# Edge: ('Caledonian Road', 'Holloway Road'), Data: {'length': 615.2974429781583, 'line_name': 'Piccadilly'}
# Edge: ('Holloway Road', 'Arsenal'), Data: {'length': 666.7091358867409, 'line_name': 'Piccadilly'}
# Edge: ('Arsenal', 'Finsbury Park'), Data: {'length': 772.7526932281038, 'line_name': 'Piccadilly'}
# Edge: ('Finsbury Park', 'Manor House'), Data: {'length': 1116.1136272204067, 'line_name': 'Piccadilly'}
# Edge: ('Manor House', 'Turnpike Lane'), Data: {'length': 2321.6593584487423, 'line_name': 'Piccadilly'}
# Edge: ('Turnpike Lane', 'Wood Green'), Data: {'length': 930.8256254031667, 'line_name': 'Piccadilly'}
# Edge: ('Wood Green', 'Bounds Green'), Data: {'length': 1505.437914405501, 'line_name': 'Piccadilly'}
# Edge: ('Bounds Green', 'Arnos Grove'), Data: {'length': 1354.2424903762085, 'line_name': 'Piccadilly'}
# Edge: ('Arnos Grove', 'Southgate'), Data: {'length': 1979.1485866133203, 'line_name': 'Piccadilly'}
# Edge: ('Southgate', 'Oakwood'), Data: {'length': 1865.6448541161906, 'line_name': 'Piccadilly'}
# Edge: ('Oakwood', 'Cockfosters'), Data: {'length': 1343.9783464004338, 'line_name': 'Piccadilly'}
# Edge: ('Rayners Lane', 'South Harrow'), Data: {'length': 1805.5567061354982, 'line_name': 'Piccadilly'}
# Edge: ('Rayners Lane', 'Eastcote'), Data: {'length': 1819.3543779174295, 'line_name': 'Metropolitan'}
# Edge: ('Rayners Lane', 'West Harrow'), Data: {'length': 1364.1124364105162, 'line_name': 'Metropolitan'}
# Edge: ('South Harrow', 'Sudbury Hill'), Data: {'length': 1485.465659034139, 'line_name': 'Piccadilly'}
# Edge: ('Sudbury Hill', 'Sudbury Town'), Data: {'length': 1617.0566152944361, 'line_name': 'Piccadilly'}
# Edge: ('Sudbury Town', 'Alperton'), Data: {'length': 1660.3572820422125, 'line_name': 'Piccadilly'}
# Edge: ('Alperton', 'Park Royal'), Data: {'length': 1922.398209631674, 'line_name': 'Piccadilly'}
# Edge: ('Park Royal', 'North Ealing'), Data: {'length': 1099.6584506284205, 'line_name': 'Piccadilly'}
# Edge: ('North Ealing', 'Ealing Common'), Data: {'length': 924.4084541330353, 'line_name': 'Piccadilly'}
# Edge: ('Uxbridge', 'Hillingdon'), Data: {'length': 2144.395127372481, 'line_name': 'Metropolitan'}
# Edge: ('Hillingdon', 'Ickenham'), Data: {'length': 1124.4371952028953, 'line_name': 'Metropolitan'}
# Edge: ('Ickenham', 'Ruislip'), Data: {'length': 1785.6549823456592, 'line_name': 'Metropolitan'}
# Edge: ('Ruislip', 'Ruislip Manor'), Data: {'length': 678.8859802386172, 'line_name': 'Metropolitan'}
# Edge: ('Ruislip Manor', 'Eastcote'), Data: {'length': 1126.2390522053406, 'line_name': 'Metropolitan'}
# Edge: ('Heathrow Terminal 4', 'Hatton Cross'), Data: {'length': 1876.332693638775, 'line_name': 'Piccadilly'}
# Edge: ('Heathrow Terminal 4', 'Heathrow Terminals 2 & 3'), Data: {'length': 4186.5370884130325, 'line_name': 'Piccadilly'}
# Edge: ('Hatton Cross', 'Heathrow Terminals 2 & 3'), Data: {'length': 2412.750945791165, 'line_name': 'Piccadilly'}
# Edge: ('Hatton Cross', 'Hounslow West'), Data: {'length': 2803.473661246835, 'line_name': 'Piccadilly'}
# Edge: ('Heathrow Terminals 2 & 3', 'Heathrow Terminal 5'), Data: {'length': 2455.278475636329, 'line_name': 'Piccadilly'}
# Edge: ('Hounslow West', 'Hounslow Central'), Data: {'length': 1479.0836919963704, 'line_name': 'Piccadilly'}
# Edge: ('Hounslow Central', 'Hounslow East'), Data: {'length': 745.6843834209199, 'line_name': 'Piccadilly'}
# Edge: ('Hounslow East', 'Osterley'), Data: {'length': 967.4946724433414, 'line_name': 'Piccadilly'}
# Edge: ('Osterley', 'Boston Manor'), Data: {'length': 2560.8142912612416, 'line_name': 'Piccadilly'}
# Edge: ('Boston Manor', 'Northfields'), Data: {'length': 930.8521452439904, 'line_name': 'Piccadilly'}
# Edge: ('Wembley Park', 'Kingsbury'), Data: {'length': 2916.771558050728, 'line_name': 'Jubilee'}
# Edge: ('Wembley Park', 'Neasden'), Data: {'length': 2353.165938195784, 'line_name': 'Jubilee'}
# Edge: ('Wembley Park', 'Preston Road'), Data: {'length': 1419.7351657628526, 'line_name': 'Metropolitan'}
# Edge: ('Wembley Park', 'Finchley Road'), Data: {'length': 7266.373927496486, 'line_name': 'Metropolitan'}
# Edge: ('Kingsbury', 'Queensbury'), Data: {'length': 1245.995234363654, 'line_name': 'Jubilee'}
# Edge: ('Queensbury', 'Canons Park'), Data: {'length': 1693.3073431971377, 'line_name': 'Jubilee'}
# Edge: ('Canons Park', 'Stanmore'), Data: {'length': 1419.669476245658, 'line_name': 'Jubilee'}
# Edge: ('Canning Town', 'North Greenwich'), Data: {'length': 1799.9427780922347, 'line_name': 'Jubilee'}
# Edge: ('Canning Town', 'Star Lane'), Data: {'length': 866.9991916215074, 'line_name': 'DLR'}
# Edge: ('Canning Town', 'Royal Victoria'), Data: {'length': 989.5890743359752, 'line_name': 'DLR'}
# Edge: ('Canning Town', 'East India'), Data: {'length': 1155.218499145243, 'line_name': 'DLR'}
# Edge: ('Canning Town', 'West Silvertown'), Data: {'length': 1651.1250609247024, 'line_name': 'DLR'}
# Edge: ('North Greenwich', 'Canary Wharf'), Data: {'length': 1829.783291029508, 'line_name': 'Jubilee'}
# Edge: ('Canary Wharf', 'West India Quay'), Data: {'length': 327.244216246571, 'line_name': 'DLR'}
# Edge: ('Canary Wharf', 'Heron Quays'), Data: {'length': 351.5719873946413, 'line_name': 'DLR'}
# Edge: ('Westminster', "St. James's Park"), Data: {'length': 560.7493399067275, 'line_name': 'District'}
# Edge: ("St. John's Wood", 'Swiss Cottage'), Data: {'length': 969.9402928050129, 'line_name': 'Jubilee'}
# Edge: ('Swiss Cottage', 'Finchley Road'), Data: {'length': 645.352744225376, 'line_name': 'Jubilee'}
# Edge: ('Neasden', 'Dollis Hill'), Data: {'length': 785.5830137547828, 'line_name': 'Jubilee'}
# Edge: ('Dollis Hill', 'Willesden Green'), Data: {'length': 1246.109381792944, 'line_name': 'Jubilee'}
# Edge: ('Willesden Green', 'Kilburn'), Data: {'length': 1185.0579298370324, 'line_name': 'Jubilee'}
# Edge: ('Maryland', 'Forest Gate'), Data: {'length': 1303.7590706656426, 'line_name': 'TfL Rail'}
# Edge: ('Forest Gate', 'Manor Park'), Data: {'length': 1548.76580881777, 'line_name': 'TfL Rail'}
# Edge: ('Manor Park', 'Ilford'), Data: {'length': 1831.4694245351989, 'line_name': 'TfL Rail'}
# Edge: ('Ilford', 'Seven Kings'), Data: {'length': 1970.5719243436356, 'line_name': 'TfL Rail'}
# Edge: ('Seven Kings', 'Goodmayes'), Data: {'length': 983.7481715426209, 'line_name': 'TfL Rail'}
# Edge: ('Goodmayes', 'Chadwell Heath'), Data: {'length': 1284.1799168510881, 'line_name': 'TfL Rail'}
# Edge: ('Gidea Park', 'Harold Wood'), Data: {'length': 2284.6409372785006, 'line_name': 'TfL Rail'}
# Edge: ('Harold Wood', 'Brentwood'), Data: {'length': 5269.263106583304, 'line_name': 'TfL Rail'}
# Edge: ('Brentwood', 'Shenfield'), Data: {'length': 3348.9245038385347, 'line_name': 'TfL Rail'}
# Edge: ('Kilburn Park', 'Maida Vale'), Data: {'length': 851.7815229276852, 'line_name': 'Bakerloo'}
# Edge: ('Maida Vale', 'Warwick Avenue'), Data: {'length': 787.6125699512305, 'line_name': 'Bakerloo'}
# Edge: ('Sloane Square', 'Victoria'), Data: {'length': 1165.7590132287191, 'line_name': 'District'}
# Edge: ('Victoria', "St. James's Park"), Data: {'length': 777.3055963190485, 'line_name': 'District'}
# Edge: ('Victoria', 'Pimlico'), Data: {'length': 1399.8781509033963, 'line_name': 'Victoria'}
# Edge: ('Temple', 'Blackfriars'), Data: {'length': 752.0407994032548, 'line_name': 'District'}
# Edge: ('Blackfriars', 'Mansion House'), Data: {'length': 660.2642961234002, 'line_name': 'District'}
# Edge: ('Mansion House', 'Cannon Street'), Data: {'length': 248.17870615089865, 'line_name': 'District'}
# Edge: ('Tower Hill', 'Aldgate'), Data: {'length': 597.1867971231038, 'line_name': 'Circle'}
# Edge: ('Ravenscourt Park', 'Stamford Brook'), Data: {'length': 709.2895541696818, 'line_name': 'District'}
# Edge: ('Wimbledon', 'Wimbledon Park'), Data: {'length': 1655.9122645891123, 'line_name': 'District'}
# Edge: ('Wimbledon Park', 'Southfields'), Data: {'length': 1359.649769982491, 'line_name': 'District'}
# Edge: ('Southfields', 'East Putney'), Data: {'length': 1630.8880949905108, 'line_name': 'District'}
# Edge: ('East Putney', 'Putney Bridge'), Data: {'length': 1058.5655902705403, 'line_name': 'District'}
# Edge: ('Putney Bridge', 'Parsons Green'), Data: {'length': 994.4623493165212, 'line_name': 'District'}
# Edge: ('Parsons Green', 'Fulham Broadway'), Data: {'length': 702.3383314281062, 'line_name': 'District'}
# Edge: ('Upney', 'Becontree'), Data: {'length': 1927.1569041478324, 'line_name': 'District'}
# Edge: ('Becontree', 'Dagenham Heathway'), Data: {'length': 1428.200777067089, 'line_name': 'District'}
# Edge: ('Dagenham Heathway', 'Dagenham East'), Data: {'length': 1279.2277890495373, 'line_name': 'District'}
# Edge: ('Dagenham East', 'Elm Park'), Data: {'length': 2295.788356383098, 'line_name': 'District'}
# Edge: ('Elm Park', 'Hornchurch'), Data: {'length': 1544.3272116890414, 'line_name': 'District'}
# Edge: ('Hornchurch', 'Upminster Bridge'), Data: {'length': 1226.92948021644, 'line_name': 'District'}
# Edge: ('West Harrow', 'Harrow-on-the-Hill'), Data: {'length': 1241.8686903537798, 'line_name': 'Metropolitan'}
# Edge: ('Harrow-on-the-Hill', 'North Harrow'), Data: {'length': 1979.628722481944, 'line_name': 'Metropolitan'}
# Edge: ('Harrow-on-the-Hill', 'Northwick Park'), Data: {'length': 1303.1318574246761, 'line_name': 'Metropolitan'}
# Edge: ('Amersham', 'Chalfont & Latimer'), Data: {'length': 3385.6601473563414, 'line_name': 'Metropolitan'}
# Edge: ('Chalfont & Latimer', 'Chorleywood'), Data: {'length': 3512.8532914577477, 'line_name': 'Metropolitan'}
# Edge: ('Chalfont & Latimer', 'Chesham'), Data: {'length': 6315.936388258736, 'line_name': 'Metropolitan'}
# Edge: ('Chorleywood', 'Rickmansworth'), Data: {'length': 3551.353240563792, 'line_name': 'Metropolitan'}
# Edge: ('Rickmansworth', 'Moor Park'), Data: {'length': 3397.2194579963216, 'line_name': 'Metropolitan'}
# Edge: ('Moor Park', 'Northwood'), Data: {'length': 2218.2991124084024, 'line_name': 'Metropolitan'}
# Edge: ('Moor Park', 'Croxley'), Data: {'length': 2910.1506484065285, 'line_name': 'Metropolitan'}
# Edge: ('Northwood', 'Northwood Hills'), Data: {'length': 1586.6688847131977, 'line_name': 'Metropolitan'}
# Edge: ('Northwood Hills', 'Pinner'), Data: {'length': 2158.6485916960487, 'line_name': 'Metropolitan'}
# Edge: ('Pinner', 'North Harrow'), Data: {'length': 1517.7554108908482, 'line_name': 'Metropolitan'}
# Edge: ('Northwick Park', 'Preston Road'), Data: {'length': 1733.1337992221177, 'line_name': 'Metropolitan'}
# Edge: ('Croxley', 'Watford'), Data: {'length': 2054.878524660146, 'line_name': 'Metropolitan'}
# Edge: ('Stratford High Street', 'Abbey Road'), Data: {'length': 655.2113012868256, 'line_name': 'DLR'}
# Edge: ('Royal Victoria', 'Custom House'), Data: {'length': 606.3433882279246, 'line_name': 'DLR'}
# Edge: ('Limehouse', 'Westferry'), Data: {'length': 973.6170070798671, 'line_name': 'DLR'}
# Edge: ('Westferry', 'West India Quay'), Data: {'length': 576.9560077519421, 'line_name': 'DLR'}
# Edge: ('Westferry', 'Poplar'), Data: {'length': 682.5134447409253, 'line_name': 'DLR'}
# Edge: ('West India Quay', 'Poplar'), Data: {'length': 260.8625738886104, 'line_name': 'DLR'}
# Edge: ('Heron Quays', 'South Quay'), Data: {'length': 651.6418490679744, 'line_name': 'DLR'}
# Edge: ('South Quay', 'Crossharbour'), Data: {'length': 596.7475038226244, 'line_name': 'DLR'}
# Edge: ('Crossharbour', 'Mudchute'), Data: {'length': 466.369801569662, 'line_name': 'DLR'}
# Edge: ('Mudchute', 'Island Gardens'), Data: {'length': 553.4510088555899, 'line_name': 'DLR'}
# Edge: ('Island Gardens', 'Cutty Sark'), Data: {'length': 797.6025385743914, 'line_name': 'DLR'}
# Edge: ('Cutty Sark', 'Greenwich'), Data: {'length': 633.6424322191381, 'line_name': 'DLR'}
# Edge: ('Greenwich', 'Deptford Bridge'), Data: {'length': 784.8639108674407, 'line_name': 'DLR'}
# Edge: ('Deptford Bridge', 'Elverson Road'), Data: {'length': 727.5004500175838, 'line_name': 'DLR'}
# Edge: ('Elverson Road', 'Lewisham'), Data: {'length': 563.545791869791, 'line_name': 'DLR'}
# Edge: ('Poplar', 'All Saints'), Data: {'length': 751.9819426773367, 'line_name': 'DLR'}
# Edge: ('Poplar', 'Blackwall'), Data: {'length': 722.9585574521175, 'line_name': 'DLR'}
# Edge: ('All Saints', 'Langdon Park'), Data: {'length': 506.4239944344515, 'line_name': 'DLR'}
# Edge: ('Blackwall', 'East India'), Data: {'length': 391.30720560220516, 'line_name': 'DLR'}
# Edge: ('Custom House', 'Prince Regent'), Data: {'length': 524.4868788091322, 'line_name': 'DLR'}
# Edge: ('Prince Regent', 'Royal Albert'), Data: {'length': 888.4204824783974, 'line_name': 'DLR'}
# Edge: ('Royal Albert', 'Beckton Park'), Data: {'length': 666.2264934724285, 'line_name': 'DLR'}
# Edge: ('Beckton Park', 'Cyprus'), Data: {'length': 628.1101328837806, 'line_name': 'DLR'}
# Edge: ('Cyprus', 'Gallions Reach'), Data: {'length': 741.7738804546091, 'line_name': 'DLR'}
# Edge: ('Gallions Reach', 'Beckton'), Data: {'length': 1236.2482759987142, 'line_name': 'DLR'}
# Edge: ('Langdon Park', 'Devons Road'), Data: {'length': 852.3487962902293, 'line_name': 'DLR'}
# Edge: ('Devons Road', 'Bow Church'), Data: {'length': 638.4852454662258, 'line_name': 'DLR'}
# Edge: ('Bow Church', 'Pudding Mill Lane'), Data: {'length': 1008.2942934529501, 'line_name': 'DLR'}
# Edge: ('Woolwich Arsenal', 'King George V'), Data: {'length': 2429.275743328937, 'line_name': 'DLR'}
# Edge: ('King George V', 'London City Airport'), Data: {'length': 1028.5768913264737, 'line_name': 'DLR'}
# Edge: ('West Silvertown', 'Pontoon Dock'), Data: {'length': 756.0458898720703, 'line_name': 'DLR'}
# Edge: ('Pontoon Dock', 'London City Airport'), Data: {'length': 1141.3500296616812, 'line_name': 'DLR'}
# Edge: ('Vauxhall', 'Pimlico'), Data: {'length': 825.3282533076276, 'line_name': 'Victoria'}

# %%
# Add 'velocity' field to each edge with value 60
for u, v, data in G.edges(data=True):
    data['velocity'] = 9

# %%
for edge, data in dict(G.edges).items():
    print(f"Edge: {edge}, Data: {data}")
# Out:
# Edge: ('Cambridge Heath', 'Bethnal Green'), Data: {'length': 831.8715882468825, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Cambridge Heath', 'London Fields'), Data: {'length': 979.4169859715292, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Bethnal Green', 'Liverpool Street'), Data: {'length': 2407.22114645448, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Bethnal Green', 'Mile End'), Data: {'length': 1992.4218024894628, 'line_name': 'Central', 'velocity': 9}
# Edge: ('London Fields', 'Hackney Downs'), Data: {'length': 926.0127117881309, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Hackney Downs', 'Rectory Road'), Data: {'length': 1201.0223774948356, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Hackney Downs', 'Clapton'), Data: {'length': 1493.1171134857082, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Rectory Road', 'Stoke Newington'), Data: {'length': 783.2557143388774, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Stoke Newington', 'Stamford Hill'), Data: {'length': 1211.4700832725982, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Stamford Hill', 'Seven Sisters'), Data: {'length': 1125.083404665905, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Seven Sisters', 'Bruce Grove'), Data: {'length': 1332.2700481811246, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Seven Sisters', 'Finsbury Park'), Data: {'length': 3405.888390028811, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Seven Sisters', 'Tottenham Hale'), Data: {'length': 1153.5391678792378, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Bruce Grove', 'White Hart Lane'), Data: {'length': 1213.4238875288067, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('White Hart Lane', 'Silver Street'), Data: {'length': 1199.9213592935591, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Silver Street', 'Edmonton Green'), Data: {'length': 1198.454675885083, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Edmonton Green', 'Southbury'), Data: {'length': 2970.5494541645353, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Edmonton Green', 'Bush Hill Park'), Data: {'length': 1912.0054425449946, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Southbury', 'Turkey Street'), Data: {'length': 2701.5767260364164, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Turkey Street', 'Theobalds Grove'), Data: {'length': 2339.842151062409, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Theobalds Grove', 'Cheshunt'), Data: {'length': 1539.905627999705, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Liverpool Street', 'Aldgate East'), Data: {'length': 965.8659667181719, 'line_name': 'Hammersmith & City', 'velocity': 9}
# Edge: ('Liverpool Street', 'Moorgate'), Data: {'length': 434.0874486023312, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Liverpool Street', 'Bank and Monument'), Data: {'length': 841.502683749556, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Liverpool Street', 'Stratford'), Data: {'length': 6698.461270481002, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Liverpool Street', 'Aldgate'), Data: {'length': 722.0840820475358, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Enfield Town', 'Bush Hill Park'), Data: {'length': 1406.8660227786572, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Romford', 'Emerson Park'), Data: {'length': 2920.238516197714, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Romford', 'Chadwell Heath'), Data: {'length': 3869.588046544387, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Romford', 'Gidea Park'), Data: {'length': 1693.9009368557536, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Emerson Park', 'Upminster'), Data: {'length': 2626.8304525481967, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Upminster', 'Upminster Bridge'), Data: {'length': 1310.782633781778, 'line_name': 'District', 'velocity': 9}
# Edge: ('Clapton', 'St James Street'), Data: {'length': 2772.7386645824745, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('St James Street', 'Walthamstow Central'), Data: {'length': 970.7099871668147, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Walthamstow Central', 'Wood Street'), Data: {'length': 1367.6959005246442, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Walthamstow Central', 'Blackhorse Road'), Data: {'length': 1559.0637437028229, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Wood Street', 'Highams Park'), Data: {'length': 2579.1394084284793, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Highams Park', 'Chingford'), Data: {'length': 2859.881267390292, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Richmond', 'Kew Gardens'), Data: {'length': 2168.1632640796356, 'line_name': 'District', 'velocity': 9}
# Edge: ('Kew Gardens', 'Gunnersbury'), Data: {'length': 1780.2809189479904, 'line_name': 'District', 'velocity': 9}
# Edge: ('Gunnersbury', 'South Acton'), Data: {'length': 1016.8393795878126, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Gunnersbury', 'Turnham Green'), Data: {'length': 1547.3179979156596, 'line_name': 'District', 'velocity': 9}
# Edge: ('South Acton', 'Acton Central'), Data: {'length': 1152.5272704397912, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Harrow & Wealdstone', 'Kenton'), Data: {'length': 1780.6719958813244, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Harrow & Wealdstone', 'Headstone Lane'), Data: {'length': 1850.9142197147085, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Kenton', 'South Kenton'), Data: {'length': 1386.9692312837617, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('South Kenton', 'North Wembley'), Data: {'length': 935.7451700868527, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('North Wembley', 'Wembley Central'), Data: {'length': 1348.156442480471, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Wembley Central', 'Stonebridge Park'), Data: {'length': 1718.0984669685454, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Stonebridge Park', 'Harlesden'), Data: {'length': 1494.9487766659236, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Harlesden', 'Willesden Junction'), Data: {'length': 1144.2331916335786, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Willesden Junction', 'Kensal Green'), Data: {'length': 1352.2488873708176, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Willesden Junction', 'Acton Central'), Data: {'length': 3065.465621352297, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Willesden Junction', 'Kensal Rise'), Data: {'length': 1629.2437946821572, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Willesden Junction', "Shepherd's Bush"), Data: {'length': 3906.332911932161, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Kensal Green', "Queen's Park"), Data: {'length': 1384.6256610695687, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ("Queen's Park", 'Kilburn High Road'), Data: {'length': 1064.503149075238, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ("Queen's Park", 'Kilburn Park'), Data: {'length': 809.8309508921109, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Kilburn High Road', 'South Hampstead'), Data: {'length': 976.3553884726724, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Kensal Rise', 'Brondesbury Park'), Data: {'length': 1002.535433570864, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Brondesbury Park', 'Brondesbury'), Data: {'length': 742.1886718422229, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Brondesbury', 'West Hampstead'), Data: {'length': 849.2312353800593, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('West Hampstead', 'Finchley Road & Frognal'), Data: {'length': 630.6575296106906, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('West Hampstead', 'Kilburn'), Data: {'length': 1015.6216072668218, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('West Hampstead', 'Finchley Road'), Data: {'length': 755.7345247171764, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Finchley Road & Frognal', 'Hampstead Heath'), Data: {'length': 1420.5331475476078, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Hampstead Heath', 'Gospel Oak'), Data: {'length': 938.5606009702096, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Gospel Oak', 'Kentish Town West'), Data: {'length': 1091.15942728907, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Gospel Oak', 'Upper Holloway'), Data: {'length': 1900.2253023634726, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Kentish Town West', 'Camden Road'), Data: {'length': 898.2449445992788, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Camden Road', 'Caledonian Road & Barnsbury'), Data: {'length': 1764.578290487494, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Caledonian Road & Barnsbury', 'Highbury & Islington'), Data: {'length': 813.6000250382895, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Highbury & Islington', 'Canonbury'), Data: {'length': 981.1097681002285, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Highbury & Islington', "King's Cross St. Pancras"), Data: {'length': 2581.853009656672, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Highbury & Islington', 'Finsbury Park'), Data: {'length': 2057.343960440664, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Canonbury', 'Dalston Kingsland'), Data: {'length': 1181.178340953049, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Canonbury', 'Dalston Junction'), Data: {'length': 1363.8686463389834, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Dalston Kingsland', 'Hackney Central'), Data: {'length': 1289.7562439979279, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Hackney Central', 'Homerton'), Data: {'length': 1035.6155471122022, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Homerton', 'Hackney Wick'), Data: {'length': 1343.350383060703, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Hackney Wick', 'Stratford'), Data: {'length': 1572.923279349752, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Stratford', 'Mile End'), Data: {'length': 2805.0013918567734, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Stratford', 'Leyton'), Data: {'length': 2131.342925924301, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Stratford', 'West Ham'), Data: {'length': 1673.5095151310568, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Stratford', 'Maryland'), Data: {'length': 951.3047206005755, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Stratford', 'Stratford High Street'), Data: {'length': 519.300073543952, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Stratford', 'Pudding Mill Lane'), Data: {'length': 1137.0332570871155, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Stratford', 'Stratford International'), Data: {'length': 1321.0681171139224, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Whitechapel', 'Shadwell'), Data: {'length': 1094.3438658652442, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Whitechapel', 'Shoreditch High Street'), Data: {'length': 1195.8214474657964, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Whitechapel', 'Aldgate East'), Data: {'length': 963.3340688058626, 'line_name': 'District', 'velocity': 9}
# Edge: ('Whitechapel', 'Stepney Green'), Data: {'length': 1080.1641834945203, 'line_name': 'District', 'velocity': 9}
# Edge: ('Shadwell', 'Wapping'), Data: {'length': 858.7781938099081, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Shadwell', 'Bank and Monument'), Data: {'length': 2317.101463770503, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Shadwell', 'Limehouse'), Data: {'length': 1192.5037329452541, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Shadwell', 'Tower Gateway'), Data: {'length': 1277.3034866933224, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Wapping', 'Rotherhithe'), Data: {'length': 450.55636194478814, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Rotherhithe', 'Canada Water'), Data: {'length': 435.2544814876285, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Canada Water', 'Surrey Quays'), Data: {'length': 549.5162309595552, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Canada Water', 'Canary Wharf'), Data: {'length': 2601.8662764926153, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Canada Water', 'Bermondsey'), Data: {'length': 989.5169205602908, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Surrey Quays', 'New Cross Gate'), Data: {'length': 2081.7685848768274, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Surrey Quays', 'New Cross'), Data: {'length': 2316.997521079707, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Surrey Quays', 'Queens Road Peckham'), Data: {'length': 2392.258374234857, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('New Cross Gate', 'Brockley'), Data: {'length': 1229.0796568850708, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Shoreditch High Street', 'Hoxton'), Data: {'length': 1075.252398134154, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Sydenham', 'Crystal Palace'), Data: {'length': 1979.8329341857207, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Sydenham', 'Forest Hill'), Data: {'length': 1415.1049911533883, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Sydenham', 'Penge West'), Data: {'length': 1185.270598549146, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Queens Road Peckham', 'Peckham Rye'), Data: {'length': 1130.560878083332, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Peckham Rye', 'Denmark Hill'), Data: {'length': 1335.5866109262497, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Denmark Hill', 'Clapham High Street'), Data: {'length': 3241.98511254321, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Clapham High Street', 'Wandsworth Road'), Data: {'length': 621.9703299905578, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Wandsworth Road', 'Clapham Junction'), Data: {'length': 2876.435508263358, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Wandsworth Road', 'Battersea Park'), Data: {'length': 1168.4892614627925, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Clapham Junction', 'Imperial Wharf'), Data: {'length': 2203.7682304786213, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('West Brompton', 'Imperial Wharf'), Data: {'length': 1577.1942937848828, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('West Brompton', 'Kensington'), Data: {'length': 1545.6914875144848, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('West Brompton', "Earl's Court"), Data: {'length': 567.389191763215, 'line_name': 'District', 'velocity': 9}
# Edge: ('West Brompton', 'Fulham Broadway'), Data: {'length': 942.7618764086681, 'line_name': 'District', 'velocity': 9}
# Edge: ('South Hampstead', 'Euston'), Data: {'length': 3831.445184198609, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Euston', 'Camden Town'), Data: {'length': 1373.598810172985, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Euston', "King's Cross St. Pancras"), Data: {'length': 863.3696737515771, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Euston', 'Mornington Crescent'), Data: {'length': 783.388597357072, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Euston', 'Warren Street'), Data: {'length': 546.2012018841854, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Bushey', 'Watford High Street'), Data: {'length': 1314.2502642277932, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Bushey', 'Carpenders Park'), Data: {'length': 1962.9784655331114, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Watford High Street', 'Watford Junction'), Data: {'length': 1406.0375315796248, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Carpenders Park', 'Hatch End'), Data: {'length': 2443.342296917783, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Hatch End', 'Headstone Lane'), Data: {'length': 1146.1498418244364, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Upper Holloway', 'Crouch Hill'), Data: {'length': 1214.8963405680036, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Crouch Hill', 'Harringay Green Lanes'), Data: {'length': 1506.577799946524, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Harringay Green Lanes', 'South Tottenham'), Data: {'length': 1858.7650958291101, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('South Tottenham', 'Blackhorse Road'), Data: {'length': 2291.1399207657278, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Blackhorse Road', 'Walthamstow Queens Road'), Data: {'length': 1422.7370347035717, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Blackhorse Road', 'Tottenham Hale'), Data: {'length': 1414.2057308806673, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Walthamstow Queens Road', 'Leyton Midland Road'), Data: {'length': 1781.9840512516762, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Leyton Midland Road', 'Leytonstone High Road'), Data: {'length': 1214.0970069086518, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Leytonstone High Road', 'Wanstead Park'), Data: {'length': 1919.3048072770791, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Wanstead Park', 'Woodgrange Park'), Data: {'length': 1320.7732927901427, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Woodgrange Park', 'Barking'), Data: {'length': 2808.655162001238, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Barking', 'East Ham'), Data: {'length': 2424.925792945743, 'line_name': 'District', 'velocity': 9}
# Edge: ('Barking', 'Upney'), Data: {'length': 1367.2954815493517, 'line_name': 'District', 'velocity': 9}
# Edge: ('Brockley', 'Honor Oak Park'), Data: {'length': 1734.321174338685, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Honor Oak Park', 'Forest Hill'), Data: {'length': 1258.06397398924, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Penge West', 'Anerley'), Data: {'length': 682.1023245902426, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Anerley', 'Norwood Junction'), Data: {'length': 1798.4480565963026, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Norwood Junction', 'West Croydon'), Data: {'length': 2935.5862436031935, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Dalston Junction', 'Haggerston'), Data: {'length': 808.0082953159692, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Haggerston', 'Hoxton'), Data: {'length': 834.5786379628204, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Kensington', "Shepherd's Bush"), Data: {'length': 998.7301384897747, 'line_name': 'London Overground', 'velocity': 9}
# Edge: ('Kensington', "Earl's Court"), Data: {'length': 1546.6911759759273, 'line_name': 'District', 'velocity': 9}
# Edge: ("Shepherd's Bush", 'White City'), Data: {'length': 1300.5010932596006, 'line_name': 'Central', 'velocity': 9}
# Edge: ("Shepherd's Bush", 'Holland Park'), Data: {'length': 911.6794212851544, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Waterloo', 'Bank and Monument'), Data: {'length': 2542.9544438569455, 'line_name': 'Waterloo & City', 'velocity': 9}
# Edge: ('Waterloo', 'Embankment'), Data: {'length': 769.4283320889064, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Waterloo', 'Kennington'), Data: {'length': 1760.1985166073966, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Waterloo', 'Southwark'), Data: {'length': 656.4269295165988, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Waterloo', 'Westminster'), Data: {'length': 850.3600263608909, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Waterloo', 'Lambeth North'), Data: {'length': 573.6890561750304, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Bank and Monument', "St. Paul's"), Data: {'length': 849.5248408807965, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Bank and Monument', 'Moorgate'), Data: {'length': 776.8294614297943, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Bank and Monument', 'London Bridge'), Data: {'length': 886.7283711455896, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Bank and Monument', 'Cannon Street'), Data: {'length': 329.3127160939519, 'line_name': 'District', 'velocity': 9}
# Edge: ('Bank and Monument', 'Tower Hill'), Data: {'length': 839.7304432545451, 'line_name': 'District', 'velocity': 9}
# Edge: ('Aldgate East', 'Tower Hill'), Data: {'length': 839.2339844118476, 'line_name': 'District', 'velocity': 9}
# Edge: ('Stepney Green', 'Mile End'), Data: {'length': 1029.2723772707482, 'line_name': 'District', 'velocity': 9}
# Edge: ('Mile End', 'Bow Road'), Data: {'length': 624.9321658959916, 'line_name': 'District', 'velocity': 9}
# Edge: ('Bow Road', 'Bromley-by-Bow'), Data: {'length': 1008.7699093618664, 'line_name': 'District', 'velocity': 9}
# Edge: ('Bromley-by-Bow', 'West Ham'), Data: {'length': 1212.245542674775, 'line_name': 'District', 'velocity': 9}
# Edge: ('West Ham', 'Plaistow'), Data: {'length': 929.835493558581, 'line_name': 'District', 'velocity': 9}
# Edge: ('West Ham', 'Canning Town'), Data: {'length': 1695.080745633354, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('West Ham', 'Abbey Road'), Data: {'length': 533.8424216961267, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('West Ham', 'Star Lane'), Data: {'length': 863.6516633001042, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Plaistow', 'Upton Park'), Data: {'length': 1321.0786434318884, 'line_name': 'District', 'velocity': 9}
# Edge: ('Upton Park', 'East Ham'), Data: {'length': 1300.2458265804771, 'line_name': 'District', 'velocity': 9}
# Edge: ('Baker Street', 'Great Portland Street'), Data: {'length': 829.5435436430772, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Baker Street', 'Edgware Road'), Data: {'length': 1034.8403674645297, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Baker Street', 'Bond Street'), Data: {'length': 1744.278230707794, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Baker Street', "St. John's Wood"), Data: {'length': 2138.930092928456, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Baker Street', 'Marylebone'), Data: {'length': 538.2983257941668, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Baker Street', "Regent's Park"), Data: {'length': 795.5400496350412, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Baker Street', 'Finchley Road'), Data: {'length': 3534.63724731488, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Great Portland Street', 'Euston Square'), Data: {'length': 619.9602182594983, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Euston Square', "King's Cross St. Pancras"), Data: {'length': 1039.478679695354, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ("King's Cross St. Pancras", 'Farringdon'), Data: {'length': 1857.9984375577433, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ("King's Cross St. Pancras", 'Angel'), Data: {'length': 1180.318720730565, 'line_name': 'Northern', 'velocity': 9}
# Edge: ("King's Cross St. Pancras", 'Russell Square'), Data: {'length': 870.500704742627, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ("King's Cross St. Pancras", 'Caledonian Road'), Data: {'length': 2034.7003654004757, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Farringdon', 'Barbican'), Data: {'length': 460.9099437416139, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Barbican', 'Moorgate'), Data: {'length': 707.2883661951114, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Moorgate', 'Old Street'), Data: {'length': 853.5197187449882, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Edgware Road', 'Paddington'), Data: {'length': 865.6743421093056, 'line_name': 'District', 'velocity': 9}
# Edge: ('Edgware Road', 'Marylebone'), Data: {'length': 602.8833428859415, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Hammersmith', 'Goldhawk Road'), Data: {'length': 1005.5893352451155, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Hammersmith', 'Barons Court'), Data: {'length': 893.8320859206598, 'line_name': 'District', 'velocity': 9}
# Edge: ('Hammersmith', 'Turnham Green'), Data: {'length': 2154.1567167489743, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Hammersmith', 'Ravenscourt Park'), Data: {'length': 840.1029182544273, 'line_name': 'District', 'velocity': 9}
# Edge: ('Goldhawk Road', "Shepherd's Bush Market"), Data: {'length': 439.28942248745847, 'line_name': 'Circle', 'velocity': 9}
# Edge: ("Shepherd's Bush Market", 'Wood Lane'), Data: {'length': 526.2629552444622, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Wood Lane', 'Latimer Road'), Data: {'length': 553.8620754401683, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Latimer Road', 'Ladbroke Grove'), Data: {'length': 659.5805348395729, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Ladbroke Grove', 'Westbourne Park'), Data: {'length': 805.9399274327974, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Westbourne Park', 'Royal Oak'), Data: {'length': 969.4042460432015, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Royal Oak', 'Paddington'), Data: {'length': 937.2965127136043, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Paddington', 'Warwick Avenue'), Data: {'length': 932.6259398243872, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Paddington', 'Bayswater'), Data: {'length': 1164.5036982271358, 'line_name': 'District', 'velocity': 9}
# Edge: ('West Acton', 'Ealing Broadway'), Data: {'length': 1616.9021668206203, 'line_name': 'Central', 'velocity': 9}
# Edge: ('West Acton', 'North Acton'), Data: {'length': 1811.4947747426338, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Ealing Broadway', 'Ealing Common'), Data: {'length': 1565.2970829542974, 'line_name': 'District', 'velocity': 9}
# Edge: ('North Acton', 'Hanger Lane'), Data: {'length': 2454.2933486674083, 'line_name': 'Central', 'velocity': 9}
# Edge: ('North Acton', 'East Acton'), Data: {'length': 1180.5193163423162, 'line_name': 'Central', 'velocity': 9}
# Edge: ('West Ruislip', 'Ruislip Gardens'), Data: {'length': 2124.393196486327, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Ruislip Gardens', 'South Ruislip'), Data: {'length': 885.8857261563876, 'line_name': 'Central', 'velocity': 9}
# Edge: ('South Ruislip', 'Northolt'), Data: {'length': 2323.990520709929, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Northolt', 'Greenford'), Data: {'length': 1818.4662603471857, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Greenford', 'Perivale'), Data: {'length': 1596.4351211843311, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Perivale', 'Hanger Lane'), Data: {'length': 2229.885214801866, 'line_name': 'Central', 'velocity': 9}
# Edge: ('East Acton', 'White City'), Data: {'length': 1957.1845158845322, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Holland Park', 'Notting Hill Gate'), Data: {'length': 699.7334629696009, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Notting Hill Gate', 'Queensway'), Data: {'length': 638.3229308800298, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Notting Hill Gate', 'High Street Kensington'), Data: {'length': 960.6455349941442, 'line_name': 'District', 'velocity': 9}
# Edge: ('Notting Hill Gate', 'Bayswater'), Data: {'length': 750.0482410997464, 'line_name': 'District', 'velocity': 9}
# Edge: ('Queensway', 'Lancaster Gate'), Data: {'length': 858.1496214616731, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Lancaster Gate', 'Marble Arch'), Data: {'length': 1218.6021847604447, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Marble Arch', 'Bond Street'), Data: {'length': 683.4362347682816, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Bond Street', 'Oxford Circus'), Data: {'length': 554.3405652906343, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Bond Street', 'Green Park'), Data: {'length': 1148.9123131606116, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Oxford Circus', 'Tottenham Court Road'), Data: {'length': 874.3023056336489, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Oxford Circus', "Regent's Park"), Data: {'length': 978.0506280250825, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Oxford Circus', 'Piccadilly Circus'), Data: {'length': 963.8300743985062, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Oxford Circus', 'Green Park'), Data: {'length': 1010.5664752575062, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Oxford Circus', 'Warren Street'), Data: {'length': 1149.7144464130404, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Tottenham Court Road', 'Holborn'), Data: {'length': 797.0616575604356, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Tottenham Court Road', 'Goodge Street'), Data: {'length': 644.4723699965093, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Tottenham Court Road', 'Leicester Square'), Data: {'length': 585.9403705631092, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Holborn', 'Chancery Lane'), Data: {'length': 565.4837123767416, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Holborn', 'Covent Garden'), Data: {'length': 632.9405713228314, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Holborn', 'Russell Square'), Data: {'length': 706.4343152148972, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Chancery Lane', "St. Paul's"), Data: {'length': 1095.1511969319665, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Leyton', 'Leytonstone'), Data: {'length': 1663.8435602914835, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Leytonstone', 'Snaresbrook'), Data: {'length': 1658.1506175069483, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Leytonstone', 'Wanstead'), Data: {'length': 1667.4505513987058, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Snaresbrook', 'South Woodford'), Data: {'length': 1315.8207360680212, 'line_name': 'Central', 'velocity': 9}
# Edge: ('South Woodford', 'Woodford'), Data: {'length': 1711.9549160130312, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Woodford', 'Buckhurst Hill'), Data: {'length': 2333.6093461223836, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Woodford', 'Roding Valley'), Data: {'length': 1392.430132825825, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Buckhurst Hill', 'Loughton'), Data: {'length': 1835.4744031274895, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Loughton', 'Debden'), Data: {'length': 2052.1170899150698, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Debden', 'Theydon Bois'), Data: {'length': 3322.111158031306, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Theydon Bois', 'Epping'), Data: {'length': 2625.4836875124006, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Wanstead', 'Redbridge'), Data: {'length': 1180.385556374102, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Redbridge', 'Gants Hill'), Data: {'length': 1457.7437616270238, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Gants Hill', 'Newbury Park'), Data: {'length': 2357.7571209039966, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Newbury Park', 'Barkingside'), Data: {'length': 1130.5544216561539, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Barkingside', 'Fairlop'), Data: {'length': 1168.7298360119833, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Fairlop', 'Hainault'), Data: {'length': 878.6835661434217, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Hainault', 'Grange Hill'), Data: {'length': 1107.648609974149, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Grange Hill', 'Chigwell'), Data: {'length': 1346.912730621657, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Chigwell', 'Roding Valley'), Data: {'length': 2188.659365740107, 'line_name': 'Central', 'velocity': 9}
# Edge: ('Edgware', 'Burnt Oak'), Data: {'length': 1518.129678863641, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Burnt Oak', 'Colindale'), Data: {'length': 1306.4220496936987, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Colindale', 'Hendon Central'), Data: {'length': 2152.513378983135, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Hendon Central', 'Brent Cross'), Data: {'length': 1133.6073424740214, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Brent Cross', 'Golders Green'), Data: {'length': 1515.0891033189582, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Golders Green', 'Hampstead'), Data: {'length': 2385.7259071813814, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Hampstead', 'Belsize Park'), Data: {'length': 1178.003104093141, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Belsize Park', 'Chalk Farm'), Data: {'length': 1038.1009394876469, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Chalk Farm', 'Camden Town'), Data: {'length': 993.7771470066834, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Camden Town', 'Kentish Town'), Data: {'length': 1277.9656427690122, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Camden Town', 'Mornington Crescent'), Data: {'length': 593.8127865687215, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Angel', 'Old Street'), Data: {'length': 1520.654760289358, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('London Bridge', 'Borough'), Data: {'length': 514.5938672619455, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('London Bridge', 'Bermondsey'), Data: {'length': 2087.8265384222937, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('London Bridge', 'Southwark'), Data: {'length': 1098.3490851025024, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Borough', 'Elephant & Castle'), Data: {'length': 821.1401522027518, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Elephant & Castle', 'Kennington'), Data: {'length': 839.5683892248398, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Elephant & Castle', 'Lambeth North'), Data: {'length': 995.7202823035962, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Kennington', 'Oval'), Data: {'length': 915.1576843385167, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Kennington', 'Nine Elms'), Data: {'length': 2030.621842856102, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Oval', 'Stockwell'), Data: {'length': 1284.024538401056, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Stockwell', 'Clapham North'), Data: {'length': 952.3018787751389, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Stockwell', 'Brixton'), Data: {'length': 1586.7375413017655, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Stockwell', 'Vauxhall'), Data: {'length': 1506.8557095093613, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Clapham North', 'Clapham Common'), Data: {'length': 642.7574913784013, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Clapham Common', 'Clapham South'), Data: {'length': 1252.3182327348222, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Clapham South', 'Balham'), Data: {'length': 1172.6346008163105, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Balham', 'Tooting Bec'), Data: {'length': 975.1654216105981, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Tooting Bec', 'Tooting Broadway'), Data: {'length': 1074.961442345419, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Tooting Broadway', 'Colliers Wood'), Data: {'length': 1280.4196837865097, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Colliers Wood', 'South Wimbledon'), Data: {'length': 1078.4681359938227, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('South Wimbledon', 'Morden'), Data: {'length': 1533.2463105578936, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Finchley Central', 'Mill Hill East'), Data: {'length': 1522.202442550613, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Finchley Central', 'West Finchley'), Data: {'length': 1236.790948157093, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Finchley Central', 'East Finchley'), Data: {'length': 2370.5565452766623, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Charing Cross', 'Embankment'), Data: {'length': 340.3308204587722, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Charing Cross', 'Leicester Square'), Data: {'length': 462.0748168446405, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Charing Cross', 'Piccadilly Circus'), Data: {'length': 571.8084397484674, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Embankment', 'Westminster'), Data: {'length': 753.7645436403577, 'line_name': 'District', 'velocity': 9}
# Edge: ('Embankment', 'Temple'), Data: {'length': 794.594002561262, 'line_name': 'District', 'velocity': 9}
# Edge: ('High Barnet', 'Totteridge & Whetstone'), Data: {'length': 2592.6305011470527, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Totteridge & Whetstone', 'Woodside Park'), Data: {'length': 1477.101696750776, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Woodside Park', 'West Finchley'), Data: {'length': 946.4743468962849, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('East Finchley', 'Highgate'), Data: {'length': 1749.0206582100698, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Highgate', 'Archway'), Data: {'length': 1590.2047962152337, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Archway', 'Tufnell Park'), Data: {'length': 993.5361118865152, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Tufnell Park', 'Kentish Town'), Data: {'length': 764.6010081567557, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Warren Street', 'Goodge Street'), Data: {'length': 532.5730091543625, 'line_name': 'Northern', 'velocity': 9}
# Edge: ('Leicester Square', 'Piccadilly Circus'), Data: {'length': 374.6914057698147, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Leicester Square', 'Covent Garden'), Data: {'length': 365.53129908227436, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Battersea Power Station', 'Nine Elms'), Data: {'length': 1073.4653619689052, 'line_name': 'Northern', 'velocity': 9}
# Edge: ("Earl's Court", 'Gloucester Road'), Data: {'length': 910.1212138490864, 'line_name': 'District', 'velocity': 9}
# Edge: ("Earl's Court", 'Barons Court'), Data: {'length': 1504.7980653620925, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ("Earl's Court", 'West Kensington'), Data: {'length': 944.0652943047372, 'line_name': 'District', 'velocity': 9}
# Edge: ("Earl's Court", 'High Street Kensington'), Data: {'length': 1300.860111181769, 'line_name': 'District', 'velocity': 9}
# Edge: ('Gloucester Road', 'South Kensington'), Data: {'length': 751.3334794399693, 'line_name': 'District', 'velocity': 9}
# Edge: ('Gloucester Road', 'High Street Kensington'), Data: {'length': 1005.1187862236483, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Barons Court', 'West Kensington'), Data: {'length': 563.6761451115776, 'line_name': 'District', 'velocity': 9}
# Edge: ('Turnham Green', 'Acton Town'), Data: {'length': 2222.542223351653, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Turnham Green', 'Stamford Brook'), Data: {'length': 610.2892102797041, 'line_name': 'District', 'velocity': 9}
# Edge: ('Turnham Green', 'Chiswick Park'), Data: {'length': 950.3729810236479, 'line_name': 'District', 'velocity': 9}
# Edge: ('Acton Town', 'South Ealing'), Data: {'length': 2127.939214032974, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Acton Town', 'Ealing Common'), Data: {'length': 1026.622829137713, 'line_name': 'District', 'velocity': 9}
# Edge: ('Acton Town', 'Chiswick Park'), Data: {'length': 1274.9448068885617, 'line_name': 'District', 'velocity': 9}
# Edge: ('South Ealing', 'Northfields'), Data: {'length': 452.9452906768383, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Knightsbridge', 'South Kensington'), Data: {'length': 1300.815318533093, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Knightsbridge', 'Hyde Park Corner'), Data: {'length': 583.9535882999706, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('South Kensington', 'Sloane Square'), Data: {'length': 1173.2223716014348, 'line_name': 'District', 'velocity': 9}
# Edge: ('Hyde Park Corner', 'Green Park'), Data: {'length': 779.8893002668186, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Green Park', 'Piccadilly Circus'), Data: {'length': 777.6260868051975, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Green Park', 'Westminster'), Data: {'length': 1423.7801946060954, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Green Park', 'Victoria'), Data: {'length': 1209.5998088020804, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Caledonian Road', 'Holloway Road'), Data: {'length': 615.2974429781583, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Holloway Road', 'Arsenal'), Data: {'length': 666.7091358867409, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Arsenal', 'Finsbury Park'), Data: {'length': 772.7526932281038, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Finsbury Park', 'Manor House'), Data: {'length': 1116.1136272204067, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Manor House', 'Turnpike Lane'), Data: {'length': 2321.6593584487423, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Turnpike Lane', 'Wood Green'), Data: {'length': 930.8256254031667, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Wood Green', 'Bounds Green'), Data: {'length': 1505.437914405501, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Bounds Green', 'Arnos Grove'), Data: {'length': 1354.2424903762085, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Arnos Grove', 'Southgate'), Data: {'length': 1979.1485866133203, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Southgate', 'Oakwood'), Data: {'length': 1865.6448541161906, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Oakwood', 'Cockfosters'), Data: {'length': 1343.9783464004338, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Rayners Lane', 'South Harrow'), Data: {'length': 1805.5567061354982, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Rayners Lane', 'Eastcote'), Data: {'length': 1819.3543779174295, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Rayners Lane', 'West Harrow'), Data: {'length': 1364.1124364105162, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('South Harrow', 'Sudbury Hill'), Data: {'length': 1485.465659034139, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Sudbury Hill', 'Sudbury Town'), Data: {'length': 1617.0566152944361, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Sudbury Town', 'Alperton'), Data: {'length': 1660.3572820422125, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Alperton', 'Park Royal'), Data: {'length': 1922.398209631674, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Park Royal', 'North Ealing'), Data: {'length': 1099.6584506284205, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('North Ealing', 'Ealing Common'), Data: {'length': 924.4084541330353, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Uxbridge', 'Hillingdon'), Data: {'length': 2144.395127372481, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Hillingdon', 'Ickenham'), Data: {'length': 1124.4371952028953, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Ickenham', 'Ruislip'), Data: {'length': 1785.6549823456592, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Ruislip', 'Ruislip Manor'), Data: {'length': 678.8859802386172, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Ruislip Manor', 'Eastcote'), Data: {'length': 1126.2390522053406, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Heathrow Terminal 4', 'Hatton Cross'), Data: {'length': 1876.332693638775, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Heathrow Terminal 4', 'Heathrow Terminals 2 & 3'), Data: {'length': 4186.5370884130325, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Hatton Cross', 'Heathrow Terminals 2 & 3'), Data: {'length': 2412.750945791165, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Hatton Cross', 'Hounslow West'), Data: {'length': 2803.473661246835, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Heathrow Terminals 2 & 3', 'Heathrow Terminal 5'), Data: {'length': 2455.278475636329, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Hounslow West', 'Hounslow Central'), Data: {'length': 1479.0836919963704, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Hounslow Central', 'Hounslow East'), Data: {'length': 745.6843834209199, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Hounslow East', 'Osterley'), Data: {'length': 967.4946724433414, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Osterley', 'Boston Manor'), Data: {'length': 2560.8142912612416, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Boston Manor', 'Northfields'), Data: {'length': 930.8521452439904, 'line_name': 'Piccadilly', 'velocity': 9}
# Edge: ('Wembley Park', 'Kingsbury'), Data: {'length': 2916.771558050728, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Wembley Park', 'Neasden'), Data: {'length': 2353.165938195784, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Wembley Park', 'Preston Road'), Data: {'length': 1419.7351657628526, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Wembley Park', 'Finchley Road'), Data: {'length': 7266.373927496486, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Kingsbury', 'Queensbury'), Data: {'length': 1245.995234363654, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Queensbury', 'Canons Park'), Data: {'length': 1693.3073431971377, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Canons Park', 'Stanmore'), Data: {'length': 1419.669476245658, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Canning Town', 'North Greenwich'), Data: {'length': 1799.9427780922347, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Canning Town', 'Star Lane'), Data: {'length': 866.9991916215074, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Canning Town', 'Royal Victoria'), Data: {'length': 989.5890743359752, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Canning Town', 'East India'), Data: {'length': 1155.218499145243, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Canning Town', 'West Silvertown'), Data: {'length': 1651.1250609247024, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('North Greenwich', 'Canary Wharf'), Data: {'length': 1829.783291029508, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Canary Wharf', 'West India Quay'), Data: {'length': 327.244216246571, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Canary Wharf', 'Heron Quays'), Data: {'length': 351.5719873946413, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Westminster', "St. James's Park"), Data: {'length': 560.7493399067275, 'line_name': 'District', 'velocity': 9}
# Edge: ("St. John's Wood", 'Swiss Cottage'), Data: {'length': 969.9402928050129, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Swiss Cottage', 'Finchley Road'), Data: {'length': 645.352744225376, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Neasden', 'Dollis Hill'), Data: {'length': 785.5830137547828, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Dollis Hill', 'Willesden Green'), Data: {'length': 1246.109381792944, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Willesden Green', 'Kilburn'), Data: {'length': 1185.0579298370324, 'line_name': 'Jubilee', 'velocity': 9}
# Edge: ('Maryland', 'Forest Gate'), Data: {'length': 1303.7590706656426, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Forest Gate', 'Manor Park'), Data: {'length': 1548.76580881777, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Manor Park', 'Ilford'), Data: {'length': 1831.4694245351989, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Ilford', 'Seven Kings'), Data: {'length': 1970.5719243436356, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Seven Kings', 'Goodmayes'), Data: {'length': 983.7481715426209, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Goodmayes', 'Chadwell Heath'), Data: {'length': 1284.1799168510881, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Gidea Park', 'Harold Wood'), Data: {'length': 2284.6409372785006, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Harold Wood', 'Brentwood'), Data: {'length': 5269.263106583304, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Brentwood', 'Shenfield'), Data: {'length': 3348.9245038385347, 'line_name': 'TfL Rail', 'velocity': 9}
# Edge: ('Kilburn Park', 'Maida Vale'), Data: {'length': 851.7815229276852, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Maida Vale', 'Warwick Avenue'), Data: {'length': 787.6125699512305, 'line_name': 'Bakerloo', 'velocity': 9}
# Edge: ('Sloane Square', 'Victoria'), Data: {'length': 1165.7590132287191, 'line_name': 'District', 'velocity': 9}
# Edge: ('Victoria', "St. James's Park"), Data: {'length': 777.3055963190485, 'line_name': 'District', 'velocity': 9}
# Edge: ('Victoria', 'Pimlico'), Data: {'length': 1399.8781509033963, 'line_name': 'Victoria', 'velocity': 9}
# Edge: ('Temple', 'Blackfriars'), Data: {'length': 752.0407994032548, 'line_name': 'District', 'velocity': 9}
# Edge: ('Blackfriars', 'Mansion House'), Data: {'length': 660.2642961234002, 'line_name': 'District', 'velocity': 9}
# Edge: ('Mansion House', 'Cannon Street'), Data: {'length': 248.17870615089865, 'line_name': 'District', 'velocity': 9}
# Edge: ('Tower Hill', 'Aldgate'), Data: {'length': 597.1867971231038, 'line_name': 'Circle', 'velocity': 9}
# Edge: ('Ravenscourt Park', 'Stamford Brook'), Data: {'length': 709.2895541696818, 'line_name': 'District', 'velocity': 9}
# Edge: ('Wimbledon', 'Wimbledon Park'), Data: {'length': 1655.9122645891123, 'line_name': 'District', 'velocity': 9}
# Edge: ('Wimbledon Park', 'Southfields'), Data: {'length': 1359.649769982491, 'line_name': 'District', 'velocity': 9}
# Edge: ('Southfields', 'East Putney'), Data: {'length': 1630.8880949905108, 'line_name': 'District', 'velocity': 9}
# Edge: ('East Putney', 'Putney Bridge'), Data: {'length': 1058.5655902705403, 'line_name': 'District', 'velocity': 9}
# Edge: ('Putney Bridge', 'Parsons Green'), Data: {'length': 994.4623493165212, 'line_name': 'District', 'velocity': 9}
# Edge: ('Parsons Green', 'Fulham Broadway'), Data: {'length': 702.3383314281062, 'line_name': 'District', 'velocity': 9}
# Edge: ('Upney', 'Becontree'), Data: {'length': 1927.1569041478324, 'line_name': 'District', 'velocity': 9}
# Edge: ('Becontree', 'Dagenham Heathway'), Data: {'length': 1428.200777067089, 'line_name': 'District', 'velocity': 9}
# Edge: ('Dagenham Heathway', 'Dagenham East'), Data: {'length': 1279.2277890495373, 'line_name': 'District', 'velocity': 9}
# Edge: ('Dagenham East', 'Elm Park'), Data: {'length': 2295.788356383098, 'line_name': 'District', 'velocity': 9}
# Edge: ('Elm Park', 'Hornchurch'), Data: {'length': 1544.3272116890414, 'line_name': 'District', 'velocity': 9}
# Edge: ('Hornchurch', 'Upminster Bridge'), Data: {'length': 1226.92948021644, 'line_name': 'District', 'velocity': 9}
# Edge: ('West Harrow', 'Harrow-on-the-Hill'), Data: {'length': 1241.8686903537798, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Harrow-on-the-Hill', 'North Harrow'), Data: {'length': 1979.628722481944, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Harrow-on-the-Hill', 'Northwick Park'), Data: {'length': 1303.1318574246761, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Amersham', 'Chalfont & Latimer'), Data: {'length': 3385.6601473563414, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Chalfont & Latimer', 'Chorleywood'), Data: {'length': 3512.8532914577477, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Chalfont & Latimer', 'Chesham'), Data: {'length': 6315.936388258736, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Chorleywood', 'Rickmansworth'), Data: {'length': 3551.353240563792, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Rickmansworth', 'Moor Park'), Data: {'length': 3397.2194579963216, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Moor Park', 'Northwood'), Data: {'length': 2218.2991124084024, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Moor Park', 'Croxley'), Data: {'length': 2910.1506484065285, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Northwood', 'Northwood Hills'), Data: {'length': 1586.6688847131977, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Northwood Hills', 'Pinner'), Data: {'length': 2158.6485916960487, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Pinner', 'North Harrow'), Data: {'length': 1517.7554108908482, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Northwick Park', 'Preston Road'), Data: {'length': 1733.1337992221177, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Croxley', 'Watford'), Data: {'length': 2054.878524660146, 'line_name': 'Metropolitan', 'velocity': 9}
# Edge: ('Stratford High Street', 'Abbey Road'), Data: {'length': 655.2113012868256, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Royal Victoria', 'Custom House'), Data: {'length': 606.3433882279246, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Limehouse', 'Westferry'), Data: {'length': 973.6170070798671, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Westferry', 'West India Quay'), Data: {'length': 576.9560077519421, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Westferry', 'Poplar'), Data: {'length': 682.5134447409253, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('West India Quay', 'Poplar'), Data: {'length': 260.8625738886104, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Heron Quays', 'South Quay'), Data: {'length': 651.6418490679744, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('South Quay', 'Crossharbour'), Data: {'length': 596.7475038226244, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Crossharbour', 'Mudchute'), Data: {'length': 466.369801569662, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Mudchute', 'Island Gardens'), Data: {'length': 553.4510088555899, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Island Gardens', 'Cutty Sark'), Data: {'length': 797.6025385743914, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Cutty Sark', 'Greenwich'), Data: {'length': 633.6424322191381, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Greenwich', 'Deptford Bridge'), Data: {'length': 784.8639108674407, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Deptford Bridge', 'Elverson Road'), Data: {'length': 727.5004500175838, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Elverson Road', 'Lewisham'), Data: {'length': 563.545791869791, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Poplar', 'All Saints'), Data: {'length': 751.9819426773367, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Poplar', 'Blackwall'), Data: {'length': 722.9585574521175, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('All Saints', 'Langdon Park'), Data: {'length': 506.4239944344515, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Blackwall', 'East India'), Data: {'length': 391.30720560220516, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Custom House', 'Prince Regent'), Data: {'length': 524.4868788091322, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Prince Regent', 'Royal Albert'), Data: {'length': 888.4204824783974, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Royal Albert', 'Beckton Park'), Data: {'length': 666.2264934724285, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Beckton Park', 'Cyprus'), Data: {'length': 628.1101328837806, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Cyprus', 'Gallions Reach'), Data: {'length': 741.7738804546091, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Gallions Reach', 'Beckton'), Data: {'length': 1236.2482759987142, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Langdon Park', 'Devons Road'), Data: {'length': 852.3487962902293, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Devons Road', 'Bow Church'), Data: {'length': 638.4852454662258, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Bow Church', 'Pudding Mill Lane'), Data: {'length': 1008.2942934529501, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Woolwich Arsenal', 'King George V'), Data: {'length': 2429.275743328937, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('King George V', 'London City Airport'), Data: {'length': 1028.5768913264737, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('West Silvertown', 'Pontoon Dock'), Data: {'length': 756.0458898720703, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Pontoon Dock', 'London City Airport'), Data: {'length': 1141.3500296616812, 'line_name': 'DLR', 'velocity': 9}
# Edge: ('Vauxhall', 'Pimlico'), Data: {'length': 825.3282533076276, 'line_name': 'Victoria', 'velocity': 9}

# %%
# Add 'velocity' field to each edge with value 60
for u, v, data in G.edges(data=True):
    data['train_time'] = data['length'] / data['velocity']

# %%
# Add 'velocity' field to each edge with value 60
for u, v, data in G.edges(data=True):
    data['dwell_time'] = data['flows'] / 50000 * 120
    data['travel_time'] = data['dwell_time'] + data['train_time']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[177], line 3
#       1 # Add 'velocity' field to each edge with value 60
#       2 for u, v, data in G.edges(data=True):
# ----> 3     data['dwell_time'] = data['flows'] / 50000 * 120
#       4     data['travel_time'] = data['dwell_time'] + data['train_time']
#
# KeyError: 'flows'

# %%
#creating the new weight, time and flows (travel time)
#travel_time = f(flows, train_time, dwell_time) # finding the formula
#travel_time = train_time + (flows * dwell time)

# Estimating Additional Dwell Time for 1,000 Passengers:

# If we assume a boarding/alighting time of 2.5 seconds per person (an average in crowded conditions)
#dwell_time = 1,000 people * 2.5 seconds/person = 2,500 seconds.
    
# Considering Multiple Doors
# London Underground trains have multiple doors per carriage (typically 3 to 4 doors per side, with about 6 to 8 carriages)
#dwell_time = Total boarding time / Number of doors = 2,500 seconds / 20 = 125 seconds (~2 minus for every additional 1000 passengers)

#travel_time (A->B) = train_time (A->B) + ((total flows of all stations between A->B /1000) * 2 min)

# %%
#inputting the new weight into the network
#set this as a network attribute (change flow to new weight)
#nx.set_edge_attributes(G, flows, 'flows') # <- change into travel_time

#plot our calcuated flows
max_travel_time = max(data['travel_time'] for u, v, data in G.edges(data=True))
travel_color = [(i[2]['travel_time']/max_travel_time) for i in G.edges(data=True)]
travel_width = [(i[2]['travel_time']/max_travel_time)*10 for i in G.edges(data=True)]

# Plot graph
fig, ax = plt.subplots(figsize=(12,12))

#pos=nx.spring_layout(X)
edg=nx.draw_networkx_edges(G, pos,edge_color=travel_color, width=travel_width)

nx.draw_networkx_nodes(G,
        pos = pos,
        node_color= 'black',
        node_size= 1)

plt.colorbar(edg,label="Passenger Travel Time",orientation="horizontal", shrink=0.5)
plt.axis("off")
plt.title("London network Passenger Travel Time",fontsize=15)
plt.show()

# %%
#set this as a network attribute (change flow to new weight)
nx.set_edge_attributes(G, flows, 'flows') # <- change into travel_time

#plot our calcuated flows
flows_values = flows.values()
flow_color=[(i[2]['flows']/max(flows_values)) for i in G.edges(data=True)]
flow_width=[(i[2]['flows']/max(flows_values)*10) for i in G.edges(data=True)]

# Plot graph
fig, ax = plt.subplots(figsize=(12,12))

#pos=nx.spring_layout(X)
edg=nx.draw_networkx_edges(G, pos,edge_color=flow_color, width=flow_width)

nx.draw_networkx_nodes(G,
        pos = pos,
        node_color= 'black',
        node_size= 1)

plt.colorbar(edg,label="Passenger Flows",orientation="horizontal", shrink=0.5)
plt.axis("off")
plt.title("London network Passenger Flows",fontsize=15)
plt.show()

# %%
# weighted alternatives
## 1. time and flow = weight

# %% [markdown]
# # II. Average Shortest Path Length (APL) Analysis

# %%
## a. Scenario 1: Business As Usual

# %%
avg_shortest_path_length = nx.average_shortest_path_length(G, weight='travel_time')
print(avg_shortest_path_length)

# %%
# Calculate all-pairs shortest paths (weighted)
path_lengths = dict(nx.all_pairs_dijkstra_path_length(G, weight='travel_time'))

# Extract the shortest path lengths into a list
lengths = []
for source, target_dict in path_lengths.items():
    for target, length in target_dict.items():
        if source != target:  # avoid zero-length paths (self loops)
            lengths.append(length)

# Plot histogram
plt.hist(lengths, bins=5, edgecolor='black')
plt.title('Histogram of Shortest Path Lengths (Weighted)')
plt.xlabel('Path Length')
plt.ylabel('Frequency')
plt.show()

# %%
## b. Scenario 2: Winter Disruption without Government Intervention

# %%
import networkx as nx

# Create a weighted graph
G = nx.Graph()

# Add edges with initial weights
G.add_edge('A', 'B', weight=4)
G.add_edge('B', 'C', weight=2)
G.add_edge('A', 'C', weight=5)

# Print the original weight of the edge A-B
print(f"Original weight of A-B: {G.edges['A', 'B']['weight']}")

# Update the weight of the edge A-B
G.edges['A', 'B']['weight'] = 10

# Print the new weight of the edge A-B
print(f"Updated weight of A-B: {G.edges['A', 'B']['weight']}")

# %%
## c. Scenario 3: Winter Disruption with Government Intervention

# %%
## d. APL Comparison between Scenarios

# %% [markdown]
# # III. Betweeness Centrality (BC) Analysis

# %%
## a. Scenario 1: Business As Usual

# %%
## b. Scenario 2: Winter Disruption without Government Intervention

# %%
## c. Scenario 3: Winter Disruption with Government Intervention

# %%
## d. BC Comparison between Scenarios

# %% [markdown]
# # IV. Intervention Recommendation
